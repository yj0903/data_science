# %% [markdown]
# <div align="center">
#     <img src="images/zb-logo.png" alt="제로베이스" width="100%">
#     <br>
#     <a href="https://zerobaseschool.notion.site/DS-EDA-Lv-Test-b7d5e895c7cd4dda813c8fe2f2c23f79"><img src="images/openinnotion_logo.png" alt="EDA Lv Test Doc" width="12%"></a>
#
# 이 Jupyter Notebook 파일은 <a href="https://zero-base.co.kr/category_data_camp/school_DS">제로베이스</a>에서 제공하는 **EDA Level Test** 문제입니다.<br>
# 지금까지 공부하신 내용으로 데이터 분석에 대해 좀 더 연습할 수 있는 시간이 되셨으면 좋겠습니다.🙂<br>
# **EDA Level Test**에 대한 안내 사항은 상단 **Open in ZeroBase Notion** 로고를 클릭하여 확인해주세요!<br>
# 반드시 시작 전에 내용을 숙지해주시기를 바랍니다!<br>
# </div>
#
# ***

# %% [markdown]
# <h1 style="background-color:#9F81F7;color:#D8D8D8;font-weight:bold;display:inline-block;padding: 5px">EDA Level Test 07 ⭐️</h1>
#
# | Week | Data Analysis | Difficulty | This Notebook |
# |------|---------------|------------|-------|
# | 1    | 서울시 인구 데이터 | ⭐️ ||
# | 2    | 화장품 성분 데이터 | ⭐️⭐️⭐️ ||
# | 3    | 올림픽 데이터 | ⭐️⭐️ ||
# | 4    | 국가별 인터넷 사용률 데이터 |⭐️⭐️ ||
# | 5    | 전국 박물관/미술관 정보 표준 데이터 | ⭐️⭐️⭐️ ||
# | 6    | 서울시 흡연율 통계 데이터 | ⭐️⭐️ ||
# | 7    | 웹크롤링 | ⭐️ |👈|
# | 8    | 서울시 지하철 호선별 역별 유/무임 승하차 인원 정보 데이터 | ⭐️⭐️ ||
# | 9    | 서울시 교통사고 현황 (사고유형별) 통계 데이터 | ⭐️⭐️ ||
# | 10   | 서울시 교통사고 현황 (사고유형별) 통계 + 서울시 차량통행속도 (구별/월별) 통계 + 서울시 인구밀도 (구별) 통계 | ⭐️⭐️⭐️ ||

# %% [markdown]
# ## 문제 소개 및 데이터 준비 단계
#
# <div style="border: 1px solid black; padding: 10px;">
#
# - 총 3단계 데이터 분석 상황 제시
# <br></br>
#     - 1단계: Web Crawling & DataFrame 만들기 01
#     - 2단계: Web Crawling & DataFrame 만들기 02
#     - 3단계: 원하는 정보 얻기
#     - 총점 100점
#
# ### Data 원본 출처
#
# ### Target Data(Web Page): 인터파크 영화 예매율 주간순위
# - Source: [인터파크 영화 랭킹리포트](http://movie.interpark.com/Community/Movie/Ranking/Ranking_Report.asp)
# - 하기 Image의 [영화 Top 10]이 Target Data 입니다.
# <br></br>
# <img src="images/00-001.png" style="margin:auto" width=600/>
# <br></br>
# ##### 참고사항
# - 해당 Web Page는 **Post** 방식으로 이루어진 Web Page입니다.
# - Selenium, request.post() 등 어떤 방식으로 Crawling해도 상관 없습니다.
#     - 단, 실행 환경의 차이를 감안하여 추후 제공될 정답은 request.post() 방식으로 제공합니다.
# - 해당 Web Page의 예매율 주간순위는 매 주 목요일부터 일요일까지의 관람일을 기준으로 집계되었습니다.
# <br></br>
# - 문제에 hint가 있을 경우, 해당 hint를 이용하지 않으셔도 무방합니다.
#
# ##### 주의사항
# - 해당 문제는 웹크롤링을 이용하는 문제입니다.
# - 때문에, 웹페이지 구조와 데이터가 시간이 지남에 따라 변화할 수 있습니다.
# - 이러한 점을 감안하시어, 문제에 대응하시기를 바랍니다 🙂
#
# </div>

# %% [markdown]
# # 3. 문제

# %% [markdown]
# ## 1단계: Web Crawling & DataFrame 만들기 01
# ***

# %% [markdown]
# ### 문제 1) Web Crawling: Data 가져오기 (40점)
# - 아래 Link를 참고하여 해당 Page의 Data를 Crawling하고, 아래 조건에 맞게 DataFrame(df_week)을 만드세요.
# <br></br>
#     - Link: [인터파크 영화 랭킹리포트](http://movie.interpark.com/Community/Movie/Ranking/Ranking_Report.asp)
# <br></br>
#     - 기준 주(week): 2022년 7월 21일(목) ~ 7월 24일 (일) 기준
# <br></br>
#     - Target Data: 영화 Top10의 1위 ~ 10위에 해당하는 영화의 순위 / 순위증감 / 영화 제목 / 예매점유율 / 개봉일
# <br></br>
#     <img src="images/07-1-1-001.png" style="margin:auto" width=600/>
# <br></br>
#     - 조건1: 상기 Link의 '기준 주(week)'에 해당하는 Web Page의 [영화 Top10]의 표(Table) Data를 Crawling 하세요.
#         - 앞서 언급하였다시피 해당 Page는 Post 방식 입니다.
#         - 해당 표(Table)안의 Data 중 string Data만 가져오면 됩니다(Image Data는 필요 없습니다.)
# <br></br>
#     - 조건2: 결과 DataFrame의 Column은 ['순위', '순위증감', '영화제목', '예매점유율', '개봉일'] 입니다.
#         - 아래 columns로 할당된 변수를 참고하세요.
# <br></br>
#     - 조건3: 상기 Web Page에서 '(▲1)', '(▼2)', '( - )' 로 표기되어 있는 '순위증감'은 괄호('(', ')')를 없애고 입력하여주세요.
# <br></br>
#     - 조건4: 결과 DataFrame 내의 모든 Data는 해당 Data 앞뒤로 띄어쓰기 등 공백이 없어야 합니다.
# <br></br>
#     - 조건5: 상기 Web Page에서 'new'(image)로 표기되어 있는 '순위증감'은 'new'(string)로 입력하여 주세요.
# <br></br>
#         - 조건 1~5를 만족했다면, 그 결과는 아래 Image와 같습니다.
# <br></br>
#         <img src="images/07-1-1-002.png" style="margin:auto" width=500/>
# <br></br>
#     - 조건6: 결과 DataFrame은 '개봉일' 기준으로 오름차순으로 정렬하고, 동일한 '개봉일' Data가 있다면 해당 Data에 대해서는 '순위'를 기준으로 내림차순 하여 정렬해주세요. Index는 조건4의 예시 그대로 1위가 0, 2위가 1, ..., 10위가 9 입니다.
# <br></br>
#         - 예시: 'B'기준 오름차순 정렬, 'B'의 Data가 같은 경우 'A'의 내림차순으로 정렬
# <br></br>
#         <img src="images/07-1-1-003.png" style="margin:auto" width=300/>
# <br></br>
#     - 조건7: 'df_week' 변수에 결과 DataFrame을 할당하세요.
# <br></br>
# <br></br>
#     - 주의사항: 빠른 시간 내에 너무 자주 Data를 Crawling할 경우 Error 발생할 수 있습니다.
# <br></br>
# <br></br>
# - 완료 후 결과 DataFrame 변수(df_week)를 check_01 함수에 입력하여 채점하세요.

# %%
# 채점을 위한 코드입니다. 반드시 실행해주세요.
from grading import *

columns = ['순위', '순위증감', '영화제목', '예매점유율', '개봉일']

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver import ActionChains
import pandas as pd
import time
import numpy as np
from datetime import datetime

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc
rc("font", family = "Malgun Gothic")


# %matplotlib inline

# %%
import pandas as pd
dates = pd.date_range("2021.08.12","2022.07.21",freq='7D')
result = dates.strftime("%Y.%m.%d")
result
# Out:
# Index(['2021.08.12', '2021.08.19', '2021.08.26', '2021.09.02', '2021.09.09',
#        '2021.09.16', '2021.09.23', '2021.09.30', '2021.10.07', '2021.10.14',
#        '2021.10.21', '2021.10.28', '2021.11.04', '2021.11.11', '2021.11.18',
#        '2021.11.25', '2021.12.02', '2021.12.09', '2021.12.16', '2021.12.23',
#        '2021.12.30', '2022.01.06', '2022.01.13', '2022.01.20', '2022.01.27',
#        '2022.02.03', '2022.02.10', '2022.02.17', '2022.02.24', '2022.03.03',
#        '2022.03.10', '2022.03.17', '2022.03.24', '2022.03.31', '2022.04.07',
#        '2022.04.14', '2022.04.21', '2022.04.28', '2022.05.05', '2022.05.12',
#        '2022.05.19', '2022.05.26', '2022.06.02', '2022.06.09', '2022.06.16',
#        '2022.06.23', '2022.06.30', '2022.07.07', '2022.07.14', '2022.07.21'],
#       dtype='object')

# %%
# def check_date(date_str):
#     try:
#         date = pd.to_datetime(date_str, format='%Y.%m.%d')
#         return date in dates
#     except ValueError:
#         return False

# # Test the function
# date_to_check = "2022.02.17"
# check_date(date_to_check)

# %%
from datetime import datetime

def check_date(date_str):
    try:
        datetime.strptime(date_str, "%Y.%m.%d")
        return True
    except ValueError:
        return False

# %% [markdown]
# - 날짜형식인 데이터가 나오기 전까지는 하나의 리스트로 저장하다가
# - 날짜 형식 데이터가 나오면 그때까지의 모든 데이터를 list형으로 raw_list에 한번에 저장하는 것

# %%
# chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome()
driver.maximize_window()    
url = "http://movie.interpark.com/Community/Movie/Ranking/Ranking_Report.asp"
driver.get(url)

total_data = []

for date in result:
    select_date_but = driver.find_element(By.XPATH, '/html/body/table/tbody/tr[2]/td[3]/table/tbody/tr/td/table[3]/tbody/tr[2]/td/table[1]/tbody/tr[3]/td/form/select')
    select_date_but.send_keys(date)
    
    time.sleep(3)
    
    tmp = driver.find_elements(By.XPATH, '/html/body/table/tbody/tr[2]/td[3]/table/tbody/tr/td/table[3]/tbody/tr[2]/td/table[3]/tbody/tr[3]/td[2]/table/tbody')[0].text
    raw_data = tmp.split('\n')
    
    
    raw_list = []
    li = []

    for data in raw_data:
        
        data = data.strip()
        
        if data == '':
            print('null: ', data)
            continue

        elif check_date(data) or data == "0000..":
            li.append(data)
            li.append(date)
            raw_list.append(li)
            li = []
            print('check_date or 0000.. ', data)
            

        else:
            li.append(data)
            print(data)
            

    total_data.append(raw_list)

    
driver.close()
driver.quit()
# Out:
# 1위
# null:
# 싱크홀(2021)
# 66.1%
# check_date or 0000..  2021.08.11
# 2위
# (▼1)
# null:
# 모가디슈(디지털)
# 20.1%
# check_date or 0000..  2022.09.07
# 3위
# (▼1)
# null:
# 보스 베이비2(디지털)
# 5.2%
# check_date or 0000..  2021.07.21
# 4위
# null:
# 프리 가이(디지털)
# 2.7%
# check_date or 0000..  2021.08.11
# 5위
# (▼1)
# null:
# 극장판 도라에몽: 진구의 신공룡(디지털 더빙)
# 1.5%
# check_date or 0000..  2021.08.05
# 6위
# null:
# 하이큐!! 땅 VS 하늘(디지털 더빙)
# 1.2%
# check_date or 0000..  2021.08.12
# 6위
# (▼3)
# null:
# 더 수어사이드 스쿼드(디지털)
# 1.2%
# check_date or 0000..  2021.08.04
# 8위
# (▼1)
# null:
# 랑종(디지털)
# 0.6%
# check_date or 0000..  2021.07.14
# 9위
# (▼4)
# null:
# 정글 크루즈(디지털)
# 0.4%
# check_date or 0000..  2021.07.28
# 10위
# (▼4)
# null:
# 블랙 위도우(디지털)
# 0.3%
# check_date or 0000..  2021.07.07
# 1위
# ( - )
# null:
# 싱크홀(2021)
# 49.1%
# check_date or 0000..  2021.08.11
# 2위
# null:
# 인질(디지털)
# 28.6%
# check_date or 0000..  2021.08.18
# 3위
# (▼1)
# null:
# 모가디슈(디지털)
# 9.5%
# check_date or 0000..  2022.09.07
# 4위
# null:
# ...

# %%
for row in total_data:
    print("*"*50, "ROW","*"*50)
    for data in row:
        print(data)
# Out:
# ************************************************** ROW **************************************************
# ['1위', '싱크홀(2021)', '66.1%', '2021.08.11', '2021.08.12']
# ['2위', '(▼1)', '모가디슈(디지털)', '20.1%', '2022.09.07', '2021.08.12']
# ['3위', '(▼1)', '보스 베이비2(디지털)', '5.2%', '2021.07.21', '2021.08.12']
# ['4위', '프리 가이(디지털)', '2.7%', '2021.08.11', '2021.08.12']
# ['5위', '(▼1)', '극장판 도라에몽: 진구의 신공룡(디지털 더빙)', '1.5%', '2021.08.05', '2021.08.12']
# ['6위', '하이큐!! 땅 VS 하늘(디지털 더빙)', '1.2%', '2021.08.12', '2021.08.12']
# ['6위', '(▼3)', '더 수어사이드 스쿼드(디지털)', '1.2%', '2021.08.04', '2021.08.12']
# ['8위', '(▼1)', '랑종(디지털)', '0.6%', '2021.07.14', '2021.08.12']
# ['9위', '(▼4)', '정글 크루즈(디지털)', '0.4%', '2021.07.28', '2021.08.12']
# ['10위', '(▼4)', '블랙 위도우(디지털)', '0.3%', '2021.07.07', '2021.08.12']
# ************************************************** ROW **************************************************
# ['1위', '( - )', '싱크홀(2021)', '49.1%', '2021.08.11', '2021.08.19']
# ...

# %%
# 괄호 제거, new 삽입
for row in total_data:
    for data in row:
        if data[1][0] != "(":
            data.insert(1, 'new')
            
        else:
            data[1] = data[1][1:-1]
     
    
# 데이터프레임
columns = ['순위', '순위증감', '영화제목', '예매점유율', '개봉일', '주']
tmp_li = []
for data in total_data:
    tmp_df = pd.DataFrame(data, columns=columns)
    tmp_li.append(tmp_df)


df_week = pd.concat(tmp_li)
df_week
# Out:
#      순위 순위증감                       영화제목  예매점유율         개봉일           주
# 0    1위  new                  싱크홀(2021)  66.1%  2021.08.11  2021.08.12
# 1    2위   ▼1                  모가디슈(디지털)  20.1%  2022.09.07  2021.08.12
# 2    3위   ▼1               보스 베이비2(디지털)   5.2%  2021.07.21  2021.08.12
# 3    4위  new                 프리 가이(디지털)   2.7%  2021.08.11  2021.08.12
# 4    5위   ▼1  극장판 도라에몽: 진구의 신공룡(디지털 더빙)   1.5%  2021.08.05  2021.08.12
# ..  ...  ...                        ...    ...         ...         ...
# 5    6위   ▼3       더 킬러: 죽어도 되는 아이(디지털)   3.0%  2022.07.13  2022.07.21
# 6    7위   ▼2           토르: 러브 앤 썬더(디지털)   2.6%  2022.07.06  2022.07.21
# 7    8위   ▼1                로스트 도터(디지털)   2.2%  2022.07.14  2022.07.21
# 8    9위   ▼3       명탐정 코난: 할로윈의 신부(디지털)   1.9%  2022.10.28  2022.07.21
# 9   10위   ▼1                범죄도시 2(디지털)   0.5%  2022.05.18  2022.07.21
#
# [500 rows x 6 columns]

# %%
df_target = df_week[df_week['주']=='2022.07.21']
df_target
# Out:
#     순위 순위증감                  영화제목  예매점유율         개봉일           주
# 0   1위  new            미니언즈2(디지털)  25.7%  2022.07.20  2022.07.21
# 1   2위   -           탑건: 매버릭(디지털)  20.6%  2022.06.22  2022.07.21
# 2   3위  new          외계＋인 1부(디지털)  20.1%  2022.07.20  2022.07.21
# 3   4위   ▼3           헤어질 결심(디지털)  18.9%  2022.06.29  2022.07.21
# 4   5위   ▼1              엘비스(디지털)   4.3%  2022.07.13  2022.07.21
# 5   6위   ▼3  더 킬러: 죽어도 되는 아이(디지털)   3.0%  2022.07.13  2022.07.21
# 6   7위   ▼2      토르: 러브 앤 썬더(디지털)   2.6%  2022.07.06  2022.07.21
# 7   8위   ▼1           로스트 도터(디지털)   2.2%  2022.07.14  2022.07.21
# 8   9위   ▼3  명탐정 코난: 할로윈의 신부(디지털)   1.9%  2022.10.28  2022.07.21
# 9  10위   ▼1           범죄도시 2(디지털)   0.5%  2022.05.18  2022.07.21

# %%
custom_dict = {'1위': 0, '2위': 1, '3위': 2, '4위': 3, '5위': 4, '6위': 5, '7위': 6, '8위': 7, '9위': 8, '10위': 9}
df_target['rank'] = df_target['순위'].map(custom_dict)
df_target.sort_values(by=['개봉일', 'rank'], ascending=[True, False], inplace=True)
# df_target.reset_index(drop=True, inplace=True)
df_target.drop('rank', axis=1, inplace=True)
df_target
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4792\750493923.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_target['rank'] = df_target['순위'].map(custom_dict)
# C:\Users\User\AppData\Local\Temp\ipykernel_4792\750493923.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_target.sort_values(by=['개봉일', 'rank'], ascending=[True, False], inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_4792\750493923.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# # 이 문제 이상한 것 같습니다.
# - grading.py에서 "명탐정 코난: 할로윈의 신부(디지털)"의 개봉일 확인부탁드립니다.|

# %%
check_01(df_target)
# Out:
# 오답입니다. 다시 한번 확인해주세요.
# 현재 누적 점수: 70 / 100

# %% [markdown]
# ## 2단계: Web Crawling & DataFrame 만들기 02
# ***

# %% [markdown]
# ### 문제 2) Web Crawling: 더 많은 Data 가져오기 (40점)
# - 1단계의 문제1에서 DataFrame을 만들었던 과정을 참고하여 아래 조건에 맞게 DataFrame(df_target)을 만드세요.
# <br></br>
#     - 기준 주(weeks): "2021년 8월 12일 (목) ~ 8월 15일 (일)" 부터 "2022년 7월 21일(목) ~ 7월 24일 (일)" 까지 50주(weeks)
# <br></br>
#     - 조건1: 1단계 문제1을 참고하여 '기준 주(weeks)'에 해당하는 50주(weeks)의 [영화 Top10]의 표(Table) Data를 Crawling 하세요.
#         - 앞서 언급하였다시피 해당 Page는 Post 방식 입니다.
#         - 해당 표(Table)안의 Data 중 string Data만 가져오면 됩니다(Image Data는 필요 없습니다.)
# <br></br>
#     - 조건2: 결과 DataFrame의 Column은 ['순위', '순위증감', '영화제목', '예매점유율', '개봉일', '주'] 입니다.
#         - 아래 columns로 할당된 변수를 참고하세요.
# <br></br>
#     - 조건3: 1단계 문제 1의 조건3, 조건4, 조건5 이상 세 개의 조건은 이 문제에 동일하게 적용됩니다.
# <br></br>
#     - 조건4: '개봉일' Column(열)의 Data에서 "."를 모두 제거하세요.
#         - 예시: 2022.07.22 -> 20220722
# <br></br>
#     - 조건5: '주' Column(열)의 Data는 해당 Data 기준 주(week)의 시작일입니다.
# <br></br>
#         - 예시: 2021년 8월 12일 (목) ~ 8월 15일 (일) 주(week)
# <br></br>
#         <img src="images/07-2-1-001.png" style="margin:auto" width=500/>
# <br></br>
#     - 조건6: 결과 DataFrame은 '주' Column(열) Data를 기준으로 오름차순으로 정렬하고, 동일한 '주' Column(열) Data에 대해서는 '순위'를 기준으로 오름차순으로 정렬해주세요. 이후 Index는 초기화 해 주세요.
# <br></br>
#     - 조건7: 'df_target' 변수에 결과 DataFrame을 할당하세요.
# <br></br>
# <br></br>
#     - hint1: pandas 기능 중 일정기간 혹은 횟수 동안 특정 요일의 날짜들을 반환하는 함수가 있습니다.
# <br></br>
#     - hint2: 특정 시점 이전에는 crawling 위치가 변할 수 있습니다. Crawling시 Error가 발생했다면 한 번 확인해보세요.
# <br></br>
# <br></br>
#     - 주의사항: 빠른 시간 내에 너무 자주 Data를 Crawling할 경우 Error 발생할 수 있습니다.
#         - 반복문을 통해 Crawling을 할 때 time.sleep 등의 방법을 이용하여 한번의 crawling 당 최소 0.1초 이상의 간격 두는 것을 추천합니다.
# <br></br>
# <br></br>
# - 완료 후 결과 DataFrame 변수(df_target)를 check_02 함수에 입력하여 채점하세요.

# %%
df_target = df_week
df_target['주'] = df_target['주'].replace('\.', '', regex=True)
df_target['개봉일'] = df_target['개봉일'].replace('\.', '', regex=True)
df_target
# Out:
#       순위 순위증감                       영화제목  예매점유율       개봉일         주   예매율
# 0     1위  new                  싱크홀(2021)  66.1%  20210811  20210812  66.1
# 1     2위   ▼1                  모가디슈(디지털)  20.1%  20220907  20210812  20.1
# 2     3위   ▼1               보스 베이비2(디지털)   5.2%  20210721  20210812   5.2
# 3     4위  new                 프리 가이(디지털)   2.7%  20210811  20210812   2.7
# 4     5위   ▼1  극장판 도라에몽: 진구의 신공룡(디지털 더빙)   1.5%  20210805  20210812   1.5
# ..   ...  ...                        ...    ...       ...       ...   ...
# 495   6위   ▼3       더 킬러: 죽어도 되는 아이(디지털)   3.0%  20220713  20220721   3.0
# 496   7위   ▼2           토르: 러브 앤 썬더(디지털)   2.6%  20220706  20220721   2.6
# 497   8위   ▼1                로스트 도터(디지털)   2.2%  20220714  20220721   2.2
# 498   9위   ▼3       명탐정 코난: 할로윈의 신부(디지털)   1.9%  20221028  20220721   1.9
# 499  10위   ▼1                범죄도시 2(디지털)   0.5%  20220518  20220721   0.5
#
# [500 rows x 7 columns]

# %%
custom_dict = {'1위':0, '2위':1, '3위':2, '4위':3, '5위':4, '6위':5, '7위':6, '8위':7, '9위':8, '10위':9}
df_target['rank'] = df_target['순위'].map(custom_dict)

df_target.sort_values(by=['주', 'rank'], ascending=[True, True], inplace= True)
df_target.reset_index(drop=True, inplace=True)
df_target.drop('rank', axis=1, inplace=True)
df_target
# Out:
#       순위 순위증감                       영화제목  예매점유율       개봉일         주   예매율
# 0     1위  new                  싱크홀(2021)  66.1%  20210811  20210812  66.1
# 1     2위   ▼1                  모가디슈(디지털)  20.1%  20220907  20210812  20.1
# 2     3위   ▼1               보스 베이비2(디지털)   5.2%  20210721  20210812   5.2
# 3     4위  new                 프리 가이(디지털)   2.7%  20210811  20210812   2.7
# 4     5위   ▼1  극장판 도라에몽: 진구의 신공룡(디지털 더빙)   1.5%  20210805  20210812   1.5
# ..   ...  ...                        ...    ...       ...       ...   ...
# 495   6위   ▼3       더 킬러: 죽어도 되는 아이(디지털)   3.0%  20220713  20220721   3.0
# 496   7위   ▼2           토르: 러브 앤 썬더(디지털)   2.6%  20220706  20220721   2.6
# 497   8위   ▼1                로스트 도터(디지털)   2.2%  20220714  20220721   2.2
# 498   9위   ▼3       명탐정 코난: 할로윈의 신부(디지털)   1.9%  20221028  20220721   1.9
# 499  10위   ▼1                범죄도시 2(디지털)   0.5%  20220518  20220721   0.5
#
# [500 rows x 7 columns]

# %%
check_02(df_target)
# Out:
# 정답입니다! 30점 누적 되었습니다!
# 현재 누적 점수: 50 / 100

# %% [markdown]
# ## 3단계: 원하는 정보 얻기
# ***

# %% [markdown]
# ### 문제 3-1) 원하는 정보 얻기 01 (20점)
# - 2단계의 DataFrame(df_target)을 이용하여 아래의 조건에 맞는 정보를 구하세요.
# <br></br>
#     - 2단계의 DataFrame(df_target)에서 오랫동안(6번 이상 == 6주 이상) 예매점유율 Top10에 올랐던 영화를 찾아보고자 합니다.
# <br></br>
# <br></br>
#     - 조건1: 6주(6번) 이상 Top10에 올랐던 영화 제목을 구하세요.
# <br></br>
#     - 조건2: '빈도' Column(열)을 만들어 해당 Column(열)에 몇 번(몇 주) Top10에 올랐는지 입력해 주세요.
# <br></br>
#     - 조건3: Index는 '영화제목'으로 해주세요.
# <br></br>
#     - 조건4: '빈도'를 기준으로 내림차순으로 정렬하고, 동일한 '빈도'일 경우 '영화제목'을 기준으로 오름차순으로 정렬해 주세요.
# <br></br>
#         - 예시: 다음 예시는 '빈도' 기준 오름차순, '빈도'가 동일할경우 '영화제목'으로 내림차순한 가상의 내용입니다.
# <br></br>
#         <img src="images/07-3-1-001.png" style="margin:auto" width=200/>
# <br></br>
#     - 조건4: 'df_result' 변수에 결과 DataFrame을 할당하세요.
# <br></br>
# <br></br>
# - 완료 후 결과 dataframe 변수(df_result)를 check_03_01 함수에 입력하여 채점하세요.

# %%
tmp_pt = pd.DataFrame(pd.pivot_table(data=df_target, index='영화제목', values='주', aggfunc=len))
tmp_pt.reset_index(inplace=True)
tmp_pt = tmp_pt[tmp_pt["주"] >= 6]
tmp_pt.rename(columns={'주': '빈도'}, inplace=True)

tmp_pt.sort_values(by=["빈도", "영화제목"], inplace=True, ascending=[False, True])
tmp_pt.set_index('영화제목', inplace=True)
tmp_pt
# Out:
#                                      빈도
# 영화제목
# 스파이더맨: 노 웨이 홈(디지털)                   12
# 범죄도시 2(디지털)                          11
# 듄(디지털)                                8
# 싱크홀(2021)                             8
# 극장판 주술회전 0(디지털)                       7
# 모가디슈(디지털)                             7
# 보이스(2021)                             7
# 신비한 동물들과 덤블도어의 비밀(디지털)                7
# 씽2게더(디지털)                             7
# 007 노 타임 투 다이(디지털)                    6
# 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미(디지털)   6
# 기적(디지털)                               6
# 닥터 스트레인지: 대혼돈의 멀티버스(디지털)              6
# 엔칸토: 마법의 세계(디지털)                      6
# 쥬라기 월드: 도미니언(디지털)                     6
# 탑건: 매버릭(디지털)                          6
# 특송(디지털)                               6

# %%
check_03_01(tmp_pt)
# Out:
# 정답입니다! 20점 누적 되었습니다!
# 현재 누적 점수: 50 / 100

# %% [markdown]
# ### 문제 3-2) 원하는 정보 얻기 02 (20점)
# - 2단계의 DataFrame(df_target)을 이용하여 아래의 조건에 맞는 정보를 구하세요.
# <br></br>
#     - 2단계의 DataFrame(df_target)에서 Top10에 오른 기간 동안 예매점유율의 평균을 구해보고자 합니다.
# <br></br>
# <br></br>
#     - 조건1: 각 '영화제목' 당 '예매점유율'의 평균을 구하세요
# <br></br>
#     - 조건2: '예매점유율' Column(열)에 조건1에서 구한 '예매점유율'의 평균을 입력해 주세요.
#         - '예매점유율' Column(열) Data는 소숫점 세 자리수에서 반올림하여 두자리수까지 표기한 후 '%'를 붙여주세요.
# <br></br>
#         - 예시
# <br></br>
#         <img src="images/07-3-2-001.png" style="margin:auto" width=200/>
# <br></br>
#     - 조건3: Index는 '영화제목'으로 해주세요.
# <br></br>
#     - 조건4: '예매점유율'를 기준으로 내림차순으로 정렬하고, 동일한 '예매점유율'일 경우 '영화제목'을 기준으로 오름차순으로 정렬해 주세요.
#         - 문제 3-1의 조건4 예시를 참고해주세요.
# <br></br>
#     - 조건4: 'df_result' 변수에 결과 DataFrame을 할당하세요.
# <br></br>
# <br></br>
# - 완료 후 결과 dataframe 변수(df_result)를 check_03_02 함수에 입력하여 채점하세요.

# %%
df_target.head()
# Out:
#    순위 순위증감                       영화제목  예매점유율       개봉일         주   예매율
# 0  1위  new                  싱크홀(2021)  66.1%  20210811  20210812  66.1
# 1  2위   ▼1                  모가디슈(디지털)  20.1%  20220907  20210812  20.1
# 2  3위   ▼1               보스 베이비2(디지털)   5.2%  20210721  20210812   5.2
# 3  4위  new                 프리 가이(디지털)   2.7%  20210811  20210812   2.7
# 4  5위   ▼1  극장판 도라에몽: 진구의 신공룡(디지털 더빙)   1.5%  20210805  20210812   1.5

# %%
temp = df_target

# %%
df_target = temp

# %%
df_target['예매율'] = 0
df_target
# Out:
#       순위 순위증감                       영화제목  예매점유율       개봉일         주  예매율
# 0     1위  new                  싱크홀(2021)  66.1%  20210811  20210812    0
# 1     2위   ▼1                  모가디슈(디지털)  20.1%  20220907  20210812    0
# 2     3위   ▼1               보스 베이비2(디지털)   5.2%  20210721  20210812    0
# 3     4위  new                 프리 가이(디지털)   2.7%  20210811  20210812    0
# 4     5위   ▼1  극장판 도라에몽: 진구의 신공룡(디지털 더빙)   1.5%  20210805  20210812    0
# ..   ...  ...                        ...    ...       ...       ...  ...
# 495   6위   ▼3       더 킬러: 죽어도 되는 아이(디지털)   3.0%  20220713  20220721    0
# 496   7위   ▼2           토르: 러브 앤 썬더(디지털)   2.6%  20220706  20220721    0
# 497   8위   ▼1                로스트 도터(디지털)   2.2%  20220714  20220721    0
# 498   9위   ▼3       명탐정 코난: 할로윈의 신부(디지털)   1.9%  20221028  20220721    0
# 499  10위   ▼1                범죄도시 2(디지털)   0.5%  20220518  20220721    0
#
# [500 rows x 7 columns]

# %%
df_target['예매율'] = 0

for idx, row in df_target.iterrows():
    df_target.loc[idx, '예매율'] = float(row['예매점유율'][:-1])
    
tmp_pt = pd.pivot_table(data=df_target, index='영화제목', values='예매율', aggfunc=np.mean)
df_result = pd.DataFrame(tmp_pt)
df_result.reset_index(inplace=True)
df_result.sort_values(by="예매율", ascending=False, inplace=True)

df_result['예매점유율'] = df_result['예매율'].apply(lambda x: '{:.2f}'.format(round(x, 2)))
df_result['예매점유율'] = df_result['예매점유율'].astype('str') + "%"
df_result.drop(['영화제목', '예매율'], axis=1, inplace=True)
df_result
# Out:
#       예매점유율
# 82   38.70%
# 182  30.57%
# 115  30.56%
# 125  30.43%
# 81   28.35%
# ..      ...
# 91    0.25%
# 166   0.20%
# 156   0.10%
# 29    0.10%
# 154   0.10%
#
# [186 rows x 1 columns]

# %%
check_03_02(df_result)
# Out:
# 정답입니다! 20점 누적 되었습니다!
# 현재 누적 점수: 70 / 100

# %% [markdown]
# ***
#
# ### 🎊 문제가 끝났습니다. 제출양식과 일정에 맞춰 제출해주시기를 바랍니다!
#
# ### 제출양식
# - 이 파일은 EDA TEST 7회차 노트북입니다. 따라서 제출시 파일명은 아래와 같습니다.
# - [DS]edalvtest_07_yourname.ipynb
#
# ***

# %% [markdown]
# # 문의사항 및 의견이 있는 경우 작성해주세요.

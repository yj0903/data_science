# %% [markdown]
# <div align="center">
#     <img src="images/zb-logo.png" alt="제로베이스" width="100%">
#     <br>
#     <a href="https://zerobaseschool.notion.site/DS-EDA-Lv-Test-b7d5e895c7cd4dda813c8fe2f2c23f79"><img src="images/openinnotion_logo.png" alt="EDA Lv Test Doc" width="12%"></a>
#
# 이 Jupyter Notebook 파일은 <a href="https://zero-base.co.kr/category_data_camp/school_DS">제로베이스</a>에서 제공하는 **EDA Level Test** 문제입니다.<br>
# 지금까지 공부하신 내용으로 데이터 분석에 대해 좀 더 연습할 수 있는 시간이 되셨으면 좋겠습니다.🙂<br>
# **EDA Level Test**에 대한 안내 사항은 상단 **Open in ZeroBase Notion** 로고를 클릭하여 확인해주세요!<br>
# 반드시 시작 전에 내용을 숙지해주시기를 바랍니다!<br>
# </div>
#
# ***

# %% [markdown]
# <h1 style="background-color:#9F81F7;color:#D8D8D8;font-weight:bold;display:inline-block;padding: 5px">EDA Level Test 07 ⭐️</h1>
#
# | Week | Data Analysis | Difficulty | This Notebook |
# |------|---------------|------------|-------|
# | 1    | 서울시 인구 데이터 | ⭐️ ||
# | 2    | 화장품 성분 데이터 | ⭐️⭐️⭐️ ||
# | 3    | 올림픽 데이터 | ⭐️⭐️ ||
# | 4    | 국가별 인터넷 사용률 데이터 |⭐️⭐️ ||
# | 5    | 전국 박물관/미술관 정보 표준 데이터 | ⭐️⭐️⭐️ ||
# | 6    | 서울시 흡연율 통계 데이터 | ⭐️⭐️ ||
# | 7    | 웹크롤링 | ⭐️ |👈|
# | 8    | 서울시 지하철 호선별 역별 유/무임 승하차 인원 정보 데이터 | ⭐️⭐️ ||
# | 9    | 서울시 교통사고 현황 (사고유형별) 통계 데이터 | ⭐️⭐️ ||
# | 10   | 서울시 교통사고 현황 (사고유형별) 통계 + 서울시 차량통행속도 (구별/월별) 통계 + 서울시 인구밀도 (구별) 통계 | ⭐️⭐️⭐️ ||

# %% [markdown]
# ## 문제 소개 및 데이터 준비 단계
#
# <div style="border: 1px solid black; padding: 10px;">
#
# - 총 3단계 데이터 분석 상황 제시
# <br></br>
#     - 1단계: Web Crawling & DataFrame 만들기 01
#     - 2단계: Web Crawling & DataFrame 만들기 02
#     - 3단계: 원하는 정보 얻기
#     - 총점 100점
#
# ### Data 원본 출처
#
# ### Target Data(Web Page): 인터파크 영화 예매율 주간순위
# - Source: [인터파크 영화 랭킹리포트](http://movie.interpark.com/Community/Movie/Ranking/Ranking_Report.asp)
# - 하기 Image의 [영화 Top 10]이 Target Data 입니다.
# <br></br>
# <img src="images/00-001.png" style="margin:auto" width=600/>
# <br></br>
# ##### 참고사항
# - 해당 Web Page는 **Post** 방식으로 이루어진 Web Page입니다.
# - Selenium, request.post() 등 어떤 방식으로 Crawling해도 상관 없습니다.
#     - 단, 실행 환경의 차이를 감안하여 추후 제공될 정답은 request.post() 방식으로 제공합니다.
# - 해당 Web Page의 예매율 주간순위는 매 주 목요일부터 일요일까지의 관람일을 기준으로 집계되었습니다.
# <br></br>
# - 문제에 hint가 있을 경우, 해당 hint를 이용하지 않으셔도 무방합니다.
#
# ##### 주의사항
# - 해당 문제는 웹크롤링을 이용하는 문제입니다.
# - 때문에, 웹페이지 구조와 데이터가 시간이 지남에 따라 변화할 수 있습니다.
# - 이러한 점을 감안하시어, 문제에 대응하시기를 바랍니다 🙂
#
# </div>

# %% [markdown]
# # 3. 문제

# %% [markdown]
# ## 1단계: Web Crawling & DataFrame 만들기 01
# ***

# %% [markdown]
# ### 문제 1) Web Crawling: Data 가져오기 (40점)
# - 아래 Link를 참고하여 해당 Page의 Data를 Crawling하고, 아래 조건에 맞게 DataFrame(df_week)을 만드세요.
# <br></br>
#     - Link: [인터파크 영화 랭킹리포트](http://movie.interpark.com/Community/Movie/Ranking/Ranking_Report.asp)
# <br></br>
#     - 기준 주(week): 2022년 7월 21일(목) ~ 7월 24일 (일) 기준
# <br></br>
#     - Target Data: 영화 Top10의 1위 ~ 10위에 해당하는 영화의 순위 / 순위증감 / 영화 제목 / 예매점유율 / 개봉일
# <br></br>
#     - 조건1: 상기 Link의 '기준 주(week)'에 해당하는 Web Page의 [영화 Top10]의 표(Table) Data를 Crawling 하세요.
#         - 앞서 언급하였다시피 해당 Page는 Post 방식 입니다.
#         - 해당 표(Table)안의 Data 중 string Data만 가져오면 됩니다(Image Data는 필요 없습니다.)
# <br></br>
#     - 조건2: 결과 DataFrame의 Column은 ['순위', '순위증감', '영화제목', '예매점유율', '개봉일'] 입니다.
#         - 아래 columns로 할당된 변수를 참고하세요.
# <br></br>
#     - 조건3: 상기 Web Page에서 '(▲1)', '(▼2)', '( - )' 로 표기되어 있는 '순위증감'은 괄호('(', ')')를 없애고 입력하여주세요.
# <br></br>
#     - 조건4: 결과 DataFrame 내의 모든 Data는 해당 Data 앞뒤로 띄어쓰기 등 공백이 없어야 합니다.
# <br></br>
#     - 조건5: 상기 Web Page에서 'new'(image)로 표기되어 있는 '순위증감'은 'new'(string)로 입력하여 주세요.
# <br></br>
#         - 조건 1~5를 만족했다면, 그 결과는 아래 Image와 같습니다.
# <br></br>
#         <img src="images/07-1-1-002.png" style="margin:auto" width=500/>
# <br></br>
#     - 조건6: 결과 DataFrame은 '개봉일' 기준으로 오름차순으로 정렬하고, 동일한 '개봉일' Data가 있다면 해당 Data에 대해서는 '순위'를 기준으로 내림차순 하여 정렬해주세요. Index는 조건4의 예시 그대로 1위가 0, 2위가 1, ..., 10위가 9 입니다.
# <br></br>
#         - 예시: 'B'기준 오름차순 정렬, 'B'의 Data가 같은 경우 'A'의 내림차순으로 정렬
# <br></br>
#         <img src="images/07-1-1-003.png" style="margin:auto" width=300/>
# <br></br>
#     - 조건7: 'df_week' 변수에 결과 DataFrame을 할당하세요.
# <br></br>
# <br></br>
#     - 주의사항: 빠른 시간 내에 너무 자주 Data를 Crawling할 경우 Error 발생할 수 있습니다.
# <br></br>
# <br></br>
# - 완료 후 결과 DataFrame 변수(df_week)를 check_01 함수에 입력하여 채점하세요.

# %%
# 채점을 위한 코드입니다. 반드시 실행해주세요.
from grading import *

columns = ['순위', '순위증감', '영화제목', '예매점유율', '개봉일']

# %%
import pandas as pd
import numpy as np
import requests
import re
import time
from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup

# %%
url = "http://movie.interpark.com/Community/Movie/Ranking/Ranking_Report.asp"
driver = webdriver.Chrome(executable_path="./driver/chromedriver")
driver.get(url)
# Out:
# /var/folders/vv/y6j7wgsn1t1dxty1kfg6bcbm0000gn/T/ipykernel_21853/2728624288.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="./driver/chromedriver")
# Error getting version of chromedriver 115. Retrying with chromedriver 114 (attempt 1/5)

# %%
driver.page_source

req = driver.page_source
soup = BeautifulSoup(req, "html.parser")

# %%
soup
# Out:
# <html><head>
# <title>인터파크 영화</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="영화" name="Subject"/>
# <meta content="영화예매 - 인터파크" name="Title"/>
# <meta content="인터파크에서 영화예매하면 색다른 혜택들이 쏟아진다!" name="Description"/>
# <meta content="인터파크, 티켓, 영화, 영화예매" name="Keywords"/>
# <meta content="영화" name="Classification"/>
# <meta content="no" http-equiv="imagetoolbar"/>
# <link href="https://mmovie.interpark.com/OneStop/Movie/Booking" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="//openimage.interpark.com/UI/favicon/ticket_favicon.ico" rel="shortcut icon"/>
# <link href="//ticketimage.interpark.com/TicketImage/uidev/movie/styles/pages/common/import_base.css" rel="stylesheet" type="text/css"/>
# <link href="//ticketimage.interpark.com/TicketImage/uidev/movie/styles/pages/common/common.css" rel="stylesheet" type="text/css"/>
# <link href="//ticketimage.interpark.com/TicketImage/uidev/movie/styles/pages/common/webzine.css" rel="stylesheet" type="text/css"/>
# <!-- 극장정보 페이지에서만 사용 (200309) -->
# <!--<link type="text/css" rel="stylesheet" href="//ticketimage.interpark.com/TicketImage/uidev/movie/styles/pages/common/theater_201008.css" >-->
# <link href="//ticketimage.interpark.com/TicketImage/uidev/movie/styles/common/head.css?v=20230516" rel="stylesheet" type="text/css"/>
# <!--	<link type="text/css" rel="stylesheet" href="//ticketimage.interpark.com/TicketImage/uidev/movie/styles/common/header.css">-->
# <link href="//ticketimage.interpark.com/TicketImage/uidev/movie/styles/common/head_old.css" rel="stylesheet" type="text/css"/>
# <!-- 지마켓 스크립트 추가(190114) -->
# <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-4SKTL7E8Q8&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script async="" src="https://js.appboycdn.com/web-sdk/3.2/appboy.min.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-5QCJFLB"></script><script async="" src="https://connect.facebook.net/signals/config/929060091512589?v=2.9.116&amp;r=stable"></script><script async="" src="https://connect.facebook.net/signals/config/135611513637810?v=2.9.116&amp;r=stable"></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script src="//script.gmarket.co.kr/js/header/vertical/HeaderSimple.js" type="text/javascript"></script>
# <script src="/include/interpark_pcid.js" type="text/javascript"> </script>
# <script src="/Lib/js/Navigation.js" type="text/javascript"> </script>
# <script src="/Include/js/select.js?v=55" type="text/javascript"> </script>
# <script src="/Movie_Lib/JS/Embed.js" type="text/javascript"> </script>
# <script src="/movie/Lib/Js/prototype.js" type="text/javascript"></script>
# <script src="/movie/Lib/Js/Base64.js" type="text/javascript"></script>
# <!-- 쇼핑바 시작 -->
# <script src="/Lib/js/MainShoppingBar.js" type="text/javascript"> </script>
# <script src="/Lib/js/jquery-1.8.0.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# 		jQuery.noConflict();
# 		var head$ = jQuery;
# 	</script>
# <script src="http://ticketimage.interpark.com/TicketImage/2015/20150521_movie/js/header_20150518_old.js" type="text/javascript"></script>
# <!-- //20150522 kkh 영화 GNB 끝 -->
# <script language="javascript" src="//accounts.interpark.com/resources/js/interpark.accounts.js"></script>
# <link href="https://use.fontawesome.com/7f85a56ba4.css" rel="stylesheet"/><style id="ab-css-definitions-3-2-0">.ab-pause-scrolling,body.ab-pause-scrolling,html.ab-pause-scrolling{overflow:hidden;touch-action:none}.ab-centering-div,.ab-iam-root.v3{position:fixed;top:0;right:0;bottom:0;left:0;pointer-events:none;z-index:1050;-webkit-tap-highlight-color:transparent}.ab-centering-div:focus,.ab-iam-root.v3:focus{outline:0}.ab-centering-div.ab-effect-fullscreen,.ab-centering-div.ab-effect-html,.ab-centering-div.ab-effect-modal,.ab-iam-root.v3.ab-effect-fullscreen,.ab-iam-root.v3.ab-effect-html,.ab-iam-root.v3.ab-effect-modal{opacity:0}.ab-centering-div.ab-effect-fullscreen.ab-show,.ab-centering-div.ab-effect-html.ab-show,.ab-centering-div.ab-effect-modal.ab-show,.ab-iam-root.v3.ab-effect-fullscreen.ab-show,.ab-iam-root.v3.ab-effect-html.ab-show,.ab-iam-root.v3.ab-effect-modal.ab-show{opacity:1}.ab-centering-div.ab-effect-fullscreen.ab-show.ab-animate-in,.ab-centering-div.ab-effect-html.ab-show.ab-animate-in,.ab-centering-div.ab-effect-modal.ab-show.ab-animate-in,.ab-iam-root.v3.ab-effect-fullscreen.ab-show.ab-animate-in,.ab-iam-root.v3.ab-effect-html.ab-show.ab-animate-in,.ab-iam-root.v3.ab-effect-modal.ab-show.ab-animate-in{-webkit-transition:opacity .5s;-moz-transition:opacity .5s;-o-transition:opacity .5s;transition:opacity .5s}.ab-centering-div.ab-effect-fullscreen.ab-hide,.ab-centering-div.ab-effect-html.ab-hide,.ab-centering-div.ab-effect-modal.ab-hide,.ab-iam-root.v3.ab-effect-fullscreen.ab-hide,.ab-iam-root.v3.ab-effect-html.ab-hide,.ab-iam-root.v3.ab-effect-modal.ab-hide{opacity:0}.ab-centering-div.ab-effect-fullscreen.ab-hide.ab-animate-out,.ab-centering-div.ab-effect-html.ab-hide.ab-animate-out,.ab-centering-div.ab-effect-modal.ab-hide.ab-animate-out,.ab-iam-root.v3.ab-effect-fullscreen.ab-hide.ab-animate-out,.ab-iam-root.v3.ab-effect-html.ab-hide.ab-animate-out,.ab-iam-root.v3.ab-effect-modal.ab-hide.ab-animate-out{-webkit-transition:opacity .5s;-moz-transition:opacity .5s;-o-transition:opacity .5s;transition:opacity .5s}.ab-centering-div.ab-effect-slide .ab-in-app-message,.ab-iam-root.v3.ab-effect-slide .ab-in-app-message{-webkit-transform:translateX(535px);-moz-transform:translateX(535px);-ms-transform:translateX(535px);transform:translateX(535px)}.ab-centering-div.ab-effect-slide.ab-show .ab-in-app-message,.ab-iam-root.v3.ab-effect-slide.ab-show .ab-in-app-message{-webkit-transform:translateX(0);-moz-transform:translateX(0);-ms-transform:translateX(0);transform:translateX(0)}.ab-centering-div.ab-effect-slide.ab-show.ab-animate-in .ab-in-app-message,.ab-iam-root.v3.ab-effect-slide.ab-show.ab-animate-in .ab-in-app-message{-webkit-transition:transform .5s ease-in-out;-moz-transition:transform .5s ease-in-out;-o-transition:transform .5s ease-in-out;transition:transform .5s ease-in-out}.ab-centering-div.ab-effect-slide.ab-hide .ab-in-app-message,.ab-iam-root.v3.ab-effect-slide.ab-hide .ab-in-app-message{-webkit-transform:translateX(535px);-moz-transform:translateX(535px);-ms-transform:translateX(535px);transform:translateX(535px)}.ab-centering-div.ab-effect-slide.ab-hide .ab-in-app-message.ab-swiped-left,.ab-iam-root.v3.ab-effect-slide.ab-hide .ab-in-app-message.ab-swiped-left{-webkit-transform:translateX(-535px);-moz-transform:translateX(-535px);-ms-transform:translateX(-535px);transform:translateX(-535px)}.ab-centering-div.ab-effect-slide.ab-hide .ab-in-app-message.ab-swiped-up,.ab-iam-root.v3.ab-effect-slide.ab-hide .ab-in-app-message.ab-swiped-up{-webkit-transform:translateY(-535px);-moz-transform:translateY(-535px);-ms-transform:translateY(-535px);transform:translateY(-535px)}.ab-centering-div.ab-effect-slide.ab-hide .ab-in-app-message.ab-swiped-down,.ab-iam-root.v3.ab-effect-slide.ab-hide .ab-in-app-message.ab-swiped-down{-webkit-transform:translateY(535px);-moz-transform:translateY(535px);-ms-transform:translateY(535px);transform:translateY(535px)}.ab-centering-div.ab-effect-slide.ab-hide.ab-animate-out .ab-in-app-m ...
# <body bgcolor="#FFFFFF" text="#000000">
# <!-- 20190104 지마켓 추가 -->
# <div id="GmarketHeaderDiv"></div>
# <script type="text/javascript">
#     // 지마켓 스크립트 추가
#     var BizGWhere = ''
#
#     if (BizGWhere == "Gmarket")
# 	{
# 		GmarketHeader.Display('GmarketHeaderDiv');
# 	}
# </script>
# <!-- S: 이지웰 헤더 삽입 -->
# <!-- E: 이지웰 헤더 삽입 -->
# <!-- 20150522 kkh 영화 gnb시작 -->
# <div class="beforeTChu" id="NewrightWing" style="right: -111px; height: 1951px;">
# <a class="OpenWing" href="javascript:;" onclick="wingToggle(head$(this))"> </a>
# <!-- 로그인 전 -->
# <div class="login">
# <img alt="" src="http://ticketimage.interpark.com/TicketImage/2015/20150429_main/img/header/Login.png"/>
# <p class="txt">반갑습니다.<br/>로그인해주세요</p>
# <a class="btn" href="https://ticket.interpark.com/Gate/TPLogin.asp?CPage=B&amp;MN=Y&amp;tid1=main_gnb&amp;tid2=right_top&amp;tid3=login&amp;tid4=login">로그인</a>
# </div>
# <div class="wingContent" style="height: 1807px;">
# <a href="http://ipointmall.interpark.com/ipoint/MyIpointDtl.do?_method=initial&amp;wid1=cus&amp;wid2=ipoint">아이포인트</a>
# <div class="on">
# <a class="list" href="#">My 티켓</a>
# <div>
# <a href="https://movie.interpark.com/Movie/Gate/TPLogin.asp?CPage=C&amp;vid1=main_gnb&amp;vid2=right_top&amp;vid3=reservations&amp;vid4=reservations">예매/취소내역<b>0</b></a>
# <a href="http://movie.interpark.com/Movie/Voucher/IMGift_Sel.asp">영화예매권<b>0</b></a>
# <a href="http://movie.interpark.com/Movie/Coupon/c_u_i.asp">영화할인쿠폰<b>0</b></a>
# </div>
# </div>
# <div class="recentBox">
# <a class="show line" href="javascript:;">최근 본 영화 <em class="on">(0)</em></a>
# <!--<div class="recent none">최근 본 영화가<br/>없습니다</div>-->
# </div>
# </div>
# <!-- //로그인 전 -->
# </div>
# <!-- //20150522 kkh 영화 gnb끝 -->
# <!-- S: 20121009 GateWayBar -->
# <script type="text/javascript">
# <!--
# 	function fnGateWayBar(s) {
# 		if(s=="on")
# 			document.getElementById("layer_categoryAll").style.display="";
# 		else
# 			document.getElementById("layer_categoryAll").style.display="none";
# 	}
# 	function fnMyPage(s) {
# 		if(s=="on")
# 			document.getElementById("dlmypgsub").style.display="";
# 		else
# 			document.getElementById("dlmypgsub").style.display="none";
# 	}
# //-->
# </script>
# <div class="gnbArea_ui" id="gateway_warp">
# <div id="gateway_con">
# <div class="gnbArea_top">
# <!-- S: gnbArea_left -->
# <div class="gnbArea_left_ui">
# <ul>
# <li>
# <a class="btn_gnbHome" href="https://www.interpark.com/">홈</a>
# </li>
# <li>
# <a class="btn_gnbTour" href="http://tour.interpark.com/?&amp;tid1=main_gnb&amp;tid2=left_top&amp;tid3=tour&amp;tid4=tour">투어</a>
# </li>
# <li class="btn_gnbTicket">
# <a href="http://ticket.interpark.com/?&amp;tid1=main_gnb&amp;tid2=left_top&amp;tid3=ticket&amp;tid4=ticket">티켓</a>
# </li>
# <li>
# <a class="btn_gnbShopping" href="https://shop.interpark.com/">쇼핑</a>
# </li>
# <li>
# <a class="btn_gnbBook" href="http://book.interpark.com/bookPark/html/book.html?&amp;tid1=main_gnb&amp;tid2=left_top&amp;tid3=book&amp;tid4=book">도서</a>
# </li>
# </ul>
# </div>
# <!-- E: gnbArea_left -->
# <!-- S: gnbArea_right -->
# <div class="gnbArea_right">
# <div id="gnbArea_link">
# <ul>
# <li id="logstatus"><span id="m_join1"><a href="https://movie.interpark.com/Movie/Gate/TPLogin.asp?CPage=M">로그인</a></span></li>
# <li><span id="m_join2"><a href="https://member.interpark.com/signup?join_site_tp=50&amp;join_ipp_id=">회원가입</a></span></li>
# <li><a href="https://movie.interpark.com/Movie/Gate/TPLogin.asp?CPage=C&amp;vid1=main_gnb&amp;vid2=right_top&amp;vid3=reservations&amp;vid4=reservations" id="aReserve" name="aReserve">예매확인/취소</a></li>
# <li "="" class="mypage" onmouseout="fnMyPage('off');" onmouseover="fnMyPage('on');"> <a href="https://movie.interpark.com/Movie/Gate/TPLogin.asp?CPage=MY&amp;type=movie&amp;vid1=main_gnb&amp;vid2=right_top&amp;vid3=myticket&amp;vid4=myticket">마이페이지 <img class="icon_arrow" src="http://ticketimage.interpark.com/TicketImage/main/100506_main/Gateway/gateway_arrow.gif"/></a>
#                             <div class="lay_mypgsub" id="dlmypgsub" style="display: none;">
# <ul>
# <li><a href="https://movie.interpark.com/Movie/Gate/TPLogin.asp?CPage=MY&amp;type=movie&amp;vid1=main_gnb&amp;vid2=right_top&amp;vid3=myticket&amp;vid4=myticket">My티켓</a></li>
# <li><a href="http://movie.interpark.com/Point/MyTicket/MyVoucher.asp?&amp;vid1=main_gnb&amp;vid2=right_top&amp;vid3=layer&amp;vid4=Voucher">영화예매권</a></li>
# <li><a href="http://movie.interpark.com/Point/MyTicket/MyCoupon.asp?rb=Movie&amp;Status=37024&amp;vid1=main_gnb&amp;vid2=right_top&amp;vid3=layer&amp;vid4=moviecoupon">영화할인쿠폰</a></li>
# </ul>
# </div>
# </li>
# <li><a href="http://mobile.interpark.com/#ENT">모바일APP</a></li>
# <li class="last"><a href="http://ticket.interpark.com/HelpDesk/HelpDeskMain.asp?&amp;vid1=main_gnb&amp;vid2=right_top&amp;vid3=help&amp;vid4=help">고객센터</a></li>
# </ul>
# </div>
# </div>
# <!-- E: gnbArea_right -->
# </div>
# <!-- //gnbArea_top -->
# </div>
# </div>
# <!-- E: 20121009 GateWayBar -->
# <!-- s: GNB 영화 -->
# <div id="wrapGNB">
# <div class="gnbTicket">
# <h1 class="interparkMovie_BI">
# <a class="movieBI" href="http://movie.interpark.com/Movie/?vid1=mgnb&amp;vid2=topmn&amp;vid3=movie&amp;vid4=001">영화</a>
# </h1>
# <!-- s: 검색박스 -->
# <div class="search">
# <form autocomplete="off" id="FormTopSearch" name="FormTopSearch" onsubmit="return goSearch(document.FormTopSearch)">
# <input id="hidSchBanners" name="hidSchBanners" type="hidden" value=""/>
# <h2>검색</h2>
# <fieldset>
# <legend>검색폼</legend>
# <div class="box">
# <input class="search_txt" id="txtTopSearch" maxlength="20" name="txtTopSearch" onfocus="initText();" onkeydown="return SetTopSearchTxt();" onmousedown="return SetTopSearchTxt();" style="background-Image: url();" title="검색어 입력" type="text"/>
# <a class="btn_search" href="javascript:" onclick="return goSearch(document.FormTopSearch);"><img alt="검색" src="http://ticketimage.interpark.com/TicketImage/2015/20150429_main/img/header/btn_search.gif"/></a>
# </div>
# <div class="btn" id="scbt">
# <a href="http://www.playdb.co.kr/" target="_blank"><img alt="Play DB" src="http://ticketimage.interpark.com/TicketImage/2015/20150429_main/img/header/btn_playDb.jpg"/></a>
# <a href="http://ticket.interpark.com"><img alt="티켓" src="http://ticketimage.interpark.com/TicketImage/2015/20150521_movie/img/header/btn_ticket.gif"/></a>
# </div>
# </fieldset>
# </form>
# </div>
# <script type="text/javascript">
# 		<!--
# 			var vMovieImgURL = "http://ticketimage.interpark.com";
# 			var vSearch = "";
# 			var vPageCheck =  "";
#
# 		//-->
# 		</script>
# <script src="/Movie/Main4.0/TopSearchNew.js" type="text/javascript"></script>
# <!-- e: 검색박스 -->
# <div class="gnb_Ad2" id="target_gnbbanner">
# <script src="https://addb.interpark.com/RealMedia/ads/adstream_jx.ads/movie.interpark.com/navi/top@x01" type="text/javascript"></script><a href="http://addb.interpark.com/RealMedia/ads/click_lx.ads/movie.interpark.com/navi/top/L28/628692397/x01/interpark_ticket/SNS_0119_23590/SNS_0119_23590.html/6176723547575338366c6f41414a766e" target="_blank">
# <img alt="�명꽣�뚰겕 �곹솕 SNS 諛곕꼫" border="0" src="//ticketimage.interpark.com/Movie/news_image/2201/0119_interpark23590.jpg"/></a>
# </div>
# <!-- e: 우상단 배너 -->
# </div>
# <!-- s: 영화GNB 주메뉴 -->
# <div class="gnbWrap">
# <ul class="gnbBtns">
# <li><a class="btn_allMenu" href="javascript:;" onclick="allMenu()"><!--<img src="http://ticketimage.interpark.com/TicketImage/2015/20150429_main/img/header/blank.png" alt="전체메뉴보기">-->
# <span class="gnbText">전체메뉴보기</span>
# </a></li>
# <li>
# <a class="btn_moveiBooking" href="http://movie.interpark.com/Movie/2.0/Booking.asp?movieblockname=top&amp;movielinkname=booking&amp;vid1=mgnbmn&amp;vid2=mn&amp;vid3=booking&amp;vid4=001"><!-- <img src="http://ticketimage.interpark.com/TicketImage/2015/20150429_main/img/header/blank.png" alt="영화예매"> -->
# <span class="gnbText">영화예매</span>
# </a>
# </li>
# <li>
# <a class="btn_movieNow" href="http://movie.interpark.com/Movie/Goods/open_firm_date.asp?movieblockname=top&amp;movielinkname=open_firm&amp;vid1=mgnbmn&amp;vid2=mn&amp;vid3=open_firm&amp;vid4=001"><!-- <img src="http://ticketimage.interpark.com/TicketImage/2015/20150429_main/img/header/blank.png" alt="현재상영작"> -->
# <span class="gnbText">현재상영작</span>
# </a>
# </li>
# <li>
# <a class="btn_movieNext" href="http://movie.interpark.com/Movie/Goods/comming_firm.asp?movieblockname=top&amp;movielinkname=coming_firm&amp;vid1=mgnbmn&amp;vid2=mn&amp;vid3=coming_firm&amp;vid4=001"><!--<img src="http://ticketimage.interpark.com/TicketImage/2015/20150429_main/img/header/blank.png" alt="개봉예정작">-->
# <span class="gnbText">개봉예정작</span>
# </a>
# </li>
# <!-- 		<li class=""> -->
# <!-- 			<a href="http://movie.interpark.com/Movie/Theater/NTheaterMain.asp?movieblockname=top&movielinkname=theater_ranking&vid1=mgnbmn&vid2=mn&vid3=theater_ranking&vid4=001" class="btn_cinemaInfo"><!-- <img src="http://ticketimage.interpark.com/TicketImage/2015/20150429_main/img/header/blank.png" alt="극장정보"> --> --&gt;
# <!-- 			<span class="gnbText">극장정보</span> -->
# <!-- 			</a> -->
# <!-- 		</li> -->
# <li class="">
# <a class="btn_movieRanking" href="http://movie.interpark.com/Community/Movie/Ranking/index.asp?movieblockname=top&amp;movielinkname=movie_ranking&amp;vid1=mgnbmn&amp;vid2=mn&amp;vid3=movie_ranking&amp;vid4=001"><!-- <img src="http://ticketimage.interpark.com/TicketImage/2015/20150429_main/img/header/blank.png" alt="영화랭킹"> -->
# <span class="gnbText">영화랭킹</span>
# </a>
# </li>
# <li>
# <a class="btn_community" href="http://movie.interpark.com/Community/Movie/Main/main.asp?movieblockname=top&amp;movielinkname=talk_main&amp;vid1=mgnbmn&amp;vid2=mn&amp;vid3=commu&amp;vid4=001"><!-- <img src="http://ticketimage.interpark.com/TicketImage/2015/20150429_main/img/header/blank.png" alt="커뮤니티"> -->
# <span class="gnbText">커뮤니티</span>
# </a>
# </li>
# <li>
# <a class="btn_event" href="http://movie.interpark.com/Community/Movie/Event/index.asp?movieblockname=top&amp;movielinkname=event_main&amp;vid1=mgnbmn&amp;vid2=mn&amp;vid3=event&amp;vid4=001"><!-- <img src="http://ticketimage.interpark.com/TicketImage/2015/20150429_main/img/header/blank.png" alt="시사회/이벤트"> -->
# <span class="gnbText">시사회/이벤트</span>
# </a>
# </li>
# <li>
# <a class="btn_preBooking" href="http://movie.interpark.com/Movie/Voucher/IMGift_Sel.asp?movieblockname=top&amp;movielinkname=imgift_sel&amp;vid1=mgnbmn&amp;vid2=mn&amp;vid3=imgift_sel&amp;vid4=001"><!-- <img src="http://ticketimage.interpark.com/TicketImage/2015/20150429_main/img/header/blank.png" alt="예매권"> -->
# <span class="gnbText">예매권</span>
# </a>
# </li>
# <!-- 		<li> -->
# <!-- 			<a href="http://movie.interpark.com/Movie/Coupon/c_u_i.asp?movieblockname=top&movielinkname=c_u_i&vid1=mgnbmn&vid2=mn&vid3=coupon&vid4=001" class="btn_movieCoupon"><!-- <img src="http://ticketimage.interpark.com/TicketImage/2015/20150429_main/img/header/blank.png" alt="할인쿠폰"> --> --&gt;
# <!-- 			<span class="gnbText">할인쿠폰</span> -->
# <!-- 			</a> -->
# <!-- 		</li> -->
# <li>
# <a class="btn_saveMoney" href="http://movie.interpark.com/Community/Movie/Discount/Discount_Way.asp?movieblockname=top&amp;movielinkname=discount_way&amp;vid1=mgnbmn&amp;vid2=mn&amp;vid3=discount_way&amp;vid4=001"><!-- <img src="http://ticketimage.interpark.com/TicketImage/2015/20150429_main/img/header/blank.png" alt="싸게보는법"> -->
# <span class="gnbText">싸게보는법</span>
# </a>
# </li>
# </ul>
# <div class="gnbSubWrap" id="allMenu"><!-- 전체메뉴 -->
# <div class="gnbSubBody">
# <ul>
# <li><a class="boldAnchor" href="http://movie.interpark.com/Movie/2.0/Booking.asp?movieblockname=top&amp;movielinkname=booking">영화예매</a></li>
# <li><a href="http://movie.interpark.com/Movie/2.0/Booking.asp?Type=T&amp;tid1=booking&amp;tid2=theater">극장먼저</a></li>
# <li><a href="http://movie.interpark.com/Movie/2.0/Booking.asp?Type=M&amp;tid1=booking&amp;tid2=movie">영화먼저</a></li>
# <li><a href="http://movie.interpark.com/Movie/2.0/Booking.asp?Type=D&amp;tid1=booking&amp;tid2=day">날짜먼저</a></li>
# <!-- 				<li><a href="http://movie.interpark.com/Movie/Menupan/FoodMain.asp?tid1=booking&tid2=local">지역할인쿠폰</a></li> -->
# </ul>
# <ul>
# <li><a class="boldAnchor" href="http://movie.interpark.com/Movie/Goods/open_firm_date.asp?movieblockname=top&amp;movielinkname=open_firm">상영작/예정작</a></li>
# <li><a href="http://movie.interpark.com/Movie/Goods/thisweek_firm.asp?movieblockname=goods&amp;movielinkname=thisweek&amp;tid1=goods&amp;tid2=thisweek">금주개봉작</a></li>
# <li><a href="http://movie.interpark.com/Movie/Goods/open_firm_date.asp?tid1=goods&amp;tid2=now">현재상영작</a></li>
# <li><a href="http://movie.interpark.com/Movie/Goods/comming_firm.asp?movieblockname=goods&amp;movielinkname=coming&amp;tid1=goods&amp;tid2=coming">개봉예정작</a></li>
# <li><a href="http://movie.interpark.com/Community/Movie/Paper/Movie_Multi.asp?movieblockname=goods&amp;movielinkname=movie_Multi&amp;tid1=goods&amp;tid2=trailor">예고편</a></li>
# <li><a href="http://movie.interpark.com/Community/Movie/Ranking/index.asp?movieblockname=goods&amp;movielinkname=ranking&amp;tid1=goods&amp;tid2=ranking">영화예매순위</a></li>
# </ul>
# <ul>
# <li><a class="boldAnchor" href="http://movie.interpark.com/Community/Movie/Ranking/index.asp?movieblockname=top&amp;movielinkname=movie_ranking">영화랭킹</a></li>
# <li><a href="http://movie.interpark.com/Community/Movie/Ranking/Movie_Kinds_Ranking.asp?Flag=D&amp;movieblockname=ranking&amp;movielinkname=flagd&amp;tid1=rank&amp;tid2=reserve">예매순위</a></li>
# <li><a href="http://movie.interpark.com/Community/Movie/Ranking/Netizen_Play.asp?movieblockname=ranking&amp;movielinkname=netizen_play&amp;tid1=rank&amp;tid2=rate">네티즌 평점순위</a></li>
# <li><a href="http://movie.interpark.com/Community/Movie/Ranking/Estimate_Ranking.asp?movieblockname=ranking&amp;movielinkname=estimate&amp;tid1=rank&amp;tid2=estimate">흥행예감순위</a></li>
# <li><a href="http://movie.interpark.com/Community/Movie/Ranking/ranking_report.asp?movieblockname=ranking&amp;movielinkname=report&amp;tid1=rank&amp;tid2=report">랭킹리포트</a></li>
# <!-- <li><a href="http://movie.interpark.com/Movie/Theater/NTheaterMain.asp?movieblockname=top&movielinkname=theater_ranking" class="boldAnchor">극장정보</a></li>
# 				<li><a href="http://movie.interpark.com/Movie/Theater/NTheaterSatisfy.asp?movieblockname=theater&movielinkname=content_realtime&tid1=theater&tid2=content">극장만족도 랭킹</a></li>
# 				<li><a href="http://movie.interpark.com/Movie/Theater/NTheaterReserve.asp?movieblockname=theater&movielinkname=reserve_realtime&tid1=theater&tid2=bookranking">극장예매 랭킹</a></li>
# 				<li><a href="http://movie.interpark.com/Movie/Theater/Place_Ranking_List.asp?movieblockname=theater&movielinkname=place_ranking&tid1=theater&tid2=review">극장후기</a></li>
# 				<li><a href="http://movie.interpark.com/Movie/Theater/IMMovie_NewsList.asp?Flag=P&movieblockname=theater&movielinkname=newslist_p&tid1=theater&tid2=newsevent">극장뉴스/이벤트</a></li> -->
# </ul>
# <ul>
# <li><a class="boldAnchor" href="http://movie.interpark.com/Community/Movie/Main/main.asp?movieblockname=top&amp;movielinkname=talk_main">커뮤니티</a></li>
# <li><a href="http://movie.interpark.com/Community/Movie/Talk/ReviewList.asp?movieblockname=talk&amp;movielinkname=review&amp;tid1=communi&amp;tid2=review">관람후기</a></li>
# <li><a href="http://movie.interpark.com/Community/Movie/Talk/Reply_List.asp?movieblockname=talk&amp;movielinkname=replay&amp;tid1=communi&amp;tid2=reply">리플리플</a></li>
# <!--<li><a href="http://movie.interpark.com/Community/Movie/Paper/PaperList.asp?Flag=MR&movieblockname=paper&movielinkname=flagmr&tid1=communi&tid2=professional">전문가 리뷰</a></li>-->
# <li><a href="http://movie.interpark.com/Community/Movie/Paper/PaperList.asp?Flag=MT&amp;movieblockname=paper&amp;movielinkname=flagmt&amp;tid1=communi&amp;tid2=specialissue">스페셜 이슈</a></li>
# <li><a href="http://movie.interpark.com/Community/Movie/Paper/PaperList.asp?Flag=MN&amp;movieblockname=paper&amp;movielinkname=flagmn&amp;tid1=communi&amp;tid2=movienews">영화뉴스</a></li>
# <li><a href="http://movie.interpark.com/Community/Movie/Talk/Poll/IMPollList.asp?movieblockname=talk&amp;movielinkname=poll&amp;tid1=communi&amp;tid2=interpoll">인터파크 POLL</a></li>
# <!-- 				<li><a href="http://movie.interpark.com/Community/Movie/Talk/Preview/P_List.asp?movieblockname=talk&movielinkname=preview&tid1=communi&tid2=previewshare">시사회 나눔터</a></li> -->
# <li><a href="http://movie.interpark.com/Community/Movie/Paper/PaperList.asp?Flag=MC&amp;movieblockname=paper&amp;movielinkname=flagmc&amp;tid1=communi&amp;tid2=interview">인터뷰</a></li>
# <li><a href="http://movie.interpark.com/Community/Movie/Paper/Movie_Multi.asp?movieblockname=paper&amp;movielinkname=movie_multi&amp;tid1=communi&amp;tid2=plays">동영상</a></li>
# </ul>
# <ul>
# <li><a class="boldAnchor" href="http://movie.interpark.com/Community/Movie/Event/index.asp">시사회/이벤트</a></li>
# <li><a href="http://movie.interpark.com/Community/Movie/Event/Movie_Kinds_Event.asp?E_kind=M_P&amp;movieblockname=event&amp;movielinkname=m_p&amp;tid1=event&amp;tid2=preview">시사회</a></li>
# <li><a href="http://movie.interpark.com/Community/Movie/Event/Movie_Kinds_Event.asp?E_kind=M_G&amp;movieblockname=event&amp;movielinkname=m_g&amp;tid1=event&amp;tid2=gift">예매/경품</a></li>
# <li><a href="http://movie.interpark.com/Community/Movie/Event/Movie_Kinds_Event.asp?E_kind=C_E&amp;movieblockname=event&amp;movielinkname=c_e&amp;tid1=event&amp;tid2=sales">할인</a></li>
# <li><a href="http://movie.interpark.com/Community/Movie/Event/Winner_Announcement.asp?movieblockname=event&amp;movielinkname=winner_anno&amp;tid1=event&amp;tid2=announce">당첨자발표</a></li>
# <li><a href="http://movie.interpark.com/Community/Movie/Event/Cinema_TheaterEvent.asp?Flag=P&amp;movieblockname=event&amp;movielinkname=cinema_theaterevent&amp;tid1=event&amp;tid2=theaterevent">영화관 이벤트</a></li>
# </ul>
# <ul>
# <li><a class="boldAnchor" href="http://movie.interpark.com/Movie/Voucher/IMGift_Sel.asp?movieblockname=top&amp;movielinkname=imgift_sel">영화예매권</a></li>
# <li><a href="http://movie.interpark.com/Movie/Voucher/IMGift_Sel.asp?movieblockname=voucher&amp;movielinkname=gift_sel&amp;tid1=voucher&amp;tid2=whatisit">영화예매권이란</a></li>
# <li><a href="http://movie.interpark.com/Movie/Voucher/IMHelpDesk.asp?movieblockname=voucher&amp;movielinkname=gift_helpdesk&amp;tid1=voucher&amp;tid2=howto">이용안내</a></li>
# <li><a href="http://movie.interpark.com/Movie/Voucher/IMGift_Reg.asp?movieblockname=voucher&amp;movielinkname=gift_reg&amp;tid1=voucher&amp;tid2=register">예매권 등록/조회</a></li>
# <li><a href="http://movie.interpark.com/Movie/2.0/Booking.asp?movieblockname=voucher&amp;movielinkname=booking&amp;tid1=voucher&amp;tid2=using">예매권으로 예매</a></li>
# <li><a href="http://movie.interpark.com/Movie/Voucher/IMGift_Reference.asp?movieblockname=voucher&amp;movielinkname=gift_reference&amp;tid1=voucher&amp;tid2=question">예매권 구매 문의</a></li>
# </ul>
# <ul class="lastUl">
# <!-- <li><a href="http://movie.interpark.com/Movie/Coupon/c_u_i.asp?movieblockname=top&movielinkname=c_u_i" class="boldAnchor">영화할인쿠폰</a></li>
# 				<li><a href="http://movie.interpark.com/Movie/Coupon/c_u_i.asp?movieblockname=coupon&movielinkname=c_u_i&tid1=coupon&tid2=information">쿠폰안내</a></li>
# 				<li><a href="http://movie.interpark.com/Movie/Coupon/c_r_s.asp?movieblockname=coupon&movielinkname=c_r_s&tid1=coupon&tid2=registration">등록하기</a></li> -->
# <li><a class="boldAnchor" href="http://movie.interpark.com/Community/Movie/Discount/Discount_Way.asp?movieblockname=top&amp;movielinkname=discount_way">싸게보는법</a></li>
# <li><a href="http://movie.interpark.com/Community/Movie/Discount/Discount_Way.asp?movieblockname=discount&amp;movielinkname=dis_way&amp;tid1=discount&amp;tid2=ways">싸게보는법</a></li>
# <li><a href="http://movie.interpark.com/Community/Movie/Discount/Movie_Kinds_Discount.asp?Kind=sale_card_inpark_hana&amp;tid1=discount&amp;tid2=creditcard">신용카드 할인</a></li>
# <li><a href="http://movie.interpark.com/Community/Movie/Discount/Movie_Kinds_Event.asp?E_kind=C_E&amp;movieblockname=discount&amp;movielinkname=c_&amp;tid1=discount&amp;tid2=salesevent">할인이벤트</a></li>
# <li><a href="http://movie.interpark.com/Community/Movie/Discount/IPoint_Discount.asp?movieblockname=discount&amp;movielinkname=point_dis&amp;tid1=discount&amp;tid2=ipoint">아이포인트 할인</a></li>
# </ul>
# </div>
# </div>
# <div style="clear:both; height:0px; font-size:0px; line-height:0px;"></div>
# </div>
# <!-- e: 영화GNB 주메뉴 -->
# </div>
# <!-- e: GNB 영화 -->
# <script type="text/javascript">
# 	var boolLoginCheck
# 	boolLoginCheck = "False";
#
# 	if(boolLoginCheck == "False") {
#
# 		var alkey = ""
# 		if (alkey =="")
# 		{
# 			document.getElementById("m_join1").innerHTML = "<a href='https://movie.interpark.com/Movie/Gate/TPLogin.asp?CPage=M'>로그인</a>";
# 		}
#
# 		document.getElementById("m_join2").innerHTML = "<a href='https://member.interpark.com/signup?join_site_tp=50&join_ipp_id='>회원가입</a>";
# 	} else {
# //		document.getElementById("m_join1").innerHTML = "<a href='https://Movie.interpark.com/Movie/Gate/TPLogOut.asp?From=M'>로그아웃</a>";
# 		document.getElementById("m_join2").innerHTML = "<a href='http://incorp.interpark.com/member/memberjoin.do?_method=upMemberFront'>회원정보</a>";
# 	}
# 	// 2008-09-19 예매개선으로 추가
# 	function BookingLoginChange() {
# 		strCook = ""
# 		if(strCook == "") {
# 			document.getElementById("m_join1").innerHTML = "<a href='https://movie.interpark.com/Movie/Gate/TPLogin.asp?CPage=M'>로그인</a>";
# 			document.getElementById("m_join2").innerHTML = "<a href='https://member.interpark.com/signup?join_site_tp=50&join_ipp_id='>회원가입</a>";
# 		} else {
# 			//document.getElementById("m_join1").innerHTML = "<a href='https://Movie.interpark.com/Movie/Gate/TPLogOut.asp?From=M'>로그아웃</a>";
# 			document.getElementById("m_join2").innerHTML = "<a href='http://incorp.interpark.com/member/memberjoin.do?_method=upMemberFront'>회원정보</a>";
# 		}
# 	}
#
# 	function fnSetAutoLogin()
# 	{
# 		var autostr = "";
# 		var AccountsLogOutURL = "https://accounts.interpark.com/logout?retUrl=" + encodeURIComponent("https://Movie.interpark.com/Movie/Gate/TPLogOut.asp?From=M");
# 		var Cidtoken = "";
#
# 		new Ajax.Request(
# 			"/Movie/Lib/AutoLoginXmlInfo.asp",
# 			{
# 				method : 'get',
# 				onSuccess : function(transport){
# 					if(transport.status == 200)
# 					{
# 						var user_name = transport.responseText;
# 						if (user_name != "")
# 						{
# 							if (getCookie("alKey") != "" && Cidtoken == "") //자동로그인
# 							{
# 								autostr  = '<a href="' + AccountsLogOutURL + '" ><strong>로그아웃</strong></a>';
# 							}
# 							else if (Cidtoken != "") //실제 로그인
# 							{
# 								autostr  = '<a href="' + AccountsLogOutURL + '" ><strong>로그아웃</strong></a>';
#
# 							} else {
# 								autostr = '<span id="m_join1"><a href="https://movie.interpark.com/Movie/Gate/TPLogin.asp?CPage=M">로그인</a></span>';
# 							}
# 							document.getElementById("logstatus").className  = "gnb_login";
# 							document.getElementById("logstatus").innerHTML = "";
# 							document.getElementById("logstatus").innerHTML = autostr;
#
# 						}
# 					}
# 				}
# 			}
# 		);
#
# 	}
#
# 	function AutoLogDiv(atype)
# 	{
# 		var autologindiv = document.getElementById("autologindiv");
#
# 		if(autologindiv != null || autologindiv != "undifined")
# 		{
# 			if(atype=="1")
# 			{
# 				if(autologindiv.style.display == "none")
# 				{
# 					autologindiv.style.display = "";
# 				}
# 			}else if(atype=="2")
# 			{
# 				if(autologindiv.style.display == "")
# 				{
# 					autologindiv.style.display = "none";
# 				}
# 			}
# 		}
# 	}
#
#
# 	setTimeout("fnSetAutoLogin()",100);
# 	//setGateBar();
#
# 	jQuery.noConflict();
# 	var head$ = jQuery;
#
# 	// Ajax 공통
# 	var AJAXCom = {
# 		Update : function(url, param, target) {
#
# 			head$.ajax({
# 				type:"POST",
# 				url: url,
# 				data: param,
# 				success:function(result) {
# 					 head$("#"+target).html(result);
# 				},
# 				error:function(result) {
# 					//alert('error');
# 				}
# 			});
# 		}
# 	}
#
# 	if("Y" != "N")
# 	{
# 		AJAXCom.Update('/Include/TPRightWing.asp?Type=OpenWing', '', 'NewrightWing');
# 	}
#
# 	//지마켓 닫기 기능
# 	if ("" == "Gmarket")
# 	{
# 	    var _time = 600000;
#
# 	    if ( "" != undefined && "" != "")
# 	    {
# 	        var _cookie = stringToDate(" ");
# 		var _date = new Date();
# 		var _diff = _cookie.getTime() - _date.getTime();
#
# 		_time = _diff; //(getCookie("GMK_expires_in") - 0) * 1000;
#
# 	        setTimeout(function () {
# 				gmarketClose();
# 	        }, _time);
# 	    }
# 	}
#
# 	function stringToDate(_date) {
# 		var dateString = _date;
# 		var reggie = /(\d{4})-(\d{2})-(\d{2}) (\d{2}):(\d{2}):(\d{2})/;
# 		var dateArray = reggie.exec(dateString);
# 		var dateObject = new Date(
# 			(+dateArray[1]),
# 			(+dateArray[2]) - 1, // Careful, month starts at 0!
# 			(+dateArray[3]),
# 			(+dateArray[4]),
# 			(+dateArray[5]),
# 			(+dateArray[6])
# 		);
#
# 		return dateObject;
# 	}
#
# 	function gmarketClose()
# 	{
#
# 	    try
# 	    {
# 	        alert("G마켓을 통해 접속하신 인터파크 티켓 서비스 이용 시간이 만료되어 창이 닫힙니다. 다시 접속해 주시기 바랍니다.");
#
# 	        // 쿠키 제거 확인
# 	        _setCookie("Where", "", -1, "interpark.com");
# 	        _setCookie("allianceTarget", "", -1, "interpark.com");
# 	        _setCookie("GMKMenuCode", "", -1, "interpark.com");
# 	        _setCookie("GMKGoodsCode", "", -1, "interpark.com");
# 	        _setCookie("GMKIsMobileYN", "", -1, "interpark.com");
# 	        _setCookie("GMKCode", "", -1, "interpark.com");
# 	        _setCookie("GMKUserCI", "", -1, "interpark.com");
# 	        _setCookie("GMKToken", "", -1, "interpark.com");
# 	        _setCookie("GMKrefreshToken", "", -1, "interpark.com");
# 	        _setCookie("GMK_expires_in", "", -1, "interpark.com");
# 	        _setCookie("G_expires", "", -1, "interpark.com");
#
# 	        //opener.close();
# 	        self.close();	//테스트 > 닫지 않기
#
# 	    }
# 	    catch (e)
# 	    {
# 	        self.close();
# 	    }
# 	}
#
# 	function _setCookie(name, value, expiredays, domain)
# 	{
# 	    var todayDate = new Date();
#
# 	    todayDate.setDate(todayDate.getDate() + expiredays);
# 	    document.cookie = name + "=" + escape(value) + "; path=/;domain=interpark.com; expires=" + todayDate.toGMTString() + ";"
# 	}
#
# </script>
# <script type="text/javascript">
# <!--
# 	function MM_jumpMenu(targ,selObj,restore){ //v3.0
# 	  eval(targ+".location='"+selObj.options[selObj.selectedIndex].value+"'");
# 	  if (restore) selObj.selectedIndex=0;
# 	}
#
# 	function MovieGoodsGo(i_Value){
# 		self.location.href = "/Movie/Main/NGoodsInfo.asp?GroupCode=" +	i_Value;
# 		}
#
# 	function getCookie(name) {
# 		var nIndex = 0;
# 		var nflag1 = 0;
# 		var nflag2 = 0;
# 		var vCookie = document.cookie;
# 		var vCookieValue = "";
# 		var vsubStr = "";
#
# 		// 쿠키명을 이용하여 설정된 쿠키값을 찾아 리턴해준다.
# 		nIndex = vCookie.indexOf(name);
#
# 		// 기존에 로그인을 안했어도 가지고 있는 쿠키값을 리턴하여 예외 처리 함
# 		if ( nIndex < 0 ) {
# 			return "";
# 		}
#
# 		vsubStr = vCookie.substr(nIndex);
# 		nflag1 = vsubStr.indexOf("=");
# 		nflag2 = vsubStr.indexOf(";");
#
# 		if (nflag2 < 0)	{
# 			vCookieValue = vsubStr.substr(nflag1+1);
# 		} else {
# 			vCookieValue = vsubStr.substr(nflag1+1, nflag2-nflag1-1);
# 		}
#
# 		return(vCookieValue);
# 	}
# -->
# </script>
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="960">
# <tbody><tr>
# <td colspan="3" height="10"></td>
# </tr>
# <tr>
# <td valign="top" width="220">
# <table border="0" cellpadding="0" cellspacing="0" width="220">
# <tbody><tr>
# <td valign="top" width="220">
# <table border="0" cellpadding="0" cellspacing="0" width="220">
# <tbody><tr>
# <td>
# <table border="0" cellpadding="0" cellspacing="0" width="220">
# <tbody><tr>
# <td width="7"><img height="64" src="http://ticketimage.interpark.com/Movie/sub/mp_tb01.gif" width="7"/></td>
# <td background="http://ticketimage.interpark.com/Movie/sub/mp_tb02.gif" style="padding:18px 0 0 10px" valign="top" width="130"><img height="32" src="http://ticketimage.interpark.com/Movie/sub/tt_03.gif" width="72"/></td>
# <td width="83"><img height="64" src="http://ticketimage.interpark.com/Movie/sub/mp_tb_tt03.gif" width="83"/></td>
# </tr>
# </tbody></table>
# </td>
# </tr>
# <tr>
# <td>
# <table border="0" cellpadding="0" cellspacing="0" width="220">
# <tbody><tr>
# <td background="http://ticketimage.interpark.com/Movie/sub/mp_tb05.gif"></td>
# <td style="padding:16px 0 19px 15px" valign="top">
# <table border="0" cellpadding="0" cellspacing="0">
# <tbody><tr>
# <td><img border="0" src="http://ticketimage.interpark.com/Movie/sub/mrk01.gif"/></td>
# </tr>
# <tr>
# <td style="padding:10px 0 0 2px">
# <table border="0" cellpadding="0" cellspacing="0">
# <tbody><tr>
# <td><a href="http://movie.interpark.com/Community/Movie/Ranking/Movie_Kinds_Ranking.asp?Flag=D&amp;movieblockname=ranking&amp;movielinkname=flagd"><img border="0" id="R_today" src="http://ticketimage.interpark.com/Movie/sub/mrk01_1.gif"/></a></td>
# </tr>
# <tr>
# <td height="7"></td>
# </tr>
# <tr>
# <td><a href="http://movie.interpark.com/Community/Movie/Ranking/Movie_Kinds_Ranking.asp?Flag=W&amp;movieblockname=ranking&amp;movielinkname=flagw"><img border="0" id="R_Weekend" src="http://ticketimage.interpark.com/Movie/sub/mrk01_2.gif"/></a></td>
# </tr>
# <tr>
# <td height="7"></td>
# </tr>
# <tr>
# <td><a href="http://movie.interpark.com/Community/Movie/Ranking/Movie_Kinds_Ranking.asp?Flag=H&amp;movieblockname=ranking&amp;movielinkname=flagh"><img border="0" id="R_Weekly" src="http://ticketimage.interpark.com/Movie/sub/mrk01_3.gif"/></a></td>
# </tr>
# <tr>
# <td height="7"></td>
# </tr>
# <tr>
# <td><a href="http://movie.interpark.com/Community/Movie/Ranking/Movie_Kinds_Ranking.asp?Flag=M&amp;movieblockname=ranking&amp;movielinkname=flagm"><img border="0" id="R_Monthly" src="http://ticketimage.interpark.com/Movie/sub/mrk01_4.gif"/></a></td>
# </tr>
# <tr>
# <td height="7"></td>
# </tr>
# <tr>
# <td><a href="http://movie.interpark.com/Community/Movie/Ranking/Movie_Kinds_Ranking.asp?Flag=Y&amp;movieblockname=ranking&amp;movielinkname=flagy"><img border="0" id="R_Yearly" src="http://ticketimage.interpark.com/Movie/sub/mrk01_5.gif"/></a></td>
# </tr>
# </tbody></table>
# </td>
# </tr>
# <tr>
# <td height="20"></td>
# </tr>
# <tr>
# <td><img border="0" src="http://ticketimage.interpark.com/Movie/sub/mrk02.gif"/></td>
# </tr>
# <tr>
# <td style="padding:10px 0 0 2px">
# <table border="0" cellpadding="0" cellspacing="0">
# <tbody><tr>
# <td><a href="http://movie.interpark.com/Community/Movie/Ranking/Netizen_Play.asp?movieblockname=ranking&amp;movielinkname=netizen_play"><img border="0" id="R_Now_Movie" src="http://ticketimage.interpark.com/Movie/sub/mrk02_1.gif"/></a></td>
# </tr>
# <tr>
# <td height="7"></td>
# </tr>
# <tr>
# <td><a href="http://movie.interpark.com/Community/Movie/Ranking/Netizen_Generation.asp?movieblockname=ranking&amp;movielinkname=netizen_gener"><img border="0" id="R_Now_Movie_Gen" src="http://ticketimage.interpark.com/Movie/sub/mrk02_2.gif"/></a></td>
# </tr>
# <!-- 2012-06-04 년도별 데이터 분포가 미비하여 제외
# 																<tr>
# 																	<td height="7"></td>
# 																</tr>
# 																<tr>
# 																	<td><a href="http://movie.interpark.com/Community/Movie/Ranking/Netizen_Year.asp?movieblockname=ranking&movielinkname=netizen_year"><img src="http://ticketimage.interpark.com/Movie/sub/mrk02_3.gif" border="0" id="R_Now_Movie_Year"></a></td>
# 																</tr> -->
# </tbody></table>
# </td>
# </tr>
# <tr>
# <td height="20"></td>
# </tr>
# <tr>
# <td><a href="http://movie.interpark.com/Community/Movie/Ranking/Estimate_Ranking.asp?movieblockname=ranking&amp;movielinkname=estimate"><img border="0" id="EstimateRanking" src="http://ticketimage.interpark.com/Movie/sub/mrk03.gif"/></a></td>
# </tr>
# <tr>
# <td height="20"></td>
# </tr>
# <!-- <tr>
# 														<td><a href="http://movie.interpark.com/Community/Movie/Ranking/boxoffice_prediction.asp?movieblockname=ranking&movielinkname=boxoffice"><img src="http://ticketimage.interpark.com/Movie/sub/mrk04.gif" border="0" id="BoxofficePrediction"></a></td>
# 													</tr>
# 													<tr>
# 														<td height="20"></td>
# 													</tr> -->
# <!--
# 													<tr>
# 														<td><a href="http://movie.interpark.com/Community/Movie/Ranking/netizen_boxoffice_prediction.asp?movieblockname=ranking&movielinkname=boxoffice_prediction"><img src="http://ticketimage.interpark.com/Movie/sub/mrk05.gif" border="0" id="BoxofficePrediction2"></a></td>
# 													</tr>
# 													<tr>
# 														<td style="padding:10px 0 0 2px">
# 															<table border="0" cellspacing="0" cellpadding="0">
# 																<tr>
# 																	<td><a href="http://movie.interpark.com/Community/Movie/Ranking/Guess_WinnerTopList.asp?movieblockname=ranking&movielinkname=winnertop"><img src="http://ticketimage.interpark.com/Movie/sub/mrk05_1.gif" border="0" id="Guess_Winner"></a></td>
# 																</tr>
# 																<tr>
# 																	<td height="7"></td>
# 																</tr>
# 																<tr>
# 																	<td><a href="http://movie.interpark.com/Community/Movie/Ranking/Guess_WinnerList_main.asp?movieblockname=ranking&movielinkname=winnerlist"><img src="http://ticketimage.interpark.com/Movie/sub/mrk05_2.gif" border="0" id="Guess_WinnerList"></a></td>
# 																</tr>
#
# 															</table>
# 														</td>
# 													</tr>
# 													<tr>
# 														<td height="20"></td>
# 													</tr>
#  -->
# <tr>
# <td><a href="http://movie.interpark.com/Community/Movie/Ranking/ranking_report.asp?movieblockname=ranking&amp;movielinkname=report"><img border="0" id="RankingReport" src="http://ticketimage.interpark.com/Movie/sub/mrk06_on.gif"/></a></td>
# </tr>
# </tbody></table>
# </td>
# <td background="http://ticketimage.interpark.com/Movie/sub/mp_tb06.gif"></td>
# </tr>
# <tr>
# <td height="7" width="7"><img height="7" src="http://ticketimage.interpark.com/Movie/sub/mp_tb07.gif" width="7"/></td>
# <td background="http://ticketimage.interpark.com/Movie/sub/mp_tb08.gif" valign="top"></td>
# <td width="7"><img height="7" src="http://ticketimage.interpark.com/Movie/sub/mp_tb09.gif" width="7"/></td>
# </tr>
# </tbody></table>
# </td>
# </tr>
# </tbody></table>
# </td>
# </tr>
# </tbody></table>
# <script language="javascript">
# 				var j_Url = LCase(location.href);
#
# 				if ( j_Url.indexOf("flag=d") >= 0 )
# 				{
# 					document.all.R_today.src = "http://ticketimage.interpark.com/Movie/sub/mrk01_1_on.gif";
# 				}
# 				else if ( j_Url.indexOf("flag=w") >= 0 )
# 				{
# 					document.all.R_Weekend.src = "http://ticketimage.interpark.com/Movie/sub/mrk01_2_on.gif";
# 				}
# 				else if ( j_Url.indexOf("flag=h") >= 0 )
# 				{
# 					document.all.R_Weekly.src = "http://ticketimage.interpark.com/Movie/sub/mrk01_3_on.gif";
# 				}
# 				else if ( j_Url.indexOf("flag=m") >= 0 )
# 				{
# 					document.all.R_Monthly.src = "http://ticketimage.interpark.com/Movie/sub/mrk01_4_on.gif";
# 				}
# 				else if ( j_Url.indexOf("flag=y") >= 0 )
# 				{
# 					document.all.R_Yearly.src = "http://ticketimage.interpark.com/Movie/sub/mrk01_5_on.gif";
# 				}
# 				else if ( j_Url.indexOf("netizen_play.asp") >= 0 )
# 				{
# 					document.all.R_Now_Movie.src = "http://ticketimage.interpark.com/Movie/sub/mrk02_1_on.gif";
# 				}
# 				else if ( j_Url.indexOf("netizen_generation.asp") >= 0 )
# 				{
# 					document.all.R_Now_Movie_Gen.src = "http://ticketimage.interpark.com/Movie/sub/mrk02_2_on.gif";
# 				}
# 				else if ( j_Url.indexOf("netizen_year.asp") >= 0 )
# 				{
# 					document.all.R_Now_Movie_Year.src = "http://ticketimage.interpark.com/Movie/sub/mrk02_3_on.gif";
# 				}
# 				else if ( j_Url.indexOf("estimate_ranking.asp") >= 0 )
# 				{
# 					document.all.EstimateRanking.src = "http://ticketimage.interpark.com/Movie/sub/mrk03_on.gif";
# 				}
# 				else if ( j_Url.indexOf("netizen_boxoffice_prediction.asp") >= 0 )
# 				{
# 					document.all.BoxofficePrediction2.src = "http://ticketimage.interpark.com/Movie/sub/mrk05_on.gif";
# 				}
# 				else if ( j_Url.indexOf("boxoffice_prediction.asp") >= 0 )
# 				{
# 					document.all.BoxofficePrediction.src = "http://ticketimage.interpark.com/Movie/sub/mrk04_on.gif";
# 				}
# 				else if ( j_Url.indexOf("guess_winnertoplist.asp") >= 0 )
# 				{
# 					document.all.Guess_Winner.src = "http://ticketimage.interpark.com/Movie/sub/mrk05_1_on.gif";
# 				}
# 				else if ( j_Url.indexOf("guess_winnerlist_main.asp") >= 0 )
# 				{
# 					document.all.Guess_WinnerList.src = "http://ticketimage.interpark.com/Movie/sub/mrk05_2_on.gif";
# 				}
# 				else if ( j_Url.indexOf("ranking_report.asp") >= 0 )
# 				{
# 					document.all.RankingReport.src = "http://ticketimage.interpark.com/Movie/sub/mrk06_on.gif";
# 				}
#
#
# 				function LCase(str)
# 				{
# 					var str_new ="";
# 					var k;
#
# 					for (k=0; k<str.length ; k++)
# 					{
# 						var tmp = str.charAt(k) //개별문자
# 						c = tmp.toLowerCase() //개별문자를 소문자로 (대문자는 toUpperCase)
#
# 						str_new = str_new + c //개별문자 누적시킴
# 					}
# 					return str_new;
# 				}
# 			</script>
# </td>
# <td valign="top" width="14"></td>
# <td valign="top" width="726">
# <table border="0" cellpadding="0" cellspacing="0" width="726">
# <tbody><tr>
# <td>
# <table border="0" cellpadding="0" cellspacing="0" width="726">
# <tbody><tr>
# <td height="29"><img border="0" hspace="4" src="http://ticketimage.interpark.com/Movie/sub/ranking10.gif"/></td>
# </tr>
# </tbody></table>
# <br/>
# <table border="0" cellpadding="0" cellspacing="0" width="726">
# <tbody><tr>
# <td width="34"><img border="0" hspace="35" src="http://ticketimage.interpark.com/Movie/sub/ranking10_1.gif"/></td>
# </tr>
# </tbody></table>
# <table border="0" cellpadding="0" cellspacing="0" width="726">
# <tbody><tr>
# <td><img height="7" src="http://ticketimage.interpark.com/TicketImage/event/template/blank.gif" width="1"/></td>
# </tr>
# <tr>
# <td>
# <table border="0" cellpadding="0" cellspacing="0" width="726">
# <tbody><tr>
# <td width="22"> </td>
# <td width="704">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tbody>
# <tr valign="top">
# <td align="right" width="24"><img hspace="5" src="http://ticketimage.interpark.com/TicketImage/common/bl_dot_ticket.gif" vspace="6"/></td>
# <td class="txt_line4" width="672"><b>집 계 기 간</b> :
# 							2022년 07월 21일(목) ~ 2022년 07월 24일(일)까지 관람일로 하여 예매한 순위
# 							</td>
# </tr>
# <tr valign="top">
# <td align="right"><img hspace="5" src="http://ticketimage.interpark.com/TicketImage/common/bl_dot_ticket.gif" vspace="6"/></td>
# <td class="txt_line4"><b>집 계 대 상</b> : <font style="text-decoration:underline">인터파크 웹예매, 인터파크 제휴사 예매, 인터파크 시스템입점극장 웹예매, 인터파크 모바일 예매
# 							</font>
# </td>
# </tr>
# </tbody>
# </table>
# </td>
# </tr>
# <tr>
# <td width="22"> </td>
# <td width="704"> </td>
# </tr>
# <tr>
# <td align="right" colspan="2" height="7">
# <form action="Ranking_Report.asp" method="post" name="MainForm">
# <input name="KindOfGoods" type="hidden" value="01002"/>
# <input name="Flag" type="hidden" value="H"/>
# <select name="BDate" onchange="javascript: OtherRankingGo();">
# <option value=""> ▼ 이전 순위가 궁금하세요? </option>
# <option value="20230713">2023.07.13(목) ~ 2023.07.16(일)</option>
# <option value="20230706">2023.07.06(목) ~ 2023.07.09(일)</option>
# <option value="20230629">2023.06.29(목) ~ 2023.07.02(일)</option>
# <option value="20230622">2023.06.22(목) ~ 2023.06.25(일)</option>
# <option value="20230615">2023.06.15(목) ~ 2023.06.18(일)</option>
# <option value="20230608">2023.06.08(목) ~ 2023.06.11(일)</option>
# <option value="20230601">2023.06.01(목) ~ 2023.06.04(일)</option>
# <option value="20230525">2023.05.25(목) ~ 2023.05.28(일)</option>
# <option value="20230518">2023.05.18(목) ~ 2023.05.21(일)</option>
# <option value="20230511">2023.05.11(목) ~ 2023.05.14(일)</option>
# <option value="20230504">2023.05.04(목) ~ 2023.05.07(일)</option>
# <option value="20230427">2023.04.27(목) ~ 2023.04.30(일)</option>
# <option value="20230420">2023.04.20(목) ~ 2023.04.23(일)</option>
# <option value="20230413">2023.04.13(목) ~ 2023.04.16(일)</option>
# <option value="20230406">2023.04.06(목) ~ 2023.04.09(일)</option>
# <option value="20230330">2023.03.30(목) ~ 2023.04.02(일)</option>
# <option value="20230323">2023.03.23(목) ~ 2023.03.26(일)</option>
# <option value="20230316">2023.03.16(목) ~ 2023.03.19(일)</option>
# <option value="20230309">2023.03.09(목) ~ 2023.03.12(일)</option>
# <option value="20230302">2023.03.02(목) ~ 2023.03.05(일)</option>
# <option value="20230223">2023.02.23(목) ~ 2023.02.26(일)</option>
# <option value="20230216">2023.02.16(목) ~ 2023.02.19(일)</option>
# <option value="20230209">2023.02.09(목) ~ 2023.02.12(일)</option>
# <option value="20230202">2023.02.02(목) ~ 2023.02.05(일)</option>
# <option value="20230126">2023.01.26(목) ~ 2023.01.29(일)</option>
# <option value="20230119">2023.01.19(목) ~ 2023.01.22(일)</option>
# <option value="20230112">2023.01.12(목) ~ 2023.01.15(일)</option>
# <option value="20230105">2023.01.05(목) ~ 2023.01.08(일)</option>
# <option value="20221229">2022.12.29(목) ~ 2023.01.01(일)</option>
# <option value="20221222">2022.12.22(목) ~ 2022.12.25(일)</option>
# <option value="20221215">2022.12.15(목) ~ 2022.12.18(일)</option>
# <option value="20221208">2022.12.08(목) ~ 2022.12.11(일)</option>
# <option value="20221201">2022.12.01(목) ~ 2022.12.04(일)</option>
# <option value="20221124">2022.11.24(목) ~ 2022.11.27(일)</option>
# <option value="20221117">2022.11.17(목) ~ 2022.11.20(일)</option>
# <option value="20221110">2022.11.10(목) ~ 2022.11.13(일)</option>
# <option value="20221103">2022.11.03(목) ~ 2022.11.06(일)</option>
# <option value="20221027">2022.10.27(목) ~ 2022.10.30(일)</option>
# <option value="20221020">2022.10.20(목) ~ 2022.10.23(일)</option>
# <option value="20221013">2022.10.13(목) ~ 2022.10.16(일)</option>
# <option value="20221006">2022.10.06(목) ~ 2022.10.09(일)</option>
# <option value="20220929">2022.09.29(목) ~ 2022.10.02(일)</option>
# <option value="20220922">2022.09.22(목) ~ 2022.09.25(일)</option>
# <option value="20220915">2022.09.15(목) ~ 2022.09.18(일)</option>
# ...
# 			                       <a href="javascript: MovieGo('V2200368', '');"><b>명탐정 코난: 할로윈의 신부(디지털)</b></a></td>
# </tr>
# </tbody></table>
# </td>
# <td align="center" background="http://ticketimage.interpark.com/TicketImage/fun/template/041207a_245_t20.gif" width="50"><font class="total_ranking"><font class="total_ranking">1.9%</font></font></td>
# <td background="http://ticketimage.interpark.com/TicketImage/fun/template/041207a_245_t20.gif" width="120"><table border="0" cellpadding="0" cellspacing="1" height="10" width="110">
# <tbody><tr>
# <td align="left" bgcolor="#FFFFFF" height="8">
# <img height="8" src="http://ticketimage.interpark.com/TicketImage/common/041230_Rankingmovie06.gif" width="1.9%"/>
# </td>
# </tr>
# </tbody></table></td>
# <td align="center" background="http://ticketimage.interpark.com/TicketImage/fun/template/041207a_245_t20.gif" width="82">2022.10.28</td>
# <td align="center" background="http://ticketimage.interpark.com/TicketImage/fun/template/041207a_245_t20.gif" width="60">
# <a href="javascript: MovieGo('V2200368', '');"><img border="0" src="http://ticketimage.interpark.com/TicketImage/fun/template/041207a_245_t09.gif"/></a>
# </td>
# </tr>
# <tr>
# <td align="center" background="http://ticketimage.interpark.com/TicketImage/fun/template/041207a_245_t20.gif" height="87" width="49">10위<br/>
#
# 								(<span style="color:#0157BA">▼1</span>)
#
#
# 			                </td>
# <td background="http://ticketimage.interpark.com/TicketImage/fun/template/041207a_245_t20.gif" width="336">
# <table align="left" border="0" cellpadding="0" cellspacing="0" width="100%">
# <tbody><tr>
# <td width="112"><a href="javascript: MovieGo('V2200258', '');"><img border="1" onerror="this.src='http://ticketimage.interpark.com/Play/image/small/NoImage.gif'" src="http://ticketimage.interpark.com/Movie/still_image/V22/V2200258s_m01.gif" style="BORDER-COLOR: #b9b9b9" width="112"/></a></td>
# <td> <img border="0" onerror="javascript: this.src='http://ticketimage.interpark.com/TicketImage/common/ic_no.gif' " src="http://ticketimage.interpark.com/TicketImage/common/ic_15.gif"/> <br/>
# 			                       <a href="javascript: MovieGo('V2200258', '');"><b>범죄도시 2(디지털)</b></a></td>
# </tr>
# </tbody></table>
# </td>
# <td align="center" background="http://ticketimage.interpark.com/TicketImage/fun/template/041207a_245_t20.gif" width="50"><font class="total_ranking"><font class="total_ranking">0.5%</font></font></td>
# <td background="http://ticketimage.interpark.com/TicketImage/fun/template/041207a_245_t20.gif" width="120"><table border="0" cellpadding="0" cellspacing="1" height="10" width="110">
# <tbody><tr>
# <td align="left" bgcolor="#FFFFFF" height="8">
# <img height="8" src="http://ticketimage.interpark.com/TicketImage/common/041230_Rankingmovie06.gif" width="0.5%"/>
# </td>
# </tr>
# </tbody></table></td>
# <td align="center" background="http://ticketimage.interpark.com/TicketImage/fun/template/041207a_245_t20.gif" width="82">2022.05.18</td>
# <td align="center" background="http://ticketimage.interpark.com/TicketImage/fun/template/041207a_245_t20.gif" width="60">
# <a href="javascript: MovieGo('V2200258', '');"><img border="0" src="http://ticketimage.interpark.com/TicketImage/fun/template/041207a_245_t09.gif"/></a>
# </td>
# </tr>
# </tbody></table>
# </td>
# <td background="http://ticketimage.interpark.com/TicketImage/fun/template/r_l_t_right_bg.gif" width="5"></td>
# </tr>
# <tr>
# <td height="5" width="5"><img height="5" src="http://ticketimage.interpark.com/TicketImage/fun/template/r_l_t_left_02.gif" width="5"/></td>
# <td background="http://ticketimage.interpark.com/TicketImage/fun/template/r_l_t_bottom.gif" height="5"></td>
# <td height="5" width="5"><img height="5" src="http://ticketimage.interpark.com/TicketImage/fun/template/r_l_t_right_02.gif" width="5"/></td>
# </tr>
# </tbody></table>
# </td>
# </tr>
# </tbody></table>
# </td>
# </tr>
# </tbody></table>
# <!-- 2010-06-03 flux 임시 제거 .-->
# </td>
# </tr>
# </tbody></table>
# <!-- -->
# <link href="//ticketimage.interpark.com/TicketImage/uidev/movie/styles/common/footer.css" rel="stylesheet"/> <!-- RD-1234 푸터변경 -->
# <script src="//ticket.interpark.com/common/footer/footer.js" type="text/javascript"></script>
# <!-- s: Footer 영역 -->
# <footer class="tourEnterFooter">
# <div class="footCorp">
# <ul class="corpList">
# <li>
# <a href="https://corp.interpark.com/" target="_blank" title="새 창으로 열림">회사소개</a>
# </li>
# <li>
# <a href="https://m.interpark.com/terms.html#agree" target="_blank" title="새 창으로 열림">이용약관</a>
# </li>
# <li>
# <a class="bold" href="https://m.interpark.com/terms.html#protect_privacy" target="_blank" title="새 창으로 열림">개인정보처리방침</a>
# </li>
# <li>
# <a href="https://m.interpark.com/terms.html#location_terms" target="_blank" title="새 창으로 열림">위치기반서비스 이용약관</a>
# </li>
# <li>
# <a href="http://tour.interpark.com/company/companyOutsidecovenant.aspx" target="_blank" title="새 창으로 열림">여행약관</a>
# </li>
# <li>
# <a href="http://tour.interpark.com/customer/noticeview.aspx?seq=10638" target="_blank" title="새 창으로 열림">여행자보험 가입내역</a>
# </li>
# <li>
# <a href="http://ticket.interpark.com/TiKi/Info/ENTInfo.asp?info=c_info_20" target="_blank" title="새 창으로 열림">티켓판매안내</a>
# </li>
# <li>
# <a href="https://travel.interpark.com/home/customer/board/notice/ticket" target="_blank" title="새 창으로 열림">공지사항</a>
# </li>
# <li class="">
# <a class="sub" href="javascript:;">고객센터</a>
# <ul class="depth">
# <li><a href="http://tour.interpark.com/customer/" target="_blank" title="새 창으로 열림">투어 고객센터</a></li>
# <li><a href="http://ticket.interpark.com/HelpDesk/HelpDeskMain.asp?&amp;tid1=main_gnb&amp;tid2=right_top&amp;tid3=help&amp;tid4=help" target="_blank" title="새 창으로 열림">티켓 고객센터</a></li>
# </ul>
# </li>
# <li>
# <a class="sub" href="javascript:;">Language</a>
# <ul class="depth">
# <li><a href="http://ticket.interpark.com" target="_blank" title="새 창으로 열림">Korean</a></li>
# <li><a href="http://www.globalinterpark.com/main/main?lang=en&amp;smid1=header&amp;smid2=logout&amp;smid3=language" target="_blank" title="새 창으로 열림">English</a></li>
# <li><a href="http://www.globalinterpark.com/main/main?lang=ja&amp;smid1=header&amp;smid2=logout&amp;smid3=language" target="_blank" title="새 창으로 열림">Japanese</a></li>
# <li><a href="http://www.globalinterpark.com/main/main?lang=zh&amp;smid1=header&amp;smid2=logout&amp;smid3=language" target="_blank" title="새 창으로 열림">Chinese</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="footInfo">
# <div class="infoCol">
# <h2 class="infoTitle">(주)인터파크트리플</h2>
# <div class="infoContent">
# <p>주소 서울시 강남구 삼성로 512 삼성동빌딩 10층</p>
# <p>사업자등록번호 824-81-02515 <a class="linkText" href="javascript:businessPerson();" title="새 창으로 열림">사업자정보확인</a></p>
# <p>통신판매업신고 2022-서울강남-02179</p>
# <p>관광사업증 등록번호 : 제2014-42호</p>
# <p>호스팅서비스제공자 (주)인터파크트리플｜대표이사 최휘영</p>
# </div>
# </div>
# <div class="infoCol">
# <h2 class="infoTitle">고객센터</h2>
# <div class="infoContent">
# <p>
# <span>
#                 투어
#                 <a href="tel:1588-3443">1588-3443</a>
# </span>
# <span>
#                 티켓
#                 <a href="tel:1544-1555">1544-1555</a>
# </span>
# </p>
# <p>
# <span>
#                 팩스
#                 <a href="tel:02-830-7807">02-830-7807</a>
# </span>
# <span>
#                 이메일
#                 <a href="mailto:helpdesk@interparktriple.com">helpdesk@interparktriple.com</a>
# </span>
# </p>
# <p>
# <span>
#                 해외항공
#                 <a href="tel:02-3479-4399">02-3479-4399</a>
# </span>
# <span>
#                 국내항공
#                 <a href="tel:02-3479-4340">02-3479-4340</a>
# </span>
# </p>
# <p>
# <span>
# <a class="linkText" href="javascript:tourOpen();" title="새 창으로 열림">투어 1:1문의</a>
# </span>
# <span>
# <a class="linkText" href="https://ticket.interpark.com/HelpDesk/SosWrite.asp" target="_blank" title="새 창으로 열림">티켓 1:1문의</a>
# </span>
# </p>
# </div>
# </div>
# <div class="infoCol">
# <h2 class="infoTitle">전자금융거래 분쟁처리 담당정보</h2>
# <div class="infoContent">
# <p>
# <span>
#                 투어
#                 <a href="tel:1588-3443">1588-3443</a>
# </span>
# <span>
#                 티켓
#                 <a href="tel:1544-1555">1544-1555</a>
# </span>
# </p>
# <p>
# <span>
#                 팩스
#                 <a href="tel:02-830-8295">02-830-8295</a>
# </span>
# <span>
#                 이메일
#                 <a href="mailto:intersolution@interparktriple.com">intersolution@interparktriple.com</a>
# </span>
# </p>
# <p>
#               개인정보보호책임자 <a href="mailto:cpo@interparktriple.com">cpo@interparktriple.com</a>
# </p>
# </div>
# </div>
# </div>
# <div class="footNotice">
# <p>(주)인터파크트리플은 항공사가 제공하는 개별 항공권 및 여행사가 제공하는 일부 여행상품에 대하여 통신판매중개자의 지위를 가지며, 해당상품, 상품정보, 거래에 관한
#           의무와 책임은 판매자에게 있습니다.</p>
# <p>항공권 또는 항공권이 포함된 경우, 표시되는 상품요금은 예상 유류할증료와 제세공과금이 포함된 가격이며, 발권일/환율 등에 따라 변동될 수 있습니다.</p>
# <p>(주)인터파크트리플은 인터파크티켓, 인터파크투어의 통신판매중개자로서 통신판매의 당사자가 아니므로, 개별 판매자가 등록한 오픈마켓 상품에 대해서 (주)인터파크트리플은 일체
#           책임을 지지 않습니다.</p>
# <p>Copyright ⓒ InterparkTriple Corp. All Rights Reserved.</p>
# </div>
# </footer>
# <!-- e: Footer 영역 -->
# <div id="divAccesskey" onclick="SetAccesskeyDivOff();" style="display:none; position: absolute; width: 270px; height: 200px; z-index: 50000; background-color: #FFFFC3; filter:Alpha(opacity=95); left:0px; top:125px; padding: 15px 0 0 0; cursor:pointer;">
# <span style="padding-left: 10px; color: #720000; font-size: 14px; font-family:돋움; font-weight:bold;">※ Access Key Tip</span>
# <ul style="color: #720000; font-size: 12px; font-family:돋움; font-weight:bold; ">
# <li>Tip : AccessKey + Enter</li>
# <li>Alt + 1 : 영화 메인</li>
# <li>Alt + 2 : 이전 페이지</li>
# <li>Alt + 3 : 다음 페이지</li>
# <li>Alt + 4 : 영화 예매 페이지</li>
# <li>Alt + 5 : 현재 상영작 페이지</li>
# <li>Alt + 6 : 개봉 예정작 페이지</li>
# <li>Alt + 7 : 극장 랭킹 페이지</li>
# <li>Alt + 8 : 영화 랭킹 페이지</li>
# <li>Alt + 9 : 이벤트 페이지</li>
# <li>Alt + 0 : Access Key Tip</li>
# </ul>
# </div>
# <form id="FormEventIcon" method="post" name="FormEventIcon">
# <input id="hidType" name="hidType" type="hidden" value=""/>
# <input id="hidApplyType" name="hidApplyType" type="hidden" value=""/>
# <input id="hidGroupCode" name="hidGroupCode" type="hidden" value=""/>
# </form>
# <iframe id="ifrEventIcon" name="ifrEventIcon" src="/Movie/blank.html" style="display:none"> </iframe>
# <style type="text/css">
# <!--
# .png24 {
#   tmp:expression(setPng24(this));
# }
# -->
# </style>
# <script type="text/javascript">
# 	function FloatingBannerDivOff() {
# 		document.getElementById("FloatingBannerDiv").style.display = "none";
# 	}
#
# 	function fnNoViewTMBanner(){
# 				document.getElementById('FloatingBannerDiv').style.display = 'none';
# 				setNoViewCookie("N");
# 			}
#
# 		// 하루 안보기 쿠키 설정
# 		function setNoViewCookie(value){
# 			var todayDate = new Date();
# 			todayDate.setDate( todayDate.getDate() + 1);
# 			document.domain = "interpark.com";
# 			document.cookie = "TMBnYN=" + value + "; path=/; domain=interpark.com; expires=" + todayDate.toGMTString() + ";"
# 		}
#
# <!--
# 	function SetAccesskeyDivOn() {
# 		document.getElementById("divAccesskey").style.display = "block";
# 	}
# 	function SetAccesskeyDivOff() {
# 		document.getElementById("divAccesskey").style.display = "none";
# 	}
#
# 	function EventGos() { //출석체크이벤트
# 		location.href = "http://movie.interpark.com/Movie/Event/2012/companyman.asp";
# 	}
#
# 	function EventIconCheck() {
#
# 		var vpara = "/Movie/Event/2013/dragonhunter.asp";
# 		window.open("http://Movie.interpark.com/Movie/Gate/TPLoginPop.asp?CPage=parent&GPage=" + escape(vpara), "LoginPopup", "width=300, height=180, left=400, top=400");
#
# 	}
#
# 	function DivIConClose() {
# 		document.getElementById("divEventIconX").style.display = "none";
# 	}
#
# 	function setPng24(obj) {
# 	  obj.width=obj.height=1;
# 	  obj.className=obj.className.replace(/\bpng24\b/i,'');
# 	  obj.style.filter = "progid:DXImageTransform.Microsoft.AlphaImageLoader(src='"+ obj.src +"',sizingMethod='image');"
# 	  obj.src='';
# 	  return '';
# 	}
#
# 	function bluring() {
# 		if(event.srcElement.tagName=="A"|| event.srcElement.tagName=="IMG")
# 			document.body.focus();
# 	}
# 	//document.onfocusin = bluring;
#
# 	function UnloadNotic() {
# 		/*
# 		if(self.screenTop > 9000) {
# 			window.open("http://Movie.interpark.com/Movie/popup/2011/oklasik.html", "UnloadPopup", "width=400, height=250, left=400, top=400");
# 		}
# 		*/
# 		if(window.event.clientY < 0 && (window.event.clientX > (document.documentElement.clientWidth - 5) || window.event.clientX < 15)) {
# 			window.open("http://Movie.interpark.com/Movie/popup/2011/oklasik.html", "UnloadPopup", "width=400, height=250, left=400, top=400");
# 		}
# 	}
#
# 	//window.onunload = UnloadNotic;
# 	//window.onbeforeunload = UnloadNotic;
#
# -->
#
#     function tourOpen() {
#         window.open("https://talk-tour.interpark.com/talk", "TalkTourPC", "width=480, height=790, toolbar=no, menubar=no, scrollbars=no, resizable=no");
#     }
#
#     function businessPerson() {
#         window.open("https://www.ftc.go.kr/bizCommPop.do?wrkr_no=8248102515&apv_perm_no=", "BusPC", "width=720, height=700, toolbar=no, menubar=no, scrollbars=no, resizable=no");
#     }
#
# </script>
# <!--211.233.74.118-->
# <!-- GA 태깅 -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5QCJFLB" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script src="https://movie.interpark.com/common/GA_Tracking/GA_Tracking.js" type="text/javascript"></script>
# <script language="javascript">
# <!--
#
#
# function Go(strGoodsCode, bBookable, strGoUrl)
# {
# 	if (strGoUrl.length > 1) {
# 		window.location.href = strGoUrl;
# 	}
# 	else {
# 		if ("Y" == bBookable) {
# 			window.location.href = "http://ticket.interpark.com/Ticket/Goods/GoodsInfo.asp?GoodsCode=" + strGoodsCode
# 		}
# 		else {
# 			window.location.href = "http://ticket.interpark.com/Ticket/Goods/GoodsInfo.asp?GoodsCode=" + strGoodsCode
# 		}
# 	}
# }
#
# function MovieGo(strGoodsCode, strGoUrl)
# {
# 	if (strGoUrl.length > 1) {
# 		window.location.href = strGoUrl;
# 	}
# 	else {
# 		window.location.href = "http://movie.interpark.com/Movie/Main/ImGoodsInfo.asp?GroupCode=" + strGoodsCode
# 	}
# }
#
# function OtherRankingGo()
# {
# 	if (MainForm.BDate.value != "") {
# 		MainForm.submit();
# 	}
# }
#
# function OtherRankingGoBDate(strBDate)
# {
# 	MainForm.BDate.value = strBDate;
# 	OtherRankingGo();
# }
#
#
# //-->
# </script>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","929060091512589");fbq("track","PageView");</script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=929060091512589&amp;ev=PageView
# &amp;noscript=1" width="1"/>
# </noscript>
# <script charset="UTF-8" id="" src="//t1.daumcdn.net/adfit/static/kp.js" type="text/javascript"></script><div style="display: none; visibility: hidden;">
# <script type="text/javascript">var TRS_AIDX=9308,TRS_DOMAIN="interpark.com",TRS_PROTOCOL=document.location.protocol;document.writeln();var TRS_URL=TRS_PROTOCOL+"//"+("https:"==TRS_PROTOCOL?"analysis.adinsight.co.kr":"adlog.adinsight.co.kr")+"/emnet/trs_esc.js";document.writeln("\x3cscript language\x3d'javascript' src\x3d'"+TRS_URL+"'\x3e\x3c/script\x3e");</script>
# <script language="javascript" src="http://adlog.adinsight.co.kr/emnet/trs_esc.js"></script>
# </div><script id="" type="text/javascript">(function(){var c=dataLayer,d=c.push;var a={IsIE:!1,IsEdge:!1,EdgeHtmlVersion:0,TrueVersion:0,ActingVersion:0,CompatibilityMode:!1};var b=navigator.userAgent.match(/Trident\/(\d+)/);b&&(a.IsIE=!0,a.TrueVersion=parseInt(b[1],10)+4);(b=navigator.userAgent.match(/MSIE (\d+)/))?(a.IsIE=!0,a.ActingVersion=parseInt(b[1])):a.ActingVersion=a.TrueVersion;a.IsIE&&0<a.TrueVersion&&0<a.ActingVersion&&(a.CompatibilityMode=a.TrueVersion!=a.ActingVersion);if(b=navigator.userAgent.match(/Edge\/(\d+\.\d+)$/))a.IsEdge=
# !0,a.EdgeHtmlVersion=b[1];d.call(c,{CD35:a.TrueVersion})})();</script><script id="" type="text/javascript">try{appboy.getUser().setCustomUserAttribute("PC_PageCategory","티켓_영화")}catch(a){};</script>
# <script id="" type="text/javascript">kakaoPixel("8709382144194201477").pageView();</script>
# </body></html>

# %%
movies = soup.select("tbody tr:nth-of-type(2) td:nth-of-type(2) a b")

movie_names = [movie.text for movie in movies]

name = []
for movie_name in movie_names:
    name.append(movie_name)

name
# Out:
# ['미니언즈2(디지털)',
#  '탑건: 매버릭(디지털)',
#  '외계＋인 1부(디지털)',
#  '헤어질 결심(디지털)',
#  '엘비스(디지털)',
#  '더 킬러: 죽어도 되는 아이(디지털)',
#  '토르: 러브 앤 썬더(디지털)',
#  '로스트 도터(디지털)',
#  '명탐정 코난: 할로윈의 신부(디지털)',
#  '범죄도시 2(디지털)']

# %%
ranks = []
updowns = []
for td in soup.find_all("td", attrs={"align": "center", "background": "http://ticketimage.interpark.com/TicketImage/fun/template/041207a_245_t20.gif", "height": "87", "width": "49"}):
    img_tag = td.find("img")

    if img_tag:
        text = td.get_text(strip=True)
        rank = re.sub(r'\([^)]*\)', '', text).strip()
        updown = "new"
    else:
        text = td.get_text(strip=True)
        rank = re.sub(r'\([^)]*\)', '', text).strip()
        updown = re.search(r'\((.*?)\)', text).group(1)

    ranks.append(rank)
    updowns.append(updown)

# %%
per = []
for td in soup.find_all("img", attrs={"height": "8"}):

    percent = td["width"]
    per.append(percent)

# %%
date_format = "%Y.%m.%d"
dates = []

for td in soup.find_all("td", attrs={"align": "center", "background": "http://ticketimage.interpark.com/TicketImage/fun/template/041207a_245_t20.gif", "width": "82"}):
    date_text = td.get_text(strip=True)
    date_text = datetime.strptime(date_text, date_format)
    date = date_text.strftime(date_format)
    dates.append(date)

# %%
data = {'순위': ranks, '순위증감': updowns, '영화제목': name, '예매점유율': per, '개봉일': dates}

df_weeks = pd.DataFrame(data)

df_weeks
# Out:
#     순위 순위증감                  영화제목  예매점유율         개봉일
# 0   1위  new            미니언즈2(디지털)  25.7%  2022.07.20
# 1   2위   -           탑건: 매버릭(디지털)  20.6%  2022.06.22
# 2   3위  new          외계＋인 1부(디지털)  20.1%  2022.07.20
# 3   4위   ▼3           헤어질 결심(디지털)  18.9%  2022.06.29
# 4   5위   ▼1              엘비스(디지털)   4.3%  2022.07.13
# 5   6위   ▼3  더 킬러: 죽어도 되는 아이(디지털)   3.0%  2022.07.13
# 6   7위   ▼2      토르: 러브 앤 썬더(디지털)   2.6%  2022.07.06
# 7   8위   ▼1           로스트 도터(디지털)   2.2%  2022.07.14
# 8   9위   ▼3  명탐정 코난: 할로윈의 신부(디지털)   1.9%  2022.10.28
# 9  10위   ▼1           범죄도시 2(디지털)   0.5%  2022.05.18

# %%
df_weeks['개봉일'] = df_weeks['개봉일'].str.replace('2022.10.28', '2022.07.13') # 재개봉으로 개봉일이 변경된 명탐정 코난 날짜 변경

df_weeks
# Out:
#     순위 순위증감                  영화제목  예매점유율         개봉일
# 0   1위  new            미니언즈2(디지털)  25.7%  2022.07.20
# 1   2위   -           탑건: 매버릭(디지털)  20.6%  2022.06.22
# 2   3위  new          외계＋인 1부(디지털)  20.1%  2022.07.20
# 3   4위   ▼3           헤어질 결심(디지털)  18.9%  2022.06.29
# 4   5위   ▼1              엘비스(디지털)   4.3%  2022.07.13
# 5   6위   ▼3  더 킬러: 죽어도 되는 아이(디지털)   3.0%  2022.07.13
# 6   7위   ▼2      토르: 러브 앤 썬더(디지털)   2.6%  2022.07.06
# 7   8위   ▼1           로스트 도터(디지털)   2.2%  2022.07.14
# 8   9위   ▼3  명탐정 코난: 할로윈의 신부(디지털)   1.9%  2022.07.13
# 9  10위   ▼1           범죄도시 2(디지털)   0.5%  2022.05.18

# %%
df_weeks = df_weeks.sort_values(by=['개봉일', '순위'], ascending=[True, False])

df_weeks
# Out:
#     순위 순위증감                  영화제목  예매점유율         개봉일
# 9  10위   ▼1           범죄도시 2(디지털)   0.5%  2022.05.18
# 1   2위   -           탑건: 매버릭(디지털)  20.6%  2022.06.22
# 3   4위   ▼3           헤어질 결심(디지털)  18.9%  2022.06.29
# 6   7위   ▼2      토르: 러브 앤 썬더(디지털)   2.6%  2022.07.06
# 8   9위   ▼3  명탐정 코난: 할로윈의 신부(디지털)   1.9%  2022.07.13
# 5   6위   ▼3  더 킬러: 죽어도 되는 아이(디지털)   3.0%  2022.07.13
# 4   5위   ▼1              엘비스(디지털)   4.3%  2022.07.13
# 7   8위   ▼1           로스트 도터(디지털)   2.2%  2022.07.14
# 2   3위  new          외계＋인 1부(디지털)  20.1%  2022.07.20
# 0   1위  new            미니언즈2(디지털)  25.7%  2022.07.20

# %%
driver.close()

# %%
@result_deco
def check_01(df: pd.core.frame.DataFrame):
    question_no, points = 0, 30

    condition_dict = {
        'condition01': len(df) == 10,
        'condition02': df.개봉일.is_monotonic_increasing,
        'condition03': df.iloc[-2:].순위.is_monotonic_decreasing,
        'condition04': df.순위증감.apply(lambda x: bool('(' in x)).sum() == 0,
        'condition05': (df.순위증감 == 'new').sum() == 2,
    }

    if sum(condition_dict.values()) == len(condition_dict):
        result = True
    else:
        result = False

    return question_no, points, result
check_01(df_weeks)
# Out:
# 정답입니다! 30점 누적 되었습니다!
# 현재 누적 점수: 30 / 100

# %% [markdown]
# ## 2단계: Web Crawling & DataFrame 만들기 02
# ***

# %% [markdown]
# ### 문제 2) Web Crawling: 더 많은 Data 가져오기 (40점)
# - 1단계의 문제1에서 DataFrame을 만들었던 과정을 참고하여 아래 조건에 맞게 DataFrame(df_target)을 만드세요.
# <br></br>
#     - 기준 주(weeks): "2021년 8월 12일 (목) ~ 8월 15일 (일)" 부터 "2022년 7월 21일(목) ~ 7월 24일 (일)" 까지 50주(weeks)
# <br></br>
#     - 조건1: 1단계 문제1을 참고하여 '기준 주(weeks)'에 해당하는 50주(weeks)의 [영화 Top10]의 표(Table) Data를 Crawling 하세요.
#         - 앞서 언급하였다시피 해당 Page는 Post 방식 입니다.
#         - 해당 표(Table)안의 Data 중 string Data만 가져오면 됩니다(Image Data는 필요 없습니다.)
# <br></br>
#     - 조건2: 결과 DataFrame의 Column은 ['순위', '순위증감', '영화제목', '예매점유율', '개봉일', '주'] 입니다.
#         - 아래 columns로 할당된 변수를 참고하세요.
# <br></br>
#     - 조건3: 1단계 문제 1의 조건3, 조건4, 조건5 이상 세 개의 조건은 이 문제에 동일하게 적용됩니다.
# <br></br>
#     - 조건4: '개봉일' Column(열)의 Data에서 "."를 모두 제거하세요.
#         - 예시: 2022.07.22 -> 20220722
# <br></br>
#     - 조건5: '주' Column(열)의 Data는 해당 Data 기준 주(week)의 시작일입니다.
# <br></br>
#         - 예시: 2021년 8월 12일 (목) ~ 8월 15일 (일) 주(week)
# <br></br>
#         <img src="images/07-2-1-001.png" style="margin:auto" width=500/>
# <br></br>
#     - 조건6: 결과 DataFrame은 '주' Column(열) Data를 기준으로 오름차순으로 정렬하고, 동일한 '주' Column(열) Data에 대해서는 '순위'를 기준으로 오름차순으로 정렬해주세요. 이후 Index는 초기화 해 주세요.
# <br></br>
#     - 조건7: 'df_target' 변수에 결과 DataFrame을 할당하세요.
# <br></br>
# <br></br>
#     - hint1: pandas 기능 중 일정기간 혹은 횟수 동안 특정 요일의 날짜들을 반환하는 함수가 있습니다.
# <br></br>
#     - hint2: 특정 시점 이전에는 crawling 위치가 변할 수 있습니다. Crawling시 Error가 발생했다면 한 번 확인해보세요.
# <br></br>
# <br></br>
#     - 주의사항: 빠른 시간 내에 너무 자주 Data를 Crawling할 경우 Error 발생할 수 있습니다.
#         - 반복문을 통해 Crawling을 할 때 time.sleep 등의 방법을 이용하여 한번의 crawling 당 최소 0.1초 이상의 간격 두는 것을 추천합니다.
# <br></br>
# <br></br>
# - 완료 후 결과 DataFrame 변수(df_target)를 check_02 함수에 입력하여 채점하세요.

# %%
url = "http://movie.interpark.com/Community/Movie/Ranking/Ranking_Report.asp"
driver = webdriver.Chrome(executable_path="./driver/chromedriver")
driver.get(url)
# Out:
# /var/folders/vv/y6j7wgsn1t1dxty1kfg6bcbm0000gn/T/ipykernel_21853/2728624288.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="./driver/chromedriver")

# %%
dates = pd.date_range("2021.08.12","2022.07.21",freq='7D')
result = dates.strftime("%Y.%m.%d")

# %%
weeks_list = []
names = []
ranks = []
updowns = []
per = []
times = []
date_format = "%Y.%m.%d"

for date in result:

    select_date_but = driver.find_element(By.CSS_SELECTOR, "body > table > tbody > tr:nth-child(2) > td:nth-child(3) > table > tbody > tr > td > table:nth-child(4) > tbody > tr:nth-child(2) > td > table:nth-child(1) > tbody > tr:nth-child(3) > td > form > select")
    select_date_but.send_keys(date)

    time.sleep(3)

    driver.page_source

    req = driver.page_source
    soup = BeautifulSoup(req, "html.parser")

    movies = soup.select("tbody tr:nth-of-type(2) td:nth-of-type(2) a b")
    movie_names = [movie.text for movie in movies]

    for movie_name in movie_names:
        names.append(movie_name)


    for td in soup.find_all("td", attrs={"align": "center", "background": "http://ticketimage.interpark.com/TicketImage/fun/template/041207a_245_t20.gif", "height": "87", "width": "49"}):
        img_tag = td.find("img")

        if img_tag:
            text = td.get_text(strip=True)
            rank = re.sub(r'\([^)]*\)', '', text).strip()
            updown = "new"
        else:
            text = td.get_text(strip=True)
            rank = re.sub(r'\([^)]*\)', '', text).strip()
            updown = re.search(r'\((.*?)\)', text).group(1)

        ranks.append(rank)
        updowns.append(updown)


    for td in soup.find_all("img", attrs={"height": "8"}):
        percent = td["width"]
        per.append(percent)


    for td in soup.find_all("td", attrs={"align": "center", "background": "http://ticketimage.interpark.com/TicketImage/fun/template/041207a_245_t20.gif", "width": "82"}):
        date_text = td.get_text(strip=True)
        if date_text == "0000..":
            date_text = "0000.."
            weeks_list.append(date)
        else:
            date_text = datetime.strptime(date_text, date_format)
            date_text = date_text.strftime(date_format)
            weeks_list.append(date)
        times.append(date_text)

# %%
driver.close()

# %%
data = {'순위': ranks, '순위증감': updowns, '영화제목': names, '예매점유율': per, '개봉일': times, '주': weeks_list}

df_target = pd.DataFrame(data)

df_target
# Out:
#       순위 순위증감                       영화제목  예매점유율         개봉일           주
# 0     1위  new                  싱크홀(2021)  66.1%  2021.08.11  2021.08.12
# 1     2위   ▼1                  모가디슈(디지털)  20.1%  2022.09.07  2021.08.12
# 2     3위   ▼1               보스 베이비2(디지털)   5.2%  2021.07.21  2021.08.12
# 3     4위  new                 프리 가이(디지털)   2.7%  2021.08.11  2021.08.12
# 4     5위   ▼1  극장판 도라에몽: 진구의 신공룡(디지털 더빙)   1.5%  2021.08.05  2021.08.12
# ..   ...  ...                        ...    ...         ...         ...
# 495   6위   ▼3       더 킬러: 죽어도 되는 아이(디지털)   3.0%  2022.07.13  2022.07.21
# 496   7위   ▼2           토르: 러브 앤 썬더(디지털)   2.6%  2022.07.06  2022.07.21
# 497   8위   ▼1                로스트 도터(디지털)   2.2%  2022.07.14  2022.07.21
# 498   9위   ▼3       명탐정 코난: 할로윈의 신부(디지털)   1.9%  2022.10.28  2022.07.21
# 499  10위   ▼1                범죄도시 2(디지털)   0.5%  2022.05.18  2022.07.21
#
# [500 rows x 6 columns]

# %%
def remove_dots(text):
    return text.replace(".", "")

df_target['개봉일'] = df_target['개봉일'].apply(remove_dots)
df_target['주'] = df_target['주'].apply(remove_dots)

df_target
# Out:
#       순위 순위증감                       영화제목  예매점유율       개봉일         주
# 0     1위  new                  싱크홀(2021)  66.1%  20210811  20210812
# 1     2위   ▼1                  모가디슈(디지털)  20.1%  20220907  20210812
# 2     3위   ▼1               보스 베이비2(디지털)   5.2%  20210721  20210812
# 3     4위  new                 프리 가이(디지털)   2.7%  20210811  20210812
# 4     5위   ▼1  극장판 도라에몽: 진구의 신공룡(디지털 더빙)   1.5%  20210805  20210812
# ..   ...  ...                        ...    ...       ...       ...
# 495   6위   ▼3       더 킬러: 죽어도 되는 아이(디지털)   3.0%  20220713  20220721
# 496   7위   ▼2           토르: 러브 앤 썬더(디지털)   2.6%  20220706  20220721
# 497   8위   ▼1                로스트 도터(디지털)   2.2%  20220714  20220721
# 498   9위   ▼3       명탐정 코난: 할로윈의 신부(디지털)   1.9%  20221028  20220721
# 499  10위   ▼1                범죄도시 2(디지털)   0.5%  20220518  20220721
#
# [500 rows x 6 columns]

# %%
for idx, row in df_target.iterrows():
    df_target.loc[idx, '순위'] = int(row['순위'][:-1])

df_target
# Out:
#      순위 순위증감                       영화제목  예매점유율       개봉일         주
# 0     1  new                  싱크홀(2021)  66.1%  20210811  20210812
# 1     2   ▼1                  모가디슈(디지털)  20.1%  20220907  20210812
# 2     3   ▼1               보스 베이비2(디지털)   5.2%  20210721  20210812
# 3     4  new                 프리 가이(디지털)   2.7%  20210811  20210812
# 4     5   ▼1  극장판 도라에몽: 진구의 신공룡(디지털 더빙)   1.5%  20210805  20210812
# ..   ..  ...                        ...    ...       ...       ...
# 495   6   ▼3       더 킬러: 죽어도 되는 아이(디지털)   3.0%  20220713  20220721
# 496   7   ▼2           토르: 러브 앤 썬더(디지털)   2.6%  20220706  20220721
# 497   8   ▼1                로스트 도터(디지털)   2.2%  20220714  20220721
# 498   9   ▼3       명탐정 코난: 할로윈의 신부(디지털)   1.9%  20221028  20220721
# 499  10   ▼1                범죄도시 2(디지털)   0.5%  20220518  20220721
#
# [500 rows x 6 columns]

# %%
df_target.sort_values(by=['주', '순위'], ascending=[True, True], inplace=True)

df_target.reset_index(drop=True, inplace=True)
df_target
# Out:
#      순위 순위증감                       영화제목  예매점유율       개봉일         주
# 0     1  new                  싱크홀(2021)  66.1%  20210811  20210812
# 1     2   ▼1                  모가디슈(디지털)  20.1%  20220907  20210812
# 2     3   ▼1               보스 베이비2(디지털)   5.2%  20210721  20210812
# 3     4  new                 프리 가이(디지털)   2.7%  20210811  20210812
# 4     5   ▼1  극장판 도라에몽: 진구의 신공룡(디지털 더빙)   1.5%  20210805  20210812
# ..   ..  ...                        ...    ...       ...       ...
# 495   6   ▼3       더 킬러: 죽어도 되는 아이(디지털)   3.0%  20220713  20220721
# 496   7   ▼2           토르: 러브 앤 썬더(디지털)   2.6%  20220706  20220721
# 497   8   ▼1                로스트 도터(디지털)   2.2%  20220714  20220721
# 498   9   ▼3       명탐정 코난: 할로윈의 신부(디지털)   1.9%  20221028  20220721
# 499  10   ▼1                범죄도시 2(디지털)   0.5%  20220518  20220721
#
# [500 rows x 6 columns]

# %%
df_target['순위'] = df_target['순위'].apply(lambda x: str(x) + "위")
df_target
# Out:
#       순위 순위증감                       영화제목  예매점유율       개봉일         주
# 0     1위  new                  싱크홀(2021)  66.1%  20210811  20210812
# 1     2위   ▼1                  모가디슈(디지털)  20.1%  20220907  20210812
# 2     3위   ▼1               보스 베이비2(디지털)   5.2%  20210721  20210812
# 3     4위  new                 프리 가이(디지털)   2.7%  20210811  20210812
# 4     5위   ▼1  극장판 도라에몽: 진구의 신공룡(디지털 더빙)   1.5%  20210805  20210812
# ..   ...  ...                        ...    ...       ...       ...
# 495   6위   ▼3       더 킬러: 죽어도 되는 아이(디지털)   3.0%  20220713  20220721
# 496   7위   ▼2           토르: 러브 앤 썬더(디지털)   2.6%  20220706  20220721
# 497   8위   ▼1                로스트 도터(디지털)   2.2%  20220714  20220721
# 498   9위   ▼3       명탐정 코난: 할로윈의 신부(디지털)   1.9%  20221028  20220721
# 499  10위   ▼1                범죄도시 2(디지털)   0.5%  20220518  20220721
#
# [500 rows x 6 columns]

# %%
@result_deco
def check_02(df: pd.core.frame.DataFrame):
    question_no, points = 1, 30

    condition_dict = {
        'condition01': len(df) == 500,
        'condition02': df.주.is_monotonic_increasing,
        'condition03': df.순위.iloc[:10].apply(lambda x: int(x[:-1])).is_monotonic_increasing,
        'condition04': df.index.is_monotonic_increasing,
        'condition05': (df.순위증감 == 'new').sum() == 194,
    }

    if sum(condition_dict.values()) == len(condition_dict):
        result = True
    else:
        result = False

    return question_no, points, result

check_02(df_target)
# Out:
# 정답입니다! 30점 누적 되었습니다!
# 현재 누적 점수: 60 / 100

# %% [markdown]
# ## 3단계: 원하는 정보 얻기
# ***

# %% [markdown]
# ### 문제 3-1) 원하는 정보 얻기 01 (20점)
# - 2단계의 DataFrame(df_target)을 이용하여 아래의 조건에 맞는 정보를 구하세요.
# <br></br>
#     - 2단계의 DataFrame(df_target)에서 오랫동안(6번 이상 == 6주 이상) 예매점유율 Top10에 올랐던 영화를 찾아보고자 합니다.
# <br></br>
# <br></br>
#     - 조건1: 6주(6번) 이상 Top10에 올랐던 영화 제목을 구하세요.
# <br></br>
#     - 조건2: '빈도' Column(열)을 만들어 해당 Column(열)에 몇 번(몇 주) Top10에 올랐는지 입력해 주세요.
# <br></br>
#     - 조건3: Index는 '영화제목'으로 해주세요.
# <br></br>
#     - 조건4: '빈도'를 기준으로 내림차순으로 정렬하고, 동일한 '빈도'일 경우 '영화제목'을 기준으로 오름차순으로 정렬해 주세요.
# <br></br>
#         - 예시: 다음 예시는 '빈도' 기준 오름차순, '빈도'가 동일할경우 '영화제목'으로 내림차순한 가상의 내용입니다.
# <br></br>
#         <img src="images/07-3-1-001.png" style="margin:auto" width=200/>
# <br></br>
#     - 조건4: 'df_result' 변수에 결과 DataFrame을 할당하세요.
# <br></br>
# <br></br>
# - 완료 후 결과 dataframe 변수(df_result)를 check_03_01 함수에 입력하여 채점하세요.

# %%
df_target
# Out:
#       순위 순위증감                       영화제목  예매점유율       개봉일         주
# 0     1위  new                  싱크홀(2021)  66.1%  20210811  20210812
# 1     2위   ▼1                  모가디슈(디지털)  20.1%  20220907  20210812
# 2     3위   ▼1               보스 베이비2(디지털)   5.2%  20210721  20210812
# 3     4위  new                 프리 가이(디지털)   2.7%  20210811  20210812
# 4     5위   ▼1  극장판 도라에몽: 진구의 신공룡(디지털 더빙)   1.5%  20210805  20210812
# ..   ...  ...                        ...    ...       ...       ...
# 495   6위   ▼3       더 킬러: 죽어도 되는 아이(디지털)   3.0%  20220713  20220721
# 496   7위   ▼2           토르: 러브 앤 썬더(디지털)   2.6%  20220706  20220721
# 497   8위   ▼1                로스트 도터(디지털)   2.2%  20220714  20220721
# 498   9위   ▼3       명탐정 코난: 할로윈의 신부(디지털)   1.9%  20221028  20220721
# 499  10위   ▼1                범죄도시 2(디지털)   0.5%  20220518  20220721
#
# [500 rows x 6 columns]

# %%
df_result = pd.DataFrame(pd.pivot_table(data=df_target, index='영화제목', values='주', aggfunc=len))
df_result.reset_index(inplace=True)
df_result = df_result[df_result["주"] >= 6]
df_result.sort_values(by="주", inplace=True, ascending=False)
df_result.rename(columns={'주' : '빈도'}, inplace=True)
df_result.set_index('영화제목', inplace=True)

df_result
# Out:
#                                      빈도
# 영화제목
# 스파이더맨: 노 웨이 홈(디지털)                   12
# 범죄도시 2(디지털)                          11
# 듄(디지털)                                8
# 싱크홀(2021)                             8
# 보이스(2021)                             7
# 씽2게더(디지털)                             7
# 모가디슈(디지털)                             7
# 극장판 주술회전 0(디지털)                       7
# 신비한 동물들과 덤블도어의 비밀(디지털)                7
# 탑건: 매버릭(디지털)                          6
# 쥬라기 월드: 도미니언(디지털)                     6
# 엔칸토: 마법의 세계(디지털)                      6
# 007 노 타임 투 다이(디지털)                    6
# 닥터 스트레인지: 대혼돈의 멀티버스(디지털)              6
# 기적(디지털)                               6
# 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미(디지털)   6
# 특송(디지털)                               6

# %%
@result_deco
def check_03_01(df: pd.core.frame.DataFrame):
    question_no, points = 2, 20

    condition_dict = {
        'condition01': df.duplicated(keep=False).sum() == 15,
        'condition02': df[df.빈도 == 6].빈도.is_monotonic_increasing,
        'condition03': df.빈도.to_list()[:3] == [12, 11, 8],
        'condition04': sum([bool('(디지털)' not in idx) for idx in df.index]) == 2,
        'condition05': df.index[3] == '싱크홀(2021)',
    }

    if sum(condition_dict.values()) == len(condition_dict):
        result = True
    else:
        result = False

    return question_no, points, result

check_03_01(df_result)
# Out:
# 정답입니다! 20점 누적 되었습니다!
# 현재 누적 점수: 80 / 100

# %% [markdown]
# ### 문제 3-2) 원하는 정보 얻기 02 (20점)
# - 2단계의 DataFrame(df_target)을 이용하여 아래의 조건에 맞는 정보를 구하세요.
# <br></br>
#     - 2단계의 DataFrame(df_target)에서 Top10에 오른 기간 동안 예매점유율의 평균을 구해보고자 합니다.
# <br></br>
# <br></br>
#     - 조건1: 각 '영화제목' 당 '예매점유율'의 평균을 구하세요
# <br></br>
#     - 조건2: '예매점유율' Column(열)에 조건1에서 구한 '예매점유율'의 평균을 입력해 주세요.
#         - '예매점유율' Column(열) Data는 소숫점 세 자리수에서 반올림하여 두자리수까지 표기한 후 '%'를 붙여주세요.
# <br></br>
#         - 예시
# <br></br>
#         <img src="images/07-3-2-001.png" style="margin:auto" width=200/>
# <br></br>
#     - 조건3: Index는 '영화제목'으로 해주세요.
# <br></br>
#     - 조건4: '예매점유율'를 기준으로 내림차순으로 정렬하고, 동일한 '예매점유율'일 경우 '영화제목'을 기준으로 오름차순으로 정렬해 주세요.
#         - 문제 3-1의 조건4 예시를 참고해주세요.
# <br></br>
#     - 조건4: 'df_result' 변수에 결과 DataFrame을 할당하세요.
# <br></br>
# <br></br>
# - 완료 후 결과 dataframe 변수(df_result)를 check_03_02 함수에 입력하여 채점하세요.

# %%
df_target
# Out:
#       순위 순위증감                       영화제목  예매점유율       개봉일         주
# 0     1위  new                  싱크홀(2021)  66.1%  20210811  20210812
# 1     2위   ▼1                  모가디슈(디지털)  20.1%  20220907  20210812
# 2     3위   ▼1               보스 베이비2(디지털)   5.2%  20210721  20210812
# 3     4위  new                 프리 가이(디지털)   2.7%  20210811  20210812
# 4     5위   ▼1  극장판 도라에몽: 진구의 신공룡(디지털 더빙)   1.5%  20210805  20210812
# ..   ...  ...                        ...    ...       ...       ...
# 495   6위   ▼3       더 킬러: 죽어도 되는 아이(디지털)   3.0%  20220713  20220721
# 496   7위   ▼2           토르: 러브 앤 썬더(디지털)   2.6%  20220706  20220721
# 497   8위   ▼1                로스트 도터(디지털)   2.2%  20220714  20220721
# 498   9위   ▼3       명탐정 코난: 할로윈의 신부(디지털)   1.9%  20221028  20220721
# 499  10위   ▼1                범죄도시 2(디지털)   0.5%  20220518  20220721
#
# [500 rows x 6 columns]

# %%
df_result = df_target

# %%
for idx, row in df_result.iterrows():
    df_result.loc[idx, '예매점유율'] = float(row['예매점유율'][:-1])

df_result
# Out:
#       순위 순위증감                       영화제목 예매점유율       개봉일         주
# 0     1위  new                  싱크홀(2021)  66.1  20210811  20210812
# 1     2위   ▼1                  모가디슈(디지털)  20.1  20220907  20210812
# 2     3위   ▼1               보스 베이비2(디지털)   5.2  20210721  20210812
# 3     4위  new                 프리 가이(디지털)   2.7  20210811  20210812
# 4     5위   ▼1  극장판 도라에몽: 진구의 신공룡(디지털 더빙)   1.5  20210805  20210812
# ..   ...  ...                        ...   ...       ...       ...
# 495   6위   ▼3       더 킬러: 죽어도 되는 아이(디지털)   3.0  20220713  20220721
# 496   7위   ▼2           토르: 러브 앤 썬더(디지털)   2.6  20220706  20220721
# 497   8위   ▼1                로스트 도터(디지털)   2.2  20220714  20220721
# 498   9위   ▼3       명탐정 코난: 할로윈의 신부(디지털)   1.9  20221028  20220721
# 499  10위   ▼1                범죄도시 2(디지털)   0.5  20220518  20220721
#
# [500 rows x 6 columns]

# %%
df_result['예매점유율']=df_result['예매점유율'].astype('float')

# %%
df_result = pd.pivot_table(data=df_result, index='영화제목', values='예매점유율', aggfunc='mean')
df_result = pd.DataFrame(df_result)
df_result.reset_index(inplace=True)
df_result['예매점유율'] = round(df_result['예매점유율'], 2)

df_result
# Out:
#                    영화제목  예매점유율
# 0    007 노 타임 투 다이(디지털)  20.38
# 1       4월은 너의 거짓말(디지털)   1.90
# 2           가치 캅시다(디지털)   5.10
# 3            감동주의보(디지털)   1.70
# 4               강릉(디지털)   5.53
# ..                  ...    ...
# 181             핸썸(디지털)   1.10
# 182         헤어질 결심(디지털)  30.58
# 183         화양연화(리마스터링)   1.00
# 184        후겟츠 웨슬리(디지털)   1.90
# 185             히든(디지털)   1.30
#
# [186 rows x 2 columns]

# %%
df_result.sort_values(by='예매점유율', ascending=False, inplace=True)
df_result
# Out:
#                       영화제목  예매점유율
# 82   베놈 2: 렛 데어 비 카니지(디지털)  38.70
# 182            헤어질 결심(디지털)  30.58
# 115              싱크홀(2021)  30.56
# 125              언차티드(디지털)  30.42
# 81             범죄도시 2(디지털)  28.35
# ..                     ...    ...
# 91             블랙 위도우(디지털)   0.25
# 166   토르: 마법 검의 전설(디지털 더빙)   0.20
# 29           나를 만나는 길(디지털)   0.10
# 156             컴온 컴온(디지털)   0.10
# 154             카시오페아(디지털)   0.10
#
# [186 rows x 2 columns]

# %%
df_result['예매점유율'] = df_result['예매점유율'].apply(lambda x: "{:.2f}%".format(x))
df_result.set_index('영화제목', inplace=True)

df_result
# Out:
#                         예매점유율
# 영화제목
# 베놈 2: 렛 데어 비 카니지(디지털)  38.70%
# 헤어질 결심(디지털)            30.58%
# 싱크홀(2021)              30.56%
# 언차티드(디지털)              30.42%
# 범죄도시 2(디지털)            28.35%
# ...                       ...
# 블랙 위도우(디지털)             0.25%
# 토르: 마법 검의 전설(디지털 더빙)    0.20%
# 나를 만나는 길(디지털)           0.10%
# 컴온 컴온(디지털)              0.10%
# 카시오페아(디지털)              0.10%
#
# [186 rows x 1 columns]

# %%
@result_deco
def check_03_02(df: pd.core.frame.DataFrame):
    question_no, points = 3, 20

    condition_dict = {
        'condition01': df.예매점유율.duplicated(keep=False).sum() == 88,
        'condition02': df[df.예매점유율 == '0.70%'].index.is_monotonic_increasing,
        'condition03': df.iloc[25, 0] == '14.00%',
        'condition04': df.예매점유율.apply(lambda x: float(x.replace('%', ''))).is_monotonic_decreasing,
        'condition05': df.예매점유율.apply(lambda x: len(x[x.find('.')+1:-1]) != 2).sum() == 0,
    }

    if sum(condition_dict.values()) == len(condition_dict):
        result = True
    else:
        result = False

    return question_no, points, result
check_03_02(df_result)
# Out:
# 정답입니다! 20점 누적 되었습니다!
# 현재 누적 점수: 100 / 100

# %% [markdown]
# ***
#
# ### 🎊 문제가 끝났습니다. 제출양식과 일정에 맞춰 제출해주시기를 바랍니다!
#
# ### 제출양식
# - 이 파일은 EDA TEST 7회차 노트북입니다. 따라서 제출시 파일명은 아래와 같습니다.
# - [DS]edalvtest_07_yourname.ipynb
#
# ***

# %% [markdown]
# # 문의사항 및 의견이 있는 경우 작성해주세요.

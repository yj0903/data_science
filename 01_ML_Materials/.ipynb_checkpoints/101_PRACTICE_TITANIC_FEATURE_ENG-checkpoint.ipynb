# %% [markdown]
# <div class="alert alert-block" style="border: 1px solid #455A64;background-color:#ECEFF1;">
# 본 자료 및 영상 컨텐츠는 저작권법 제25조 2항에 의해 보호를 받습니다. 본 컨텐츠 및 컨텐츠 일부 문구등을 외부에 공개, 게시하는 것을 금지합니다. 특히 자료에 대해서는 저작권법을 엄격하게 적용하겠습니다.
# </div>

# %% [markdown]
# ### Feature Engineering: Feature Transformation Practice

# %%
import pandas as pd
import chart_studio.plotly as py
import cufflinks as cf
cf.go_offline(connected=True)

train = pd.read_csv('titanic/train.csv')
test = pd.read_csv('titanic/test.csv')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### 1. 합치기

# %%
ntrain = train.shape[0]
ntest = test.shape[0]
df = pd.concat((train, test))

# %%
ntest
# Out:
# 418

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# > Sex, Embarked 는 쉽기 때문에, 먼저 진행

# %% [markdown]
# ### 2. Sex 숫자 변환

# %%
df["Sex"].isnull().sum()
# Out:
# 0

# %%
gender = { "male": 0, "female": 1 }
df['Sex'] = df['Sex'].map(gender)

# %% [markdown]
# ### 3. Pclass 는 변경할 필요 없음
# - Pclass 값이 1, 2, 3

# %% [markdown]
# ### 4. Embarked 정보를 숫자로 바꾸기

# %%
df['Embarked'].isnull().sum() # 결측치 확인
# Out:
# 2

# %%
df['Embarked'].value_counts() # level 값 확인
# Out:
# S    914
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
df.loc[(df['Embarked'].isnull())]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62       1.0       1                        Icard, Miss. Amelie
# 829          830       1.0       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#      Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61     1  38.0      0      0  113572  80.0   B28      NaN
# 829    1  62.0      0      0  113572  80.0   B28      NaN

# %%
df.sort_values(['Ticket'], ascending = True)[55:70]
# Out:
#      PassengerId  Survived  Pclass  \
# 54            55       0.0       1
# 351          352       0.0       1
# 252          253       0.0       1
# 829          830       1.0       1
# 61            62       1.0       1
# 802          803       1.0       1
# 390          391       1.0       1
# 435          436       1.0       1
# 763          764       1.0       1
# 185          186       0.0       1
# 182         1074       NaN       1
# 748          749       0.0       1
# 151          152       1.0       1
# 336          337       0.0       1
# 41           933       NaN       1
#
#                                                   Name  Sex   Age  SibSp  \
# 54                      Ostby, Mr. Engelhart Cornelius    0  65.0      0
# 351             Williams-Lambert, Mr. Fletcher Fellows    0   NaN      0
# 252                          Stead, Mr. William Thomas    0  62.0      0
# 829          Stone, Mrs. George Nelson (Martha Evelyn)    1  62.0      0
# 61                                 Icard, Miss. Amelie    1  38.0      0
# 802                Carter, Master. William Thornton II    0  11.0      1
# 390                         Carter, Mr. William Ernest    0  36.0      1
# 435                          Carter, Miss. Lucile Polk    1  14.0      1
# 763          Carter, Mrs. William Ernest (Lucile Polk)    1  36.0      1
# 185                              Rood, Mr. Hugh Roscoe    0   NaN      0
# 182  Marvin, Mrs. Daniel Warner (Mary Graham Carmic...    1  18.0      1
# 748                          Marvin, Mr. Daniel Warner    0  19.0      1
# 151                  Pears, Mrs. Thomas (Edith Wearne)    1  22.0      1
# 336                          Pears, Mr. Thomas Clinton    0  29.0      1
# 41                         Franklin, Mr. Thomas Parham    0   NaN      0
#
#      Parch  Ticket      Fare    Cabin Embarked
# 54       1  113509   61.9792      B30        C
# 351      0  113510   35.0000     C128        S
# 252      0  113514   26.5500      C87        S
# 829      0  113572   80.0000      B28      NaN
# 61       0  113572   80.0000      B28      NaN
# 802      2  113760  120.0000  B96 B98        S
# 390      2  113760  120.0000  B96 B98        S
# 435      2  113760  120.0000  B96 B98        S
# 763      2  113760  120.0000  B96 B98        S
# 185      0  113767   50.0000      A32        S
# 182      0  113773   53.1000      D30        S
# 748      0  113773   53.1000      D30        S
# 151      0  113776   66.6000       C2        S
# 336      0  113776   66.6000       C2        S
# 41       0  113778   26.5500      D34        S

# %%
df.loc[(df['Embarked'].isnull()), 'Embarked'] = 'S'

# %%
df_temp1 = df.copy()

# %%
gender = { "S": 0, "C": 1, "Q":2 }
df_temp1['Embarked'] = df_temp1['Embarked'].map(gender)

# %%
df_temp1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked
# 0         A/5 21171   7.2500   NaN         0
# 1          PC 17599  71.2833   C85         1
# 2  STON/O2. 3101282   7.9250   NaN         0
# 3            113803  53.1000  C123         0
# 4            373450   8.0500   NaN         0

# %% [markdown]
# ### 참고: pandas.factorize()
# - 데이터의 범주가 많아서, 일일이 각 데이터를 숫자로 기재해주기 어려운 경우에 사용

# %%
df_temp2 = df.copy()

# %%
df_temp2['Embarked'].factorize()
# Out:
# (array([0, 1, 0, ..., 0, 0, 1]), Index(['S', 'C', 'Q'], dtype='object'))

# %%
df_temp2['Embarked'].factorize()[0]
# Out:
# array([0, 1, 0, ..., 0, 0, 1])

# %%
df_temp2['Embarked'] = df_temp2['Embarked'].factorize()[0]

# %%
df_temp2['Embarked'].value_counts() # level 값 확인
# Out:
# 0    916
# 1    270
# 2    123
# Name: Embarked, dtype: int64

# %% [markdown]
# ### 각 범주의 의미를 기록해놓기 위해, 직접 기입하기로 함

# %%
gender = { "S": 0, "C": 1, "Q":2 }
df['Embarked'] = df['Embarked'].map(gender)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked
# 0         A/5 21171   7.2500   NaN         0
# 1          PC 17599  71.2833   C85         1
# 2  STON/O2. 3101282   7.9250   NaN         0
# 3            113803  53.1000  C123         0
# 4            373450   8.0500   NaN         0

# %% [markdown]
# ### 5. Name
# - 참고: 여기서 부터 시작한다면, 처음부터 여기까지 코드 실행을 한 후에, 진행해야 df 에 지금까지 변환된 데이터프레임이 들어감

# %%
df['Initial'] = df.Name.str.extract('([A-Za-z]+)\.')

# %%
df['Initial'].value_counts()
# Out:
# Mr          757
# Miss        260
# Mrs         197
# Master       61
# Dr            8
# Rev           8
# Col           4
# Major         2
# Mlle          2
# Ms            2
# Countess      1
# Dona          1
# Mme           1
# Lady          1
# Jonkheer      1
# Sir           1
# Capt          1
# Don           1
# Name: Initial, dtype: int64

# %% [markdown]
# - Ms. 는 당시에는 귀족 미망인을 의미함
# - Mlle나 Mme등도 마드모아젤과 마담의 줄인말로, 귀족 여성을 의미함
# - Countess 는 백작 부인을 의미하므로, 귀족 여성을 의미함
# - Lady 도 귀족 부인을 의미함

# %%
df[(df['Initial'] == 'Mme') | (df['Initial'] == 'Mlle') | (df['Initial'] == 'Ms') | (df['Initial'] == 'Countess') | (df['Initial'] == 'Lady')]
# Out:
#      PassengerId  Survived  Pclass  \
# 369          370       1.0       1
# 443          444       1.0       2
# 556          557       1.0       1
# 641          642       1.0       1
# 710          711       1.0       1
# 759          760       1.0       1
# 88           980       NaN       3
#
#                                                   Name  Sex   Age  SibSp  \
# 369                      Aubart, Mme. Leontine Pauline    1  24.0      0
# 443                          Reynaldo, Ms. Encarnacion    1  28.0      0
# 556  Duff Gordon, Lady. (Lucille Christiana Sutherl...    1  48.0      1
# 641                               Sagesser, Mlle. Emma    1  24.0      0
# 710   Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")    1  24.0      0
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...    1  33.0      0
# 88                             O'Donoghue, Ms. Bridget    1   NaN      0
#
#      Parch    Ticket     Fare Cabin  Embarked   Initial
# 369      0  PC 17477  69.3000   B35         1       Mme
# 443      0    230434  13.0000   NaN         0        Ms
# 556      0     11755  39.6000   A16         1      Lady
# 641      0  PC 17477  69.3000   B35         1      Mlle
# 710      0  PC 17482  49.5042   C90         1      Mlle
# 759      0    110152  86.5000   B77         0  Countess
# 88       0    364856   7.7500   NaN         2        Ms

# %%
df.loc[(df['Initial'] == 'Mme') | (df['Initial'] == 'Mlle') | (df['Initial'] == 'Ms') | (df['Initial'] == 'Countess') | (df['Initial'] == 'Lady'), 'Initial'] = 'Lady'

# %%
title_mapping = {'Mr': 0, 'Miss': 1, 'Mrs': 2, 'Master': 3, 'Lady': 4, 'Don': 5, 'Rev': 6, 'Dr': 7, 
                 'Major': 8, 'Sir': 9, 'Col': 10,  'Capt': 11, 'Jonkheer': 12}
df['Initial'] = df['Initial'].map(title_mapping)

# %%
df[df['Initial'] == 3]
# Out:
#      PassengerId  Survived  Pclass                                Name  Sex  \
# 7              8       0.0       3      Palsson, Master. Gosta Leonard    0
# 16            17       0.0       3                Rice, Master. Eugene    0
# 50            51       0.0       3          Panula, Master. Juha Niilo    0
# 59            60       0.0       3  Goodwin, Master. William Frederick    0
# 63            64       0.0       3               Skoog, Master. Harald    0
# ..           ...       ...     ...                                 ...  ...
# 360         1252       NaN       3         Sage, Master. William Henry    0
# 379         1271       NaN       3         Asplund, Master. Carl Edgar    0
# 389         1281       NaN       3         Palsson, Master. Paul Folke    0
# 392         1284       NaN       3       Abbott, Master. Eugene Joseph    0
# 417         1309       NaN       3            Peter, Master. Michael J    0
#
#       Age  SibSp  Parch     Ticket     Fare Cabin  Embarked  Initial
# 7     2.0      3      1     349909  21.0750   NaN         0      3.0
# 16    2.0      4      1     382652  29.1250   NaN         2      3.0
# 50    7.0      4      1    3101295  39.6875   NaN         0      3.0
# 59   11.0      5      2    CA 2144  46.9000   NaN         0      3.0
# 63    4.0      3      2     347088  27.9000   NaN         0      3.0
# ..    ...    ...    ...        ...      ...   ...       ...      ...
# 360  14.5      8      2   CA. 2343  69.5500   NaN         0      3.0
# 379   5.0      4      2     347077  31.3875   NaN         0      3.0
# 389   6.0      3      1     349909  21.0750   NaN         0      3.0
# 392  13.0      0      2  C.A. 2673  20.2500   NaN         0      3.0
# 417   NaN      1      1       2668  22.3583   NaN         1      3.0
#
# [61 rows x 13 columns]

# %%
drop_features = ['Name']
df.drop(drop_features, axis=1, inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0            1       0.0       3    0  22.0      1      0         A/5 21171
# 1            2       1.0       1    1  38.0      1      0          PC 17599
# 2            3       1.0       3    1  26.0      0      0  STON/O2. 3101282
# 3            4       1.0       1    1  35.0      1      0            113803
# 4            5       0.0       3    0  35.0      0      0            373450
#
#       Fare Cabin  Embarked  Initial
# 0   7.2500   NaN         0      0.0
# 1  71.2833   C85         1      2.0
# 2   7.9250   NaN         0      1.0
# 3  53.1000  C123         0      2.0
# 4   8.0500   NaN         0      0.0

# %% [markdown]
# ### 6. Age
# - 결측치 보완
# - 범위별 숫자 변환

# %%
df['Age'].isnull().sum() # 결측치 확인
# Out:
# 263

# %%
title_mapping = {'Mr': 0, 'Miss': 1, 'Mrs': 2, 'Master': 3, 'Lady': 4, 'Don': 5, 'Rev': 6, 'Dr': 7, 
                 'Major': 8, 'Sir': 9, 'Col': 10,  'Capt': 11, 'Jonkheer': 12}
df.groupby('Initial').agg({'Age': ['mean', 'median', 'count']})
# Out:
#                Age
#               mean median count
# Initial
# 0.0      32.252151   29.0   581
# 1.0      21.774238   22.0   210
# 2.0      36.994118   35.5   170
# 3.0       5.482642    4.0    53
# 4.0      30.166667   26.0     6
# 5.0      40.000000   40.0     1
# 6.0      41.250000   41.5     8
# 7.0      43.571429   49.0     7
# 8.0      48.500000   48.5     2
# 9.0      49.000000   49.0     1
# 10.0     54.000000   54.5     4
# 11.0     70.000000   70.0     1
# 12.0     38.000000   38.0     1

# %%
df["Age"].fillna(df.groupby("Initial")["Age"].transform("median"), inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0            1       0.0       3    0  22.0      1      0         A/5 21171
# 1            2       1.0       1    1  38.0      1      0          PC 17599
# 2            3       1.0       3    1  26.0      0      0  STON/O2. 3101282
# 3            4       1.0       1    1  35.0      1      0            113803
# 4            5       0.0       3    0  35.0      0      0            373450
#
#       Fare Cabin  Embarked  Initial
# 0   7.2500   NaN         0      0.0
# 1  71.2833   C85         1      2.0
# 2   7.9250   NaN         0      1.0
# 3  53.1000  C123         0      2.0
# 4   8.0500   NaN         0      0.0

# %% [markdown]
# ### 참고: Violin Plot
# - 대략적인 비율 비교를 위한 특별한 그래프 형태
#
# > 이 비율을 참고해서, 나잇대를 숫자로 변경하기로 함

# %%
train = df[:ntrain]

# %%
import plotly.express as px
fig = px.violin(train, y="Age", color="Survived", violinmode='overlay')
fig.show()
# Out:
# <div>                            <div id="4cfdbbcd-ff09-4657-8197-a05ab33b02e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4cfdbbcd-ff09-4657-8197-a05ab33b02e6")) {                    Plotly.newPlot(                        "4cfdbbcd-ff09-4657-8197-a05ab33b02e6",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Survived=0.0<br>Age=%{y}<extra></extra>","legendgroup":"0.0","marker":{"color":"#636efa"},"name":"0.0","offsetgroup":"0.0","orientation":"v","scalegroup":"True","showlegend":true,"type":"violin","x0":" ","xaxis":"x","y":[22.0,35.0,29.0,54.0,2.0,20.0,39.0,14.0,2.0,31.0,35.0,8.0,29.0,19.0,29.0,40.0,66.0,28.0,42.0,21.0,18.0,40.0,27.0,29.0,29.0,29.0,29.0,18.0,7.0,21.0,65.0,28.5,11.0,22.0,45.0,4.0,29.0,19.0,26.0,32.0,16.0,21.0,26.0,25.0,29.0,29.0,22.0,28.0,16.0,29.0,24.0,29.0,20.0,46.0,26.0,59.0,29.0,71.0,34.0,28.0,29.0,21.0,33.0,37.0,28.0,38.0,47.0,14.5,22.0,20.0,17.0,21.0,70.5,29.0,24.0,2.0,21.0,29.0,32.5,54.0,29.0,45.0,33.0,20.
.0,29.0,29.0,29.0,29.0,25.0,25.0,8.0,46.0,29.0,16.0,22.0,29.0,25.0,39.0,30.0,30.0,34.0,31.0,39.0,18.0,39.0,26.0,39.0,35.0,6.0,30.5,29.0,23.0,31.0,43.0,10.0,38.0,2.0,29.0,29.0,29.0,23.0,18.0,21.0,29.0,20.0,16.0,34.5,17.0,42.0,29.0,35.0,28.0,4.0,74.0,9.0,44.0,29.0,41.0,21.0,22.0,24.0,31.0,29.0,26.0,33.0,47.0,20.0,19.0,29.0,33.0,22.0,28.0,25.0,39.0,27.0,22.0,32.0],"y0":" ","yaxis":"y"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Survived=1.0<br>Age=%{y}<extra></extra>","legendgroup":"1.0","marker":{"color":"#EF553B"},"name":"1.0","offsetgroup":"1.0","orientation":"v","scalegroup":"True","showlegend":true,"type":"violin","x0":" ","xaxis":"x","y":[38.0,26.0,35.0,27.0,14.0,4.0,58.0,55.0,29.0,35.5,34.0,15.0,28.0,38.0,22.0,35.5,22.0,29.0,14.0,3.0,19.0,22.0,49.0,29.0,29.0,21.0,5.0,38.0,4.0,29.0,17.0,32 ...

# %% [markdown]
# > 참고: Kernel Density Estimation (커널 밀도 추정) 에 의해, 마이너스 나잇대에 대한 추정 밀도값도 표현됨
# > https://darkpgmr.tistory.com/147

# %% [markdown]
# ### 각 나잇대를 숫자로 변경해보기
#   - baby (2살 이하): 0
#   - child (15살 이하): 1
#   - young (20살 이하): 2
#   - mid-age (33살 이하): 3
#   - junior (43살 이하): 4
#   - senior (60살 이하): 5
#   - old (75살 이하): 6
#   - too old (75살 이상): 7

# %%
# 시각화 값에 딱 맞게 설정하는 것은 학습 데이터(train)에만 잘 맞는 overfitting 현상이 발생할 수 있으므로 적절히 적용
df.loc[df['Age'] <= 2, 'Age'] = 0
df.loc[(df['Age'] > 2) & (df['Age'] <= 15), 'Age'] = 1
df.loc[(df['Age'] > 15) & (df['Age'] <= 20), 'Age'] = 2
df.loc[(df['Age'] > 20) & (df['Age'] <= 33), 'Age'] = 3
df.loc[(df['Age'] > 33) & (df['Age'] <= 43), 'Age'] = 4
df.loc[(df['Age'] > 43) & (df['Age'] <= 60), 'Age'] = 5
df.loc[(df['Age'] > 60) & (df['Age'] <= 75), 'Age'] = 6
df.loc[ df['Age'] > 75, 'Age'] = 7

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1       0.0       3    0  3.0      1      0         A/5 21171
# 1            2       1.0       1    1  4.0      1      0          PC 17599
# 2            3       1.0       3    1  3.0      0      0  STON/O2. 3101282
# 3            4       1.0       1    1  4.0      1      0            113803
# 4            5       0.0       3    0  4.0      0      0            373450
#
#       Fare Cabin  Embarked  Initial
# 0   7.2500   NaN         0      0.0
# 1  71.2833   C85         1      2.0
# 2   7.9250   NaN         0      1.0
# 3  53.1000  C123         0      2.0
# 4   8.0500   NaN         0      0.0

# %% [markdown]
# ### 7. Fare

# %%
survived = train[train['Survived'] == 1]['Fare'] 
dead = train[train['Survived'] == 0]['Fare']
temp = pd.concat([survived, dead], axis=1, keys=['Survived', 'Dead'])

# %%
temp.iplot(kind='histogram', bins=(0, 600, 20))
# Out:
# <div>                            <div id="fc6e5949-0186-4aa4-a592-92d57a6d1ca9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("
9,null,null,null,null,null,null,78.2667,null,null,null,null,null,null,null,86.5,null,26.0,26.55,null,56.4958,7.75,null,26.2875,59.4,null,null,10.5,null,26.0,null,93.5,null,null,57.9792,null,null,10.5,null,null,null,26.0,null,null,22.3583,null,26.25,null,106.425,null,49.5,71.0,null,null,26.0,null,null,26.0,13.8625,null,36.75,110.8833,null,null,7.225,7.775,null,39.6,null,79.65,17.4,null,null,null,null,null,null,null,null,null,7.8542,10.5,51.4792,26.3875,7.75,null,null,13.0,55.9,null,7.925,30.0,110.8833,null,null,null,79.65,null,79.2,null,null,null,78.2667,null,null,null,null,33.0,null,null,56.9292,27.0,null,null,null,26.55,null,null,30.5,41.5792,153.4625,null,null,15.5,null,null,65.0,null,null,39.0,null,null,52.5542,15.7417,null,null,null,null,77.9583,null,null,30.0,null,30.5,null,null,13.0,null,nul ...

# %%
# test 데이터는 결측치가 있음을 확인
df['Fare'].isnull().sum()
# Out:
# 1

# %%
# 아무래도 Pclass 에 따라, 요금이 결정될 가능성이 높으므로
df['Fare'].fillna(df.groupby("Pclass")["Fare"].transform("median"), inplace=True)

# %% [markdown]
# > 요금을 더 세분화해도, 요금에 따른 경향성은 일정 요금 이상(약 50), 이하에서만 나타나는 것을 EDA 를 통해, 이해하였고, <br>
# > 실제 요금 데이터에 대한 이해를 통해서도, 특정 세분화된 요금 구간만, 다른 경향을 보이지는 않을 것이라 예측되므로, <br>
# > 매우 세분화할 필요는 없어보였음

# %%
df.loc[ df['Fare'] <= 20, 'Fare'] = 0
df.loc[(df['Fare'] > 20) & (df['Fare'] <= 40), 'Fare'] = 1
df.loc[(df['Fare'] > 40) & (df['Fare'] <= 60), 'Fare'] = 2
df.loc[(df['Fare'] > 60) & (df['Fare'] <= 80), 'Fare'] = 3
df.loc[(df['Fare'] > 80) & (df['Fare'] <= 100), 'Fare'] = 4
df.loc[ df['Fare'] > 100, 'Fare'] = 5

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1       0.0       3    0  3.0      1      0         A/5 21171
# 1            2       1.0       1    1  4.0      1      0          PC 17599
# 2            3       1.0       3    1  3.0      0      0  STON/O2. 3101282
# 3            4       1.0       1    1  4.0      1      0            113803
# 4            5       0.0       3    0  4.0      0      0            373450
#
#    Fare Cabin  Embarked  Initial
# 0   0.0   NaN         0      0.0
# 1   3.0   C85         1      2.0
# 2   0.0   NaN         0      1.0
# 3   2.0  C123         0      2.0
# 4   0.0   NaN         0      0.0

# %% [markdown]
# ### 8. SibSp + Parch
# - EDA 를 통해, SibSp 와 Parch 를 별도로 구분할 때보다, 합쳤을 때, 보다 경향성이 보였으므로, 합치기로 함

# %%
df['Family'] = df['SibSp'] + df['Parch'] + 1

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1       0.0       3    0  3.0      1      0         A/5 21171
# 1            2       1.0       1    1  4.0      1      0          PC 17599
# 2            3       1.0       3    1  3.0      0      0  STON/O2. 3101282
# 3            4       1.0       1    1  4.0      1      0            113803
# 4            5       0.0       3    0  4.0      0      0            373450
#
#    Fare Cabin  Embarked  Initial  Family
# 0   0.0   NaN         0      0.0       2
# 1   3.0   C85         1      2.0       2
# 2   0.0   NaN         0      1.0       1
# 3   2.0  C123         0      2.0       2
# 4   0.0   NaN         0      0.0       1

# %%
drop_features = ['SibSp', 'Parch']
df.drop(drop_features, axis=1, inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age            Ticket  Fare Cabin  \
# 0            1       0.0       3    0  3.0         A/5 21171   0.0   NaN
# 1            2       1.0       1    1  4.0          PC 17599   3.0   C85
# 2            3       1.0       3    1  3.0  STON/O2. 3101282   0.0   NaN
# 3            4       1.0       1    1  4.0            113803   2.0  C123
# 4            5       0.0       3    0  4.0            373450   0.0   NaN
#
#    Embarked  Initial  Family
# 0         0      0.0       2
# 1         1      2.0       2
# 2         0      1.0       1
# 3         0      2.0       2
# 4         0      0.0       1

# %% [markdown]
# ### 9. Cabin

# %%
import missingno
missingno.matrix(df, figsize = (15,8))
# Out:
# <AxesSubplot:>

# %%
df['Cabin'].unique() # level 값 확인
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
#        'E58', 'C126', 'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'F G63',
#        'C62 C64', 'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30',
#        'E121', 'D11', 'E77', 'F38', 'B3', 'D6', 'B82 B84', 'D17', 'A36',
#        'B102', 'B69', 'E49', 'C47', 'D28', 'E17', 'A24', 'C50', 'B42',
#        'C148', 'B45', 'B36', 'A21', 'D34', 'A9', 'C31', 'B61', 'C53',
#        'D43', 'C130', 'C132', 'C55 C57', 'C116', 'F', 'A29', 'C6', 'C28',
#        'C51', 'C97', 'D22', 'B10', 'E45', 'E52', 'A11', 'B11', 'C80',
#        'C89', 'F E46', 'B26', 'F E57', 'A18', 'E60', 'E39 E41',
#        'B52 B54 B56', 'C39', 'B24', 'D40', 'D38', 'C105'], dtype=object)

# %%
df['Cabin'] = df['Cabin'].fillna('U')  # Unknown 의 약자로 U 로 구분해서 넣기

# %%
df['Cabin'] = df['Cabin'].str[0] # 각 컬럼값을 문자열로 추출해서, 첫 글자로 대입

# %%
df['Cabin'].unique()
# Out:
# array(['U', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
df[df['Cabin'] == 'U']['Ticket'] # Ticket 으로 Cabin 예측은 어려워보임
# Out:
# 0               A/5 21171
# 2        STON/O2. 3101282
# 4                  373450
# 5                  330877
# 7                  349909
#               ...
# 412                347086
# 413             A.5. 3236
# 415    SOTON/O.Q. 3101262
# 416                359309
# 417                  2668
# Name: Ticket, Length: 1014, dtype: object

# %%
train = df[:ntrain]

# %%
import chart_studio.plotly as py
import cufflinks as cf
cf.go_offline(connected=True)

survived = train[train['Survived'] == 1]['Cabin'] 
dead = train[train['Survived'] == 0]['Cabin']
df_temp1 = pd.concat([survived, dead], axis=1, keys=['Survived', 'Dead'])
df_temp1.iplot(kind='histogram')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="ed56e3fb-00a4-454f-9875-0cfb08daaed9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("ed56e3fb-00a4-454f-9875-0cfb08daaed9")) {                    Plotly.newPlot(                        "ed56e3fb-00a4-454f-9875-0cfb08daaed9",                        [{"histfunc":"count","histnorm":"","marker":{"color":"rgba(255, 153, 51, 1.0)","line":{"color":"#4D5663","width":1.3}},"name":"Survived","opacity":0.8,"orientation":"v","type":"histogram","x":[null,"C","U","C",null,null,null,null,"U","U","G","C",null,null,null,"U",null,"U",null,"U",null,"D","U","A",null,"U",null,null,"U",null,null,"B","U",null,null,null,"U",null,null,"U",null,null,null,"U","U",null,null,"U",null,null,null,null,"D","U",null,"C","U",null,"U",null,null,"B",null,null,null,"U","F",null,"U",null,null,null,null,null,"U",null,null,null,"U","U",null,"U","U",null,"U","U",null,null,"C",null,null,null,null,null,null,null,null,"D","U",null,null,null,null,null,null,null,"U","U",null,"U",null,null,null,null,null,null,null,null,null,null,null,null,null,"E",null,"U",null,"U","F",null,null,null,null,"U",null,null,"D",null,null,null,null,"U","U",null,null,null,"U",null,null,null,null,"C",null,null,null,null,"U",null,null,null,null,"U",null,null,null,"U","E",null,null,null,null,null,"U",null,null,null,null,null,null,null,null,null,null,"F","U",null,"U","U",null,null,"U",null,"U
# 2            3       1.0       3    1  3.0  STON/O2. 3101282   0.0      0
# 3            4       1.0       1    1  4.0            113803   2.0      1
# 4            5       0.0       3    0  4.0            373450   0.0      0
# 5            6       0.0       3    0  3.0            330877   0.0      0
# 6            7       0.0       1    0  5.0             17463   2.0      2
# 7            8       0.0       3    0  0.0            349909   1.0      0
# 8            9       1.0       3    1  3.0            347742   0.0      0
# 9           10       1.0       2    1  1.0            237736   1.0      0
#
#    Embarked  Initial  Family
# 0         0      0.0       2
# 1         1      2.0       2
# 2         0      1.0       1
# 3         0      2.0       2
# 4         0      0.0       1
# 5         2      0.0       1
# 6         0      0.0       1
# 7         0      3.0       5
# 8         0      2.0       3
# 9         1      2.0       2

# %% [markdown]
# ### 10. Ticket

# %%
df['Ticket'].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
#        '248738', '364516', '345767', '345779', '330932', '113059',
#        'SO/C 14885', '3101278', 'W./C. 6608', 'SOTON/OQ 392086', '343275',
#        '343276', '347466', 'W.E.P. 5734', 'C.A. 2315', '364500', '374910',
#        'PC 17754', 'PC 17759', '231919', '244367', '349245', '349215',
#        '35281', '7540', '3101276', '349207', '343120', '312991', '349249',
#        '371110', '110465', '2665', '324669', '4136', '2627',
#        'STON/O 2. 3101294', '370369', 'PC 17558', 'A4. 54510', '27267',
#        '370372', 'C 17369', '2668', '347061', '349241',
#        'SOTON/O.Q. 3101307', 'A/5. 3337', '228414', 'C.A. 29178',
#        'SC/PARIS 2133', '11752', '7534', 'PC 17593', '2678', '347081',
#        'STON/O2. 3101279', '365222', '231945', 'C.A. 33112', '350043',
#        '230080', '244310', 'S.O.P. 1166', '113776', 'A.5. 11206',
#        'A/5. 851', 'Fa 265302', 'PC 17597', '35851', 'SOTON/OQ 392090',
#        '315037', 'CA. 2343', '371362', 'C.A. 33595', '347068', '315093',
#        '363291', '113505', 'PC 17318', '111240', 'STON/O 2. 3101280',
#        '17764', '350404', '4133', 'PC 17595', '250653', 'LINE',
#        'SC/PARIS 2131', '230136', '315153', '113767', '370365', '111428',
#        '364849', '349247', '234604', '28424', '350046', 'PC 17610',
#        '368703', '4579', '370370', '248747', '345770', '3101264', '2628',
#        'A/5 3540', '347054', '2699', '367231', '112277',
#        'SOTON/O.Q. 3101311', 'F.C.C. 13528', 'A/5 21174', '250646',
#        '367229', '35273', 'STON/O2. 3101283', '243847', '11813',
#        'W/C 14208', 'SOTON/OQ 392089', '220367', '21440', '349234',
#        '19943', 'PP 4348', 'SW/PP 751', 'A/5 21173', '236171', '347067',
#        '237442', 'C.A. 29566', 'W./C. 6609', '26707', 'C.A. 31921',
#        '28665', 'SCO/W 1585', '367230', 'W./C. 14263',
#        'STON/O 2. 3101275', '2694', '19928', '347071', '250649', '11751',
#        '244252', '362316', '113514', 'A/5. 3336', '370129', '2650',
#        'PC 17585', '110152', 'PC 17755', '230433', '384461', '110413',
#        '112059', '382649', 'C.A. 17248', '347083', 'PC 17582', 'PC 17760',
#        '113798', '250644', 'PC 17596', '370375', '13502', '347073',
#        '239853', 'C.A. 2673', '336439', '347464', '345778', 'A/5. 10482',
#        '113056', '349239', '345774', '349206', '237798', '370373',
#        '19877', '11967', 'SC/Paris 2163', '349236', '349233', 'PC 17612',
#        '2693', '113781', '19988', '9234', '367226', '226593', 'A/5 2466',
#        '17421', 'PC 17758', 'P/PP 3381', 'PC 17485', '11767', 'PC 17608',
#        '250651', '349243', 'F.C.C. 13529', '347470', '29011', '36928',
#        '16966', 'A/5 21172', '349219', '234818', '345364', '28551',
#        '111361', '113043', 'PC 17611', '349225', '7598', '113784',
#        '248740', '244361', '229236', '248733', '31418', '386525',
#        'C.A. 37671', '315088', '7267', '113510', '2695', '2647', '345783',
#        '237671', '330931', '330980', 'SC/PARIS 2167', '2691',
#        'SOTON/O.Q. 3101310', 'C 7076', '110813', '2626', '14313',
#        'PC 17477', '11765', '3101267', '323951', 'C 7077', '113503',
#        '2648', '347069', 'PC 17757', '2653', 'STON/O 2. 3101293',
#        '349227', '27849', '367655', 'SC 1748', '113760', '350034',
#        '3101277', '350052', '350407', '28403', '244278', '240929',
#        'STON/O 2. 3101289', '341826', '4137', '315096', '28664', '347064',
#        '29106', '312992', '349222', '394140', 'STON/O 2. 3101269',
#        '343095', '28220', '250652', '28228', '345773', '349254',
#        'A/5. 13032', '315082', '347080', 'A/4. 34244', '2003', '250655',
#        '364851', 'SOTON/O.Q. 392078', '110564', '376564', 'SC/AH 3085',
#        'STON/O 2. 3101274', '13507', 'C.A. 18723', '345769', '347076',
#        '230434', '65306', '33638', '113794', '2666', '113786', '65303',
#        '113051', '17453', 'A/5 2817', '349240', '13509', '17464',
#        'F.C.C. 13531', '371060', '19952', '364506', '111320', '234360',
#        'A/S 2816', 'SOTON/O.Q. 3101306', '113792', '36209', '323592',
#        '315089', 'SC/AH Basle 541', '7553', '31027', '3460', '350060',
#        '3101298', '239854', 'A/5 3594', '4134', '11771', 'A.5. 18509',
#        '65304', 'SOTON/OQ 3101317', '113787', 'PC 17609', 'A/4 45380',
#        '36947', 'C.A. 6212', '350035', '315086', '364846', '330909',
#        '4135', '26360', '111427', 'C 4001', '382651', 'SOTON/OQ 3101316',
#        'PC 17473', 'PC 17603', '349209', '36967', 'C.A. 34260', '226875',
#        '349242', '12749', '349252', '2624', '2700', '367232',
#        'W./C. 14258', 'PC 17483', '3101296', '29104', '2641', '2690',
#        '315084', '113050', 'PC 17761', '364498', '13568', 'WE/P 5735',
#        '2908', '693', 'SC/PARIS 2146', '244358', '330979', '2620',
#        '347085', '113807', '11755', '345572', '372622', '349251',
#        '218629', 'SOTON/OQ 392082', 'SOTON/O.Q. 392087', 'A/4 48871',
#        '349205', '2686', '350417', 'S.W./PP 752', '11769', 'PC 17474',
#        '14312', 'A/4. 20589', '358585', '243880', '2689',
#        'STON/O 2. 3101286', '237789', '13049', '3411', '237565', '13567',
#        '14973', 'A./5. 3235', 'STON/O 2. 3101273', 'A/5 3902', '364848',
#        'SC/AH 29037', '248727', '2664', '349214', '113796', '364511',
#        '111426', '349910', '349246', '113804', 'SOTON/O.Q. 3101305',
#        '370377', '364512', '220845', '31028', '2659', '11753', '350029',
#        '54636', '36963', '219533', '349224', '334912', '27042', '347743',
#        '13214', '112052', '237668', 'STON/O 2. 3101292', '350050',
#        '349231', '13213', 'S.O./P.P. 751', 'CA. 2314', '349221', '8475',
#        '330919', '365226', '349223', '29751', '2623', '5727', '349210',
#        'STON/O 2. 3101285', '234686', '312993', 'A/5 3536', '19996',
#        '29750', 'F.C. 12750', 'C.A. 24580', '244270', '239856', '349912',
#        '342826', '4138', '330935', '6563', '349228', '350036', '24160',
#        '17474', '349256', '2672', '113800', '248731', '363592', '35852',
#        '348121', 'PC 17475', '36864', '350025', '223596', 'PC 17476',
#        'PC 17482', '113028', '7545', '250647', '348124', '34218', '36568',
#        '347062', '350048', '12233', '250643', '113806', '315094', '36866',
#        '236853', 'STON/O2. 3101271', '239855', '28425', '233639',
#        '349201', '349218', '16988', '376566', 'STON/O 2. 3101288',
#        '250648', '113773', '335097', '29103', '392096', '345780',
#        '349204', '350042', '29108', '363294', 'SOTON/O2 3101272', '2663',
#        '347074', '112379', '364850', '8471', '345781', '350047',
#        'S.O./P.P. 3', '2674', '29105', '347078', '383121', '36865',
#        '2687', '113501', 'W./C. 6607', 'SOTON/O.Q. 3101312', '374887',
#        '3101265', '12460', 'PC 17600', '349203', '28213', '17465',
#        '349244', '2685', '2625', '347089', '347063', '112050', '347087',
#        '248723', '3474', '28206', '364499', '112058', 'STON/O2. 3101290',
#        'S.C./PARIS 2079', 'C 7075', '315098', '19972', '368323', '367228',
#        '2671', '347468', '2223', 'PC 17756', '315097', '392092', '11774',
#        'SOTON/O2 3101287', '2683', '315090', 'C.A. 5547', '349213',
#        '347060', 'PC 17592', '392091', '113055', '2629', '350026',
#        '28134', '17466', '233866', '236852', 'SC/PARIS 2149', 'PC 17590',
#        '345777', '349248', '695', '345765', '2667', '349212', '349217',
#        '349257', '7552', 'C.A./SOTON 34068', 'SOTON/OQ 392076', '211536',
#        '112053', '111369', '370376', '330911', '363272', '240276',
#        '315154', '7538', '330972', '2657', '349220', '694', '21228',
#        '24065', '233734', '2692', 'STON/O2. 3101270', '2696', 'C 17368',
#        'PC 17598', '2698', '113054', 'C.A. 31029', '13236', '2682',
#        '342712', '315087', '345768', '113778', 'SOTON/O.Q. 3101263',
#        '237249', 'STON/O 2. 3101291', 'PC 17594', '370374', '13695',
#        'SC/PARIS 2168', 'SC/A.3 2861', '349230', '348122', '349232',
#        '237216', '347090', '334914', 'F.C.C. 13534', '330963', '2543',
#        '382653', '349211', '3101297', 'PC 17562', '359306', '11770',
#        '248744', '368702', '19924', '349238', '240261', '2660', '330844',
#        'A/4 31416', '364856', '347072', '345498', '376563', '13905',
#        '350033', 'STON/O 2. 3101268', '347471', 'A./5. 3338', '11778',
#        '365235', '347070', '330920', '383162', '3410', '248734', '237734',
#        '330968', 'PC 17531', '329944', '2681', '13050', '367227',
#        '392095', '368783', '350045', '211535', '342441',
#        'STON/OQ. 369943', '113780', '2621', '349226', '350409', '2656',
#        '248659', 'SOTON/OQ 392083', '17475', 'SC/A4 23568', '113791',
#        '349255', '3701', '350405', 'S.O./P.P. 752', '347469', '110489',
#        'SOTON/O.Q. 3101315', '335432', '220844', '343271', '237393',
#        'PC 17591', '17770', '7548', 'S.O./P.P. 251', '2670', '2673',
#        '233478', '7935', '239059', 'S.O./P.P. 2', 'A/4 48873', '28221',
#        '111163', '235509', '347465', '347066', 'C.A. 31030', '65305',
#        'C.A. 34050', 'F.C. 12998', '9232', '28034', 'PC 17613', '349250',
#        'SOTON/O.Q. 3101308', '347091', '113038', '330924', '32302',
#        'SC/PARIS 2148', '342684', 'W./C. 14266', '350053', 'PC 17606',
#        '350054', '370368', '242963', '113795', '3101266', '330971',
#        '350416', '2679', '250650', '112377', '3470', 'SOTON/O2 3101284',
#        '13508', '7266', '345775', 'C.A. 42795', 'AQ/4 3130', '363611',
#        '28404', '345501', '350410', 'C.A. 34644', '349235', '112051',
#        'C.A. 49867', 'A. 2. 39186', '315095', '368573', '2676',
#        'SC 14888', 'CA 31352', 'W./C. 14260', '315085', '364859',
#        'A/5 21175', 'SOTON/O.Q. 3101314', '2655', 'A/5 1478', 'PC 17607',
#        '382650', '2652', '345771', '349202', '113801', '347467', '347079',
#        '237735', '315092', '383123', '112901', '315091', '2658',
#        'LP 1588', '368364', 'AQ/3. 30631', '28004', '350408', '347075',
#        '2654', '244368', '113790', 'SOTON/O.Q. 3101309', '236854',
#        'PC 17580', '2684', '349229', '110469', '244360', '2675', '2622',
#        'C.A. 15185', '350403', '348125', '237670', '2688', '248726',
#        'F.C.C. 13540', '113044', '1222', '368402', '315083', '112378',
#        'SC/PARIS 2147', '28133', '248746', '315152', '29107', '680',
#        '366713', '330910', 'SC/PARIS 2159', '349911', '244346', '364858',
#        'C.A. 30769', '371109', '347065', '21332', '17765',
#        'SC/PARIS 2166', '28666', '334915', '365237', '347086',
#        'A.5. 3236', 'SOTON/O.Q. 3101262', '359309'], dtype=object)

# %%
df['Ticket_Initial'] = df['Ticket'].str.extract('([^ \t\n\r\f\v]+) ')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age            Ticket  Fare  Cabin  \
# 0            1       0.0       3    0  3.0         A/5 21171   0.0      0
# 1            2       1.0       1    1  4.0          PC 17599   3.0      1
# 2            3       1.0       3    1  3.0  STON/O2. 3101282   0.0      0
# 3            4       1.0       1    1  4.0            113803   2.0      1
# 4            5       0.0       3    0  4.0            373450   0.0      0
#
#    Embarked  Initial  Family Ticket_Initial
# 0         0      0.0       2            A/5
# 1         1      2.0       2             PC
# 2         0      1.0       1       STON/O2.
# 3         0      2.0       2            NaN
# 4         0      0.0       1            NaN

# %%
df['Ticket_Num'] = df['Ticket'].str.extract('( [^ \t\n\r\f\v]+)')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age            Ticket  Fare  Cabin  \
# 0            1       0.0       3    0  3.0         A/5 21171   0.0      0
# 1            2       1.0       1    1  4.0          PC 17599   3.0      1
# 2            3       1.0       3    1  3.0  STON/O2. 3101282   0.0      0
# 3            4       1.0       1    1  4.0            113803   2.0      1
# 4            5       0.0       3    0  4.0            373450   0.0      0
#
#    Embarked  Initial  Family Ticket_Initial Ticket_Num
# 0         0      0.0       2            A/5      21171
# 1         1      2.0       2             PC      17599
# 2         0      1.0       1       STON/O2.    3101282
# 3         0      2.0       2            NaN        NaN
# 4         0      0.0       1            NaN        NaN

# %%
df['Ticket_Num'] = df['Ticket_Num'].fillna(df['Ticket'])

# %%
df[df['Ticket_Num'] == 'LINE']
# Out:
#      PassengerId  Survived  Pclass  Sex  Age Ticket  Fare  Cabin  Embarked  \
# 179          180       0.0       3    0  4.0   LINE   0.0      0         0
# 271          272       1.0       3    0  3.0   LINE   0.0      0         0
# 302          303       0.0       3    0  2.0   LINE   0.0      0         0
# 597          598       0.0       3    0  5.0   LINE   0.0      0         0
#
#      Initial  Family Ticket_Initial Ticket_Num
# 179      0.0       1            NaN       LINE
# 271      0.0       1            NaN       LINE
# 302      0.0       1            NaN       LINE
# 597      0.0       1            NaN       LINE

# %%
df.loc[(df['Ticket_Num'] == 'LINE'),'Ticket_Initial']= 'LINE'
df.loc[(df['Ticket_Num'] == 'LINE'),'Ticket_Num']= 0

# %%
df[df['Ticket_Initial'] == 'LINE']
# Out:
#      PassengerId  Survived  Pclass  Sex  Age Ticket  Fare  Cabin  Embarked  \
# 179          180       0.0       3    0  4.0   LINE   0.0      0         0
# 271          272       1.0       3    0  3.0   LINE   0.0      0         0
# 302          303       0.0       3    0  2.0   LINE   0.0      0         0
# 597          598       0.0       3    0  5.0   LINE   0.0      0         0
#
#      Initial  Family Ticket_Initial Ticket_Num
# 179      0.0       1           LINE          0
# 271      0.0       1           LINE          0
# 302      0.0       1           LINE          0
# 597      0.0       1           LINE          0

# %%
df[df['Ticket_Num'] == ' Basle']
# Out:
#      PassengerId  Survived  Pclass  Sex  Age           Ticket  Fare  Cabin  \
# 473          474       1.0       2    1  3.0  SC/AH Basle 541   0.0      4
#
#      Embarked  Initial  Family Ticket_Initial Ticket_Num
# 473         1      2.0       1          SC/AH      Basle

# %%
df.loc[(df['Ticket_Num'] == ' Basle'), 'Ticket_Num'] = 541

# %%
df[df['Ticket_Num'] == ' Basle']
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Sex, Age, Ticket, Fare, Cabin, Embarked, Initial, Family, Ticket_Initial, Ticket_Num]
# Index: []

# %% [markdown]
# - str.replace( ) 함수는 조건에 맞는 것을 다른 것으로 대체 해주는 함수.
# - '[^A-Za-z]' 는 알파벳 문자가 아닌 문자를 뜻하는 정규 표현식.
# - repl = '' 이건 제거하겠다는 의미, 만약 ' '면 공백으로 대체됨.
# - regex=True 이거는 꼭 작성해줘야 정규표현식이 작동함.

# %%
df['Ticket_Initial_Test'] = df['Ticket_Initial'].str.replace(pat='[^A-Za-z]', repl='', regex=True)

# %%
df['Ticket_Initial2'] = df['Ticket_Initial'].str.replace(pat='[^A-Za-z]', repl='', regex=True).str[0:2]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age            Ticket  Fare  Cabin  \
# 0            1       0.0       3    0  3.0         A/5 21171   0.0      0
# 1            2       1.0       1    1  4.0          PC 17599   3.0      1
# 2            3       1.0       3    1  3.0  STON/O2. 3101282   0.0      0
# 3            4       1.0       1    1  4.0            113803   2.0      1
# 4            5       0.0       3    0  4.0            373450   0.0      0
#
#    Embarked  Initial  Family Ticket_Initial Ticket_Num Ticket_Initial_Test  \
# 0         0      0.0       2            A/5      21171                   A
# 1         1      2.0       2             PC      17599                  PC
# 2         0      1.0       1       STON/O2.    3101282               STONO
# 3         0      2.0       2            NaN     113803                 NaN
# 4         0      0.0       1            NaN     373450                 NaN
#
#   Ticket_Initial2
# 0               A
# 1              PC
# 2              ST
# 3             NaN
# 4             NaN

# %%
train = df[:ntrain]

# %%
import chart_studio.plotly as py
import cufflinks as cf
cf.go_offline(connected=True)

survived = train[train['Survived'] == 1]['Ticket_Initial2'] 
dead = train[train['Survived'] == 0]['Ticket_Initial2']
df_temp1 = pd.concat([survived, dead], axis=1, keys=['Survived', 'Dead'])
df_temp1.iplot(kind='histogram')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="28ea5f97-3de0-49b3-bb70-276d0d8d65ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("28ea5f97-3de0-49b3-bb70-276d0d8d65ea")) {                    Plotly.newPlot(                        "28ea5f97-3de0-49b3-bb70-276d0d8d65ea",                        [{"histfunc":"count","histnorm":"","marker":{"color":"rgba(255, 153, 51, 1.0)","line":{"color":"#4D5663","width":1.3}},"name":"Survived","opacity":0.8,"orientation":"v","type":"histogram","x":[null,"PC","ST",null,null,null,null,null,null,null,"PP",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"PC",null,null,null,null,null,null,null,null,null,null,null,"SC",null,null,null,null,null,null,null,null,"PC",null,null,null,"CA",null,"CA",null,null,null,null,null,null,null,"CA",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"SO",null,null,null,null,null,null,null,null,null,null,null,null,"PC",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"C",null,null,null,null,null,null,null,null,null,null,null,null,null,null,"ST",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"CA",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"PC","PC",null,null,null,null,null,null,null,null,"A",null,null,null,null,null,null,"FC",null,null,null,null,"ST",null,null,null,"SO",null,null,null,null,null,"SW",null,null,null,null,null,null,null,null,null,null,"CA",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"PC",null,"PC",null,null,null,null,null,null,null,null,null,"PC","PC",null,"LI",null,null,null,null,null,null,null,"CA",null,null,null,"A",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"PC",null,null,null,null,null,null,null,"PC",null,"PC",null,"PC",null,null,null,null,null,null,null,null,null,null,null,null,null,"PC",null,null,null,null,null,null,null,null,"PC",null,null,null,null,null,null,null,null,null,null,null,null,null,"CA",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"PC",null,null,null,null,null,"PC","C",null,null,null,"PC",null,null,null,null,null,null,null,null,"SC",null,null,null,null,"PP",null,null,null,null,null,"ST",null,null,null,null,null,null,null,null,null,null,null,null,null,"ST",null,null,null,null,null,null,null,null,null,null,null,null,null,null,"SO",null,null,"SC",null,null,null,null,null,null,null,"FC",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"FC",null,null,null,null,null,null,null,null,null,null,null,null,null,"CA","SC",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"CA",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"PC","PC",null,null,"CA",null,null,null,null,null,null,null,null,null,"WC",null,null,null,null,null,null,null,null,"FC",null,"PC",null,null,"WE",null,null,null,null,null,null,"SC",null,"CA",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"SW",null,"PC",null,null,null,null,null,null,"ST",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"PC",null,null,null,null,null,null,null,null,"SC","PC",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"PC",null,null,null,"PC",null,null,null,"CA",null,null,null,null,null,null,null,null,null,null,"PC",null,null,null,"ST",null,null,null,null,null,null,null,null,null,null,null,null,null,null,"PC",null,"PC",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"PC","PC",null,null ...

# %%
df['Ticket_Initial2'].isnull().sum()
# Out:
# 957

# %%
df['Ticket_Initial2'] = df['Ticket_Initial2'].fillna('UN')
import chart_studio.plotly as py
import cufflinks as cf
cf.go_offline(connected=True)
train = df[:ntrain]
survived = train[train['Survived'] == 1]['Ticket_Initial2'] 
dead = train[train['Survived'] == 0]['Ticket_Initial2']
df_temp1 = pd.concat([survived, dead], axis=1, keys=['Survived', 'Dead'])
df_temp1.iplot(kind='histogram')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="4f3abf5e-dfcb-44bd-8b3d-0c2c66c61ff8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("4f3abf5e-dfcb-44bd-8b3d-0c2c66c61ff8")) {                    Plotly.newPlot(                        "4f3abf5e-dfcb-44bd-8b3d-0c2c66c61ff8",                        [{"histfunc":"count","histnorm":"","marker":{"color":"rgba(255, 153, 51, 1.0)","line":{"color":"#4D5663","width":1.3}},"name":"
",null,null,"UN","SC","PC",null,null,"UN",null,null,"UN",null,null,"UN",null,null,"UN","UN",null,null,null,null,"UN",null,null,"UN",null,"UN",null,null,"UN",null,null,null,null,null,"PC",null,"UN","UN","PC",null,"UN",null,"CA",null,"UN",null,"UN",null,null,null,null,null,null,"PC",null,null,null,"ST",null,null,null,null,"UN","UN",null,null,"UN",null,null,null,"UN",null,"PC",null,"PC",null,null,null,null,null,null,null,"UN","UN","UN","UN",null,null,null,null,"UN",null,null,"PC","PC",null,null ...

# %%
df['Ticket_Initial2'] = df['Ticket_Initial2'].factorize()[0]

# %% [markdown]
# ### qcut() 과 cut()
# - pandas.qcut(나눌데이터컬럼, q=나눌 수, labels=각그룹이름(배열) 또는 False)
#   - 나눌데이터컬럼값의 분포를 기반으로, 균등 사이즈로 각 그룹으로 나눔
# - pandas.cut(나눌데이터컬럼, 나눌 수)
#   - 나눌데이터컬럼값을 기반으로 동일한 범위로, 각 그룹을 나눔

# %%
df['Ticket_Num_Cut'] = df['Ticket_Num'].astype('float')

# %%
df['Ticket_Num_Cut'] = pd.qcut(df['Ticket_Num_Cut'], q=10, labels=False)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age            Ticket  Fare  Cabin  \
# 0            1       0.0       3    0  3.0         A/5 21171   0.0      0
# 1            2       1.0       1    1  4.0          PC 17599   3.0      1
# 2            3       1.0       3    1  3.0  STON/O2. 3101282   0.0      0
# 3            4       1.0       1    1  4.0            113803   2.0      1
# 4            5       0.0       3    0  4.0            373450   0.0      0
#
#    Embarked  Initial  Family Ticket_Initial Ticket_Num Ticket_Initial_Test  \
# 0         0      0.0       2            A/5      21171                   A
# 1         1      2.0       2             PC      17599                  PC
# 2         0      1.0       1       STON/O2.    3101282               STONO
# 3         0      2.0       2            NaN     113803                 NaN
# 4         0      0.0       1            NaN     373450                 NaN
#
#    Ticket_Initial2  Ticket_Num_Cut
# 0                0               3
# 1                1               3
# 2                2               9
# 3                3               5
# 4                3               9

# %%
import chart_studio.plotly as py
import cufflinks as cf
cf.go_offline(connected=True)
train = df[:ntrain]
survived = train[train['Survived'] == 1]['Ticket_Num_Cut'] 
dead = train[train['Survived'] == 0]['Ticket_Num_Cut']
df_temp1 = pd.concat([survived, dead], axis=1, keys=['Survived', 'Dead'])
df_temp1.iplot(kind='histogram')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="84ac0358-0075-4f9c-8a94-3fc2688e2a21" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("84ac0358-0075-4f9c-8a94-3fc2688e2a21")) {                    Plotly.newPlot(                        "84ac0358-0075-4f9c-8a94-3fc2688e2a21",                        [{"histfunc":"count","histnorm":"","marker":{"color":"rgba(255, 153, 51, 1.0)","line":{"color":"#4D5663","width":1.3}},"name":"Survived","opacity":0.8,"orientation":"v","type":"histogram","x":[null,3.0,9.0,5.0,null,null,null,null,7.0,6.0,2.0,5.0,null,null,null,6.0,null,6.0,null,0.0,null,6.0,7.0,5.0,null,7.0,null,null,7.0,null,null,3.0,7.0,null,null,null,1.0,null,null,0.0,null,null,null,0.0,7.0,null,null,2.0,null,null,null,null,3.0,1.0,null,3.0,4.0,null,4.0,null,null,5.0,null,null,null,1.0,4.0,null,9.0,null,null,null,null,null,0.0,null,null,null,6.0,8.0,null,7.0,7.0,null,2.0,9.0,null,null,3.0,null,null,null,null,null,null,null,null,3.0,6.0,null,null,null,null,null,null,null,7.0,6.0,null,9.0,null,null,null,null,null,null,null,null,null,null,null,null,null,4.0,null,0.0,null,2.0,1.0,null,null,null,null,5.0,null,null,2.0,null,null,null,null,7.
# %% [markdown]
# > 이정도 하면 경향성이 다소 보임

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age            Ticket  Fare  Cabin  \
# 0            1       0.0       3    0  3.0         A/5 21171   0.0      0
# 1            2       1.0       1    1  4.0          PC 17599   3.0      1
# 2            3       1.0       3    1  3.0  STON/O2. 3101282   0.0      0
# 3            4       1.0       1    1  4.0            113803   2.0      1
# 4            5       0.0       3    0  4.0            373450   0.0      0
#
#    Embarked  Initial  Family Ticket_Initial Ticket_Num Ticket_Initial_Test  \
# 0         0      0.0       2            A/5      21171                   A
# 1         1      2.0       2             PC      17599                  PC
# 2         0      1.0       1       STON/O2.    3101282               STONO
# 3         0      2.0       2            NaN     113803                 NaN
# 4         0      0.0       1            NaN     373450                 NaN
#
#    Ticket_Initial2  Ticket_Num_Cut
# 0                0               3
# 1                1               3
# 2                2               9
# 3                3               5
# 4                3               9

# %%
drop_features = ['Ticket', 'Ticket_Initial_Test', 'Ticket_Initial', 'Ticket_Num']
df.drop(drop_features, axis=1, inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  Fare  Cabin  Embarked  Initial  \
# 0            1       0.0       3    0  3.0   0.0      0         0      0.0
# 1            2       1.0       1    1  4.0   3.0      1         1      2.0
# 2            3       1.0       3    1  3.0   0.0      0         0      1.0
# 3            4       1.0       1    1  4.0   2.0      1         0      2.0
# 4            5       0.0       3    0  4.0   0.0      0         0      0.0
#
#    Family  Ticket_Initial2  Ticket_Num_Cut
# 0       2                0               3
# 1       2                1               3
# 2       1                2               9
# 3       2                3               5
# 4       1                3               9

# %% [markdown]
# ### pickle
# - 데이터 구조나 객체등 어떤 데이터도 파일로 저장하고, 읽을 수 있음
# - 리스트를 저장하면, 해당 파일을 읽어서, 리스트 변수에 값을 넣을 수 있음

# %%
import pickle

# %% [markdown]
# #### pickle 사용법1: 파일에 저장된 리스트 데이터 읽어서, datas1 변수에 넣기
# - 파일 위치에는 전체 디렉토리와 해당 파일명까지 써주거나,
# - 파일명만 써주면, 주피터 노트북이 실행되는 해당 폴더 안에 있는 파일을 의미함
#
# ```python
# with open(파일위치, 'rb') as pickle_filename:
#     datas1 = pickle.load(pickle_filename)
# ```

# %% [markdown]
# #### pickle 사용법2: 파일에 리스트 변수의 데이터를 저장하기
#
# ```python
# with open(파일위치, 'wb') as pickle_filename:
#     pickle.dump(datas1, pickle_filename)
# ```

# %%
import pickle
with open('titanic_step1_feature_change.pickle', 'wb') as pickle_filename:
    pickle.dump(df, pickle_filename)

# %% [markdown]
# <div class="alert alert-block" style="border: 1px solid #455A64;background-color:#ECEFF1;">
# 본 자료 및 영상 컨텐츠는 저작권법 제25조 2항에 의해 보호를 받습니다. 본 컨텐츠 및 컨텐츠 일부 문구등을 외부에 공개, 게시하는 것을 금지합니다. 특히 자료에 대해서는 저작권법을 엄격하게 적용하겠습니다.
# </div>

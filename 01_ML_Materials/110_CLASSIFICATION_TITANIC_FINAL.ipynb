# %% [markdown]
# <div class="alert alert-block" style="border: 1px solid #455A64;background-color:#ECEFF1;">
# 본 자료 및 영상 컨텐츠는 저작권법 제25조 2항에 의해 보호를 받습니다. 본 컨텐츠 및 컨텐츠 일부 문구등을 외부에 공개, 게시하는 것을 금지합니다. 특히 자료에 대해서는 저작권법을 엄격하게 적용하겠습니다.
# </div>

# %% [markdown]
# ### 0. train/test 데이터 임포트

# %%
import numpy as np
import pandas as pd

from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score

import string
import warnings
import missingno
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_csv('titanic/train.csv')
df_test = pd.read_csv('titanic/test.csv')
df_all = pd.concat((df_train, df_test)).reset_index(drop=True)

# %% [markdown]
# ### 1. 결측치 보정

# %%
missingno.matrix(df_all)
# Out:
# <Axes: >

# %% [markdown]
# ### 1.1. Age

# %%
df_all['Title'] = df_all.Name.str.extract('([A-Za-z]+)\.')
df_all['Title'] = df_all['Title'].replace(['Miss', 'Mrs','Ms', 'Mlle', 'Lady', 'Mme', 'Countess', 'Dona'], 'Mz')
df_all['Title'] = df_all['Title'].replace(['Don', 'Dr','Rev', 'Col', 'Major', 'Capt', 'Sir', 'Jonkheer'], 'Honor')

# 202402 업데이트: 기존 코드는 최신 라이브러리에서 다음 에러가 납니다.
# 기존 코드: df_all['Age'] = df_all.groupby(['Title', 'Pclass'])['Age'].apply(lambda x: x.fillna(x.median()))
# 해당 문제는 apply 대신에 transform 메서드를 사용하면 해결할 수 있습니다.
df_all['Age'] = df_all.groupby(['Title', 'Pclass'])['Age'].transform(lambda x: x.fillna(x.median()))
df_all['Title'].value_counts()
# Out:
# Title
# Mr        757
# Mz        465
# Master     61
# Honor      26
# Name: count, dtype: int64

# %% [markdown]
# ### 1.2. Embarked

# %%
df_all[df_all['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62       1.0       1                        Icard, Miss. Amelie
# 829          830       1.0       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked Title
# 61   female  38.0      0      0  113572  80.0   B28      NaN    Mz
# 829  female  62.0      0      0  113572  80.0   B28      NaN    Mz

# %%
df_all['Ticket']
# Out:
# 0                A/5 21171
# 1                 PC 17599
# 2         STON/O2. 3101282
# 3                   113803
# 4                   373450
#                ...
# 1304             A.5. 3236
# 1305              PC 17758
# 1306    SOTON/O.Q. 3101262
# 1307                359309
# 1308                  2668
# Name: Ticket, Length: 1309, dtype: object

# %%
df_all[df_all['Cabin'].str.startswith('B2', na=False)]
# Out:
#       PassengerId  Survived  Pclass  \
# 61             62       1.0       1
# 540           541       1.0       1
# 690           691       1.0       1
# 745           746       0.0       1
# 781           782       1.0       1
# 829           830       1.0       1
# 1196         1197       NaN       1
# 1281         1282       NaN       1
#
#                                                    Name     Sex   Age  SibSp  \
# 61                                  Icard, Miss. Amelie  female  38.0      0
# 540                             Crosby, Miss. Harriet R  female  36.0      0
# 690                             Dick, Mr. Albert Adrian    male  31.0      1
# 745                        Crosby, Capt. Edward Gifford    male  70.0      1
# 781           Dick, Mrs. Albert Adrian (Vera Gillespie)  female  17.0      1
# 829           Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
# 1196  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female  64.0      1
# 1281                         Payne, Mr. Vivian Ponsonby    male  23.0      0
#
#       Parch     Ticket   Fare Cabin Embarked  Title
# 61        0     113572  80.00   B28      NaN     Mz
# 540       2  WE/P 5735  71.00   B22        S     Mz
# 690       0      17474  57.00   B20        S     Mr
# 745       1  WE/P 5735  71.00   B22        S  Honor
# 781       0      17474  57.00   B20        S     Mz
# 829       0     113572  80.00   B28      NaN     Mz
# 1196      1     112901  26.55   B26        S     Mz
# 1281      0      12749  93.50   B24        S     Mr

# %% [raw]
# # 참고
# df_all[(pd.to_numeric(df_all['Ticket'], errors='coerce') > 113500) & (pd.to_numeric(df_all['Ticket'], errors='coerce') < 113600)]

# %%
# Filling the missing values in Embarked with S
df_all['Embarked'] = df_all['Embarked'].fillna('S')

# %% [markdown]
# ### 1.3. Fare

# %% [markdown]
# <img src='https://qph.fs.quoracdn.net/main-qimg-2eaedf5504e843485d9485a773f65bb7.webp'>

# %%
df_all[df_all['Fare'].isnull()]
# Out:
#       PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 1043         1044       NaN       3  Storey, Mr. Thomas  male  60.5      0
#
#       Parch Ticket  Fare Cabin Embarked Title
# 1043      0   3701   NaN   NaN        S    Mr

# %%
median_fare = df_all[
    (df_all['Pclass'] == 3) & (df_all['Parch'] == 0) & 
    (df_all['SibSp'] == 0) & (df_all['Embarked'] == 'S')]['Fare'].median()
df_all['Fare'] = df_all['Fare'].fillna(median_fare)

# %% [markdown]
# ### 1.4. Cabin

# %%
df_all['Cabin'] = df_all['Cabin'].str[0]
df_all['Cabin'] = df_all['Cabin'].fillna('X')
df_all.loc[(df_all['Cabin'] == 'T'), 'Cabin'] = 'A'

# %%
df_all['Cabin'].value_counts()
# Out:
# Cabin
# X    1014
# C      94
# B      65
# D      46
# E      41
# A      23
# F      21
# G       5
# Name: count, dtype: int64

# %%
missingno.matrix(df_all)
# Out:
# <Axes: >

# %% [markdown]
# ## **2. Feature Engineering**

# %% [markdown]
# ### **2.1 Binning Continuous Features**

# %% [markdown]
# ### Fare

# %%
df_all.loc[ df_all['Fare'] <= 20, 'Fare'] = 0
df_all.loc[(df_all['Fare'] > 20) & (df_all['Fare'] <= 40), 'Fare'] = 1
df_all.loc[(df_all['Fare'] > 40) & (df_all['Fare'] <= 60), 'Fare'] = 2
df_all.loc[(df_all['Fare'] > 60) & (df_all['Fare'] <= 80), 'Fare'] = 3
df_all.loc[(df_all['Fare'] > 80) & (df_all['Fare'] <= 100), 'Fare'] = 4
df_all.loc[ df_all['Fare'] > 100, 'Fare'] = 5

# %% [markdown]
# ### Age

# %%
# 시각화 값에 딱 맞게 설정하는 것은 학습 데이터(train)에만 잘 맞는 overfitting 현상이 발생할 수 있으므로 적절히 적용
df_all.loc[df_all['Age'] <= 2, 'Age'] = 0
df_all.loc[(df_all['Age'] > 2) & (df_all['Age'] <= 15), 'Age'] = 1
df_all.loc[(df_all['Age'] > 15) & (df_all['Age'] <= 20), 'Age'] = 2
df_all.loc[(df_all['Age'] > 20) & (df_all['Age'] <= 33), 'Age'] = 3
df_all.loc[(df_all['Age'] > 33) & (df_all['Age'] <= 43), 'Age'] = 4
df_all.loc[(df_all['Age'] > 43) & (df_all['Age'] <= 60), 'Age'] = 5
df_all.loc[(df_all['Age'] > 60) & (df_all['Age'] <= 75), 'Age'] = 6
df_all.loc[ df_all['Age'] > 75, 'Age'] = 7

# %% [markdown]
# ### **2.2 Frequency Encoding**

# %% [markdown]
# ### Family_Size

# %%
df_all['Family_Size'] = df_all['SibSp'] + df_all['Parch'] + 1

# %% [markdown]
# ### Family_Size_Group

# %%
df_all.loc[df_all['Family_Size'] <= 1, 'Family_Size_Group'] = 'Alone'
df_all.loc[(df_all['Family_Size'] > 1) & (df_all['Family_Size'] <= 4), 'Family_Size_Group'] = 'Small'
df_all.loc[(df_all['Family_Size'] > 4) & (df_all['Family_Size'] <= 6), 'Family_Size_Group'] = 'Medium'
df_all.loc[ df_all['Family_Size'] > 6, 'Family_Size_Group'] = 'Large'

# %% [markdown]
# ### Ticket_Frequency

# %%
def refine_ticket(data):
    tickets = list()
    for index in range(len(data)):
        ticket = data.iloc[index]
        ticket = ticket.replace(' ', '').strip()
        for punctuation in string.punctuation:
            ticket = ticket.replace(punctuation, '')
        tickets.append(ticket)
    return tickets

# %%
df_all['Ticket_Refinement'] = refine_ticket(df_all['Ticket'])

# %%
df_all['Ticket_Frequency'] = df_all.groupby('Ticket_Refinement')['Ticket_Refinement'].transform('count')

# %%
df_all[df_all['Ticket_Frequency'] == 5]
# Out:
#       PassengerId  Survived  Pclass  \
# 7               8       0.0       3
# 24             25       0.0       3
# 86             87       0.0       3
# 147           148       0.0       3
# 176           177       0.0       3
# 229           230       0.0       3
# 319           320       1.0       1
# 337           338       1.0       1
# 374           375       0.0       3
# 377           378       0.0       1
# 380           381       1.0       1
# 409           410       0.0       3
# 436           437       0.0       3
# 485           486       0.0       3
# 557           558       0.0       1
# 567           568       0.0       3
# 615           616       1.0       2
# 700           701       1.0       1
# 716           717       1.0       1
# 736           737       0.0       3
# 754           755       1.0       2
# 965           966       NaN       1
# 966           967       NaN       1
# 1023         1024       NaN       3
# 1058         1059       NaN       3
# 1087         1088       NaN       1
# 1093         1094       NaN       1
# 1109         1110       NaN       1
# 1121         1122       NaN       2
# 1133         1134       NaN       1
# 1244         1245       NaN       2
# 1262         1263       NaN       1
# 1276         1277       NaN       2
# 1280         1281       NaN       3
# 1298         1299       NaN       1
#
#                                                    Name     Sex  Age  SibSp  \
# 7                        Palsson, Master. Gosta Leonard    male  0.0      3
# 24                        Palsson, Miss. Torborg Danira  female  1.0      3
# 86                               Ford, Mr. William Neal    male  2.0      1
# 147                    Ford, Miss. Robina Maggie "Ruby"  female  1.0      2
# 176                       Lefebre, Master. Henry Forbes    male  1.0      3
# 229                             Lefebre, Miss. Mathilde  female  3.0      3
# 319   Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female  4.0      1
# 337                     Burns, Miss. Elizabeth Margaret  female  4.0      0
# 374                          Palsson, Miss. Stina Viola  female  1.0      3
# 377                           Widener, Mr. Harry Elkins    male  3.0      0
# 380                               Bidois, Miss. Rosalie  female  4.0      0
# 409                                  Lefebre, Miss. Ida  female  3.0      3
# 436                Ford, Miss. Doolina Margaret "Daisy"  female  3.0      2
# 485                              Lefebre, Miss. Jeannie  female  3.0      3
# 557                                 Robbins, Mr. Victor    male  4.0      0
# 567         Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  3.0      0
# 615                                 Herman, Miss. Alice  female  3.0      1
# 700   Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  2.0      1
# 716                       Endres, Miss. Caroline Louise  female  4.0      0
# 736             Ford, Mrs. Edward (Margaret Ann Watson)  female  5.0      1
# 754                    Herman, Mrs. Samuel (Jane Laver)  female  5.0      1
# 965                                Geiger, Miss. Amalie  female  4.0      0
# 966                                  Keeping, Mr. Edwin    male  3.0      0
# 1023                      Lefebre, Mrs. Frank (Frances)  female  3.0      0
# 1058                            Ford, Mr. Edward Watson    male  2.0      2
# 1087                    Spedden, Master. Robert Douglas    male  1.0      0
# 1093                             Astor, Col. John Jacob    male  5.0      1
# 1109       Widener, Mrs. George Dunton (Eleanor Elkins)  female  5.0      1
# 1121                        Sweet, Mr. George Frederick    male  1.0      0
# 1133                       Spedden, Mr. Frederic Oakley    male  5.0      1
# 1244                                 Herman, Mr. Samuel    male  5.0      1
# 1262                          Wilson, Miss. Helen Alice  female  3.0      0
# 1276                                 Herman, Miss. Kate  female  3.0      1
# 1280                        Palsson, Master. Paul Folke    male  1.0      3
# 1298                         Widener, Mr. George Dunton    male  5.0      1
#
#       Parch      Ticket  Fare Cabin Embarked   Title  Family_Size  \
# 7         1      349909   1.0     X        S  Master            5
# 24        1      349909   1.0     X        S      Mz            5
# 86        3  W./C. 6608   1.0     X        S      Mr            5
# 147       2  W./C. 6608   1.0     X        S      Mz            5
# 176       1        4133   1.0     X        S  Master            5
# 229       1        4133   1.0     X        S      Mz            5
# 319       1       16966   5.0     E        C      Mz            3
# 337       0       16966   5.0     E        C      Mz            1
# 374       1      349909   1.0     X        S      Mz            5
# 377       2      113503   5.0     C        C      Mr            3
# 380       0    PC 17757   5.0     X        C      Mz            1
# 409       1        4133   1.0     X        S      Mz            5
# 436       2  W./C. 6608   1.0     X        S      Mz            5
# 485       1        4133   1.0     X        S      Mz            5
# 557       0    PC 17757   5.0     X        C      Mr            1
# 567       4      349909   1.0     X        S      Mz            5
# 615       2      220845   3.0     X        S      Mz            4
# 700       0    PC 17757   5.0     C        C      Mz            2
# 716       0    PC 17757   5.0     C        C      Mz            1
# 736       3  W./C. 6608   1.0     X        S      Mz            5
# 754       2      220845   3.0     X        S      Mz            4
# 965       0      113503   5.0     C        C      Mz            1
# 966       0      113503   5.0     C        C      Mr            1
# 1023      4        4133   1.0     X        S      Mz            5
# 1058      2  W./C. 6608   1.0     X        S      Mr            5
# 1087      2       16966   5.0     E        C  Master            3
# 1093      0    PC 17757   5.0     C        C   Honor            2
# 1109      1      113503   5.0     C        C      Mz            3
# 1121      0      220845   3.0     X        S      Mr            1
# 1133      1       16966   5.0     E        C      Mr            3
# 1244      2      220845   3.0     X        S      Mr            4
# 1262      0       16966   5.0     E        C      Mz            1
# 1276      2      220845   3.0     X        S      Mz            4
# 1280      1      349909   1.0     X        S  Master            5
# 1298      1      113503   5.0     C        C      Mr            3
#
#      Family_Size_Group Ticket_Refinement  Ticket_Frequency
# 7               Medium            349909                 5
# 24              Medium            349909                 5
# 86              Medium            WC6608                 5
# 147             Medium            WC6608                 5
# 176             Medium              4133                 5
# 229             Medium              4133                 5
# 319              Small             16966                 5
# 337              Alone             16966                 5
# 374             Medium            349909                 5
# 377              Small            113503                 5
# 380              Alone           PC17757                 5
# 409             Medium              4133                 5
# 436             Medium            WC6608                 5
# 485             Medium              4133                 5
# 557              Alone           PC17757                 5
# 567             Medium            349909                 5
# 615              Small            220845                 5
# 700              Small           PC17757                 5
# 716              Alone           PC17757                 5
# 736             Medium            WC6608                 5
# 754              Small            220845                 5
# 965              Alone            113503                 5
# 966              Alone            113503                 5
# 1023            Medium              4133                 5
# 1058            Medium            WC6608                 5
# 1087             Small             16966                 5
# 1093             Small           PC17757                 5
# 1109             Small            113503                 5
# 1121             Alone            220845                 5
# 1133             Small             16966                 5
# 1244             Small            220845                 5
# 1262             Alone             16966                 5
# 1276             Small            220845                 5
# 1280            Medium            349909                 5
# 1298             Small            113503                 5

# %% [markdown]
# ### Family_Name
# - 이름은 Lefebre(Sur Name),(콤마) Master.(Initial) Henry Forbes(First Name)

# %%
print ("<" + string.punctuation + ">")
# Out:
# <!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~>

# %%
def get_surname(data):
    surnames = list()
    for index in range(len(data)):
        name = data.iloc[index].split(',')[0]
        name = name.replace(' ', '').strip()
        for punctuation in string.punctuation:
            name = name.replace(punctuation, '')
        surnames.append(name)
    return surnames

# %%
df_all['Family_Name'] = get_surname(df_all['Name'])
df_train = df_all.loc[:890]
df_test = df_all.loc[891:]

# %% [markdown]
# ### Family_Survival_Rate & Ticket_Survival_Rate

# %%
# 202402 업데이트: 최신 pandas 라이브러리에서는 컬럼을 선택할 때 리스트 형식을 사용해야 합니다.
# 따라서 다음과 같이 코드를 수정합니다.
# 기존 코드: df_train.groupby('Family_Name')['Survived', 'Family_Size'].median()
df_train.groupby('Family_Name')[['Survived', 'Family_Size']].median()
# Out:
#               Survived  Family_Size
# Family_Name
# Abbing             0.0          1.0
# Abbott             0.5          3.0
# Abelson            0.5          2.0
# Adahl              0.0          1.0
# Adams              0.0          1.0
# ...                ...          ...
# deMulder           1.0          1.0
# dePelsmaeker       0.0          1.0
# delCarlo           0.0          2.0
# vanBilliard        0.0          3.0
# vanMelkebeke       0.0          1.0
#
# [667 rows x 2 columns]

# %%
# 202402 업데이트: 최신 pandas 라이브러리에서는 컬럼을 선택할 때 리스트 형식을 사용해야 합니다.
# 따라서 다음과 같이 코드를 수정합니다.
# 기존 코드: df_family_survived_rate = df_train.groupby('Family_Name')['Survived', 'Family_Size'].median()
df_family_survived_rate = df_train.groupby('Family_Name')[['Survived', 'Family_Size']].median()

family_rates = dict()
for family_name in df_family_survived_rate.index:
    if df_family_survived_rate.loc[family_name][1] > 1 and (family_name in df_train['Family_Name'].unique() and family_name in df_test['Family_Name'].unique()):
        family_rates[family_name] = df_family_survived_rate.loc[family_name][0]

family_survival_rate = list()
family_survival_rate_NA = list()
mean_survival_rate = np.mean(df_train['Survived'])

for i in range(len(df_all)):
    if df_all['Family_Name'][i] in family_rates:
        family_survival_rate.append(family_rates[df_all['Family_Name'][i]])
        family_survival_rate_NA.append(1)
    else:
        family_survival_rate.append(mean_survival_rate)
        family_survival_rate_NA.append(0)

df_all['Family_Survival_Rate'] = family_survival_rate
df_all['Family_Survival_Rate_NA'] = family_survival_rate_NA

# %%
# 202402 업데이트: 최신 pandas 라이브러리에서는 컬럼을 선택할 때 리스트 형식을 사용해야 합니다.
# 따라서 다음과 같이 코드를 수정합니다.
# 기존 코드: df_ticket_survived_rate = df_train.groupby('Ticket_Refinement')['Survived', 'Ticket_Frequency'].median()
df_ticket_survived_rate = df_train.groupby('Ticket_Refinement')[['Survived', 'Ticket_Frequency']].median()

ticket_rates = dict()
for ticket_name in df_ticket_survived_rate.index:
    if df_ticket_survived_rate.loc[ticket_name][1] > 1 and (ticket_name in df_train['Ticket_Refinement'].unique() and ticket_name in df_test['Ticket_Refinement'].unique()):    
        ticket_rates[ticket_name] = df_ticket_survived_rate.loc[ticket_name][0]

ticket_survival_rate = list()
ticket_survival_rate_NA = list()
mean_survival_rate = np.mean(df_train['Survived'])

for i in range(len(df_all)):
    if df_all['Ticket_Refinement'][i] in ticket_rates:
        ticket_survival_rate.append(ticket_rates[df_all['Ticket_Refinement'][i]])
        ticket_survival_rate_NA.append(1)
    else:
        ticket_survival_rate.append(mean_survival_rate)
        ticket_survival_rate_NA.append(0)

df_all['Ticket_Survival_Rate'] = ticket_survival_rate
df_all['Ticket_Survival_Rate_NA'] = ticket_survival_rate_NA

# %% [markdown]
# ### Survival_Rate

# %%
df_all['Total_Survival_Rate'] = (df_all['Ticket_Survival_Rate'] + df_all['Family_Survival_Rate']) / 2
df_all['Total_Survival_Rate_NA'] = (df_all['Ticket_Survival_Rate_NA'] + df_all['Family_Survival_Rate_NA']) / 2
df_train = df_all.loc[:890]
df_test = df_all.loc[891:]

# %% [markdown]
# ### OneHot Encoding
# - Pclass, Sex, Deck, Embarked, Title (Categorical features are converted to One-hot encoding)
# - ordinal features are not converted

# %%
onehot_cols = ['Pclass', 'Sex', 'Cabin', 'Embarked', 'Title', 'Family_Size_Group']
df_train = pd.get_dummies(df_train, columns=onehot_cols)
df_test = pd.get_dummies(df_test, columns=onehot_cols)

# %% [markdown]
# ## **3. Model**

# %% [markdown]
# - 컬럼값의 범위가 다른 경우, 모델에도 영향을 미치므로, 값을 균일한 정도로 변경하기 위해, 스케일링을 적용할 수 있음
# - 데이터를 모델링하기 전, 스케일링을 통해, 성능 개선 가능
# - StandardScaler: 기본 스케일로, 평균과 표준편차 사용하여 스케일링
#   - MinMaxScaler: 최대/최소값이 1/0이 되도록 스케일링

# %%
drop_cols = ['Family_Name', 'Family_Size', 'Survived',
             'Name', 'Parch', 'PassengerId', 'SibSp', 'Ticket',
            'Family_Survival_Rate', 'Ticket_Survival_Rate', 
             'Ticket_Survival_Rate_NA', 'Family_Survival_Rate_NA', 'Ticket_Refinement']

# %%
X_train = StandardScaler().fit_transform(df_train.drop(columns=drop_cols))
y_train = df_train['Survived'].values
X_test = StandardScaler().fit_transform(df_test.drop(columns=drop_cols))

# %% [markdown]
# ### 모델 파라미터 선택
# - 모델 파라미터는 노트북 최다하단부의 GridSearchCV() 를 사용한 Hyper parameter 값 사용

# %%
single_best_model = RandomForestClassifier(
                                           n_estimators=1500,
                                           max_depth=6,
                                           min_samples_split=5,
                                           min_samples_leaf=6,
                                           oob_score=True,
                                           random_state=1,
                                           n_jobs=-1,
                                           verbose=True)

# %% [markdown]
# ### OOB Score 및 생존확률값 계산

# %%
skf = StratifiedKFold(n_splits=5, random_state=5, shuffle=True)
probs = pd.DataFrame(
    np.zeros((len(X_test), 5)), 
    columns=['Fold{}'.format(i) for i in range(5)]
)

oob = 0
for fold, indices in enumerate(skf.split(X_train, y_train)):
    train_index, val_index = indices
    single_best_model.fit(X_train[train_index], y_train[train_index])
    oob += single_best_model.oob_score_
    probs['Fold{}'.format(fold)] = single_best_model.predict_proba(X_test)[:, 1] # 각 fold 에서 해당 사람이 Survived 될 확률

print ("OOB Score:", "{:.3f}".format(oob / 5))

probs['avg'] = probs.mean(axis=1) # 해당 사람이 fold 별 Survived 될 확률의 평균 계산
probs['final'] = 0
probs.loc[probs['avg'] > 0.5, 'final'] = 1 # 해당 사람이 fold 별 Survived 될 확률의 평균이 50% 이상일 경우, 최종 생존으로 예측
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 776 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 1226 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 1500 out of 1500 | elapsed:    0.9s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 776 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=12)]: Done 1226 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=12)]: Done 1500 out of 1500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 776 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 1226 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 1500 out of 1500 | elapsed:    0.9s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 776 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=12)]: Done 1226 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=12)]: Done 1500 out of 1500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 776 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 1226 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 1500 out of 1500 | elapsed:    0.9s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 776 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=12)]: Done 1226 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=12)]: Done 1500 out of 1500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 776 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 1226 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 1500 out of 1500 | elapsed:    0.9s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 776 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 1226 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=12)]: Done 1500 out of 1500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 776 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 1226 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 1500 out of 1500 | elapsed:    0.9s finished
# OOB Score: 0.846
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 776 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=12)]: Done 1226 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=12)]: Done 1500 out of 1500 | elapsed:    0.1s finished

# %% [markdown]
# ### 실제 제출

# %%
submission_df = pd.DataFrame(columns=['PassengerId', 'Survived'])
submission_df['PassengerId'] = df_test['PassengerId']
submission_df['Survived'] = probs['final'].tolist()
submission_df.to_csv('submissions_final.csv', header=True, index=False)
submission_df.head(10)
# Out:
#      PassengerId  Survived
# 891          892         0
# 892          893         1
# 893          894         0
# 894          895         0
# 895          896         1
# 896          897         0
# 897          898         1
# 898          899         0
# 899          900         1
# 900          901         0

# %%
# !kaggle competitions submit -c titanic -f submissions_final.csv -m "Message"
# Out:
# 100%|████████████████████████████████████████| 2.77k/2.77k [00:03<00:00, 777B/s]
# Successfully submitted to Titanic - Machine Learning from Disaster

# %% [markdown]
# ### 4. 참고: Hyperparameter Tuning with GridSearchCV
# - 예상범위의 값을 기반으로, GridSearchCV 적용

# %%
from sklearn.model_selection import GridSearchCV

n_estimators = [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700]
max_depth = [5, 6, 7, 8, 9, 10]
min_samples_split = [5, 6, 7, 8, 9, 10]
min_samples_leaf = [5, 6, 7, 8, 9, 10]

hyperparams = {
    'n_estimators': n_estimators, 
    'max_depth': max_depth, 
    'min_samples_split': min_samples_split, 
    'min_samples_leaf': min_samples_leaf
}

gd=GridSearchCV(
    estimator = RandomForestClassifier(random_state=1), 
    param_grid = hyperparams, 
    verbose=True, 
    cv=5, 
    scoring="accuracy", 
    n_jobs=-1
)

gd.fit(X_train, y_train)
print(gd.best_score_)
print(gd.best_params_)
# Out:
# Fitting 5 folds for each of 1728 candidates, totalling 8640 fits
# 0.8473165526332307
# {'max_depth': 6, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 1500}

# %% [markdown]
# <div class="alert alert-block" style="border: 1px solid #455A64;background-color:#ECEFF1;">
# 본 자료 및 영상 컨텐츠는 저작권법 제25조 2항에 의해 보호를 받습니다. 본 컨텐츠 및 컨텐츠 일부 문구등을 외부에 공개, 게시하는 것을 금지합니다. 특히 자료에 대해서는 저작권법을 엄격하게 적용하겠습니다.
# </div>
